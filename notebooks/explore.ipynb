# %%
import glob
import os
import json

from lxml import etree

# %% [markdown]
# ## Fabritius

# %%
tree = etree.parse('../data/fabritius/xml/fr.xml')

# %% [markdown]
# For now, we are only interested in the `Iconography` field in each record:

# %%
terms_ = set()
for record in list(tree.findall('record')):
    iconography = record.find('Iconography')
    if iconography is not None:
        for terms in iconography:
            terms_.add(terms.tag)
print(terms_)
# Out:
# {'iconographicTerms', 'generalSubjectDescription', 'iconographicInterpretation', 'subjectTerms', 'specificSubjectIdentification', 'conceptualTerms', 'subjectInterpretiveHistory'}

# %% [markdown]
# ## Subject Terms

# %% [markdown]
# Let's start with the field `subjectTerms`:

# %%
def parse_lil_field(field):
    main_term, sub_terms = "<UNK>", []
    if '(' in field:
        idx = field.find('(')
        main_term = field[:idx].strip()
        if not main_term:
            main_term  = '<UNK>'
        sub_terms = field[idx:].strip().replace('(', '').replace(')', '')
        sub_terms = [st.strip() for st in sub_terms.split(';')]
        sub_terms = [sorted(st.split(' : ')) for st in sub_terms]
    else:
        main_term = field.strip()
    return main_term, sub_terms

def parse_subjectTerms(field):
    field = ' '.join(field.strip().split())
    
    fields_, d = [], []
    
    if ') ; ' in field:
        fields_ = [f.strip() for f in field.split(') ;')]
    elif ' ; ' in field and ')' not in field:
        fields_ = [f.strip() for f in field.split(' ; ')]
    else:
        fields_ = [field]
        
    fields = []
    for field in fields_:
        if ' ; ' in field and '(' not in field:
            fields.extend(field.split(' ; '))
        else:
            fields.append(field)
    
    d = []
    for field in fields:      
        main_term, sub_terms = parse_lil_field(field.strip())
        d.append({main_term : sub_terms})
    
    return d

def parse_xml_file(path):
    meta = {}
    tree = etree.parse(path)
    
    for record in list(tree.findall('record')):
        record_id = record.find('RecordID').text
        iconography = record.find('Iconography')

        if iconography is None:
            continue

        subject = iconography.find('subjectTerms')
        if subject is not None:
            d = parse_subjectTerms(subject.text)
            meta[record_id] = d
    return meta

# %%
for path in sorted(glob.glob('../data/fabritius/xml/*.xml')):
    print(path)
    meta = parse_xml_file(path)
    bn = os.path.basename(path).replace('.xml', '.json')
    with open(f'../data/fabritius/json/{bn}', 'w', encoding='utf8') as json_file:
        json.dump(meta, json_file, ensure_ascii=False, indent=4)
# Out:
# ../data/fabritius/xml/en.xml
# ../data/fabritius/xml/fr.xml
# ../data/fabritius/xml/nl.xml

# %% [markdown]
# As such, the structured of a parsed record will be:
#    - a ordered list of one-key dictionaries,
#    - that have a "main descriptor" as single entry (which can be "<UNK>")
#    - the secondary descriptor consists of a list of lists, because a secondary descriptor can be a set of multiple terms

# %% [markdown]
# ## Iconclass

# %%
import iconclass

# %%
iconclass.get('25G41')
# Out:
# {'c': ['25G41(...)',
#   '25G411',
#   '25G412',
#   '25GG41',
#   '25G41(+0)',
#   '25G41(+1)',
#   '25G41(+2)',
#   '25G41(+3)'],
#  'txt': {'it': 'fiori',
#   'pt': 'flores',
#   'zh': '花卉',
#   'nl': 'Bloemen….(met NAAM)',
#   'de': 'Blumen',
#   'fi': 'kukat',
#   'fr': 'fleurs',
#   'en': 'flowers'},
#  'kw': {'it': ['fiore'],
#   'pt': ['flor'],
#   'nl': ['bloem'],
#   'de': ['Blume'],
#   'fi': ['kukka'],
#   'fr': ['fleur'],
#   'es': ['flor'],
#   'en': ['flower']},
#  'n': '25G41',
#  'p': ['2', '25', '25G', '25G4', '25G41']}

# %% [markdown]
# From the [website](https://labs.brill.com/ictestset/):
#
# > The keys in the returned dict are:
# > - 'n' The notation of this node (the same thing as the first parameter of the .get() call)
# > - 'p' Path to this node, starting from the root of the hierarchy
# > - 'c' Children (descendants) of this node
# > - 'kw' Keywords, a dict keyed on two-letter language code containing keywords associated with this entry
# > - 'txt Textual descriptions of this notation, a dict of strings keyed on two-letter language code.

# %% [markdown]
# Idea:
#     - get frequency and co-occurence data from Brill's iconclass dataset
#     - map ontologies using fasttext and co-ocurence probabilities (some kind of beam search?)

# %%
import json
with open('../data/iconclass_img/data.json') as f:
    ic = json.loads(f.read())

# %%
len(ic)
# Out:
# 87744

# %%
documents = []
for _, codes in ic.items():
    documents.append(codes)

# %%
print(len(documents))
# Out:
# 87744

# %%
documents[:10]
# Out:
# [['31A235', '31A24(+1)', '61B(+54)', '61B:31A2212(+1)', '61B:31D14'],
#  ['41D92', '25G41'],
#  ['11H', '11I35', '11I36'],
#  ['11F25', '11FF25', '41E2'],
#  ['25F3', '25F38(PHEASANT)', '25H', '25H11', '25H213', '34B232(+51)'],
#  ['22E12',
#   '31AA2352',
#   '31B52',
#   '41C122',
#   '41C326',
#   '41C71',
#   '54A43(+11)',
#   '58AA1',
#   '86(ESSEN, TRINKEN UND DAS SPIEL DER VENUS SCHADEN DORT, WO etc.)',
#   '98B(SARDANAPALUS)'],
#  ['25I1', '46C24', '25H13', '46C513', '48C161', '48C149', '25I151'],
#  ['31D14', '41A2', '48C7311', '48C75'],
#  ['31A231', '31A24(+1)', '61B(+55)', '61B:31A2212(+1)'],
#  ['61B(+53)', '61B:31D14']]

# %%
for doc in documents[:10]:
    for term in doc:
        try:
            print(term, iconclass.get(term)['kw']['en'])
        except (KeyError, TypeError):
            pass
# Out:
# 31A235 ['sitting']
# 31A24(+1) ['Stirnansicht', 'front view', 'head', 'posture', 'veduta frontale', 'vue de face']
# 61B(+54) ['Dreiviertel', 'three-quarter', 'tre quarti', 'trois-quarts']
# 41D92 ['woman']
# 25G41 ['flower']
# 11H ['saint']
# 11F25 ['Mater Dolorosa', 'bust', 'full length', 'half-length', 'head', 'mother']
# 41E2 ['optical illusion', 'picture', "trompe l'oeil"]
# 25F3 ['bird']
# 25F38(PHEASANT) ['pheasant']
# 25H ['ideal landscape', 'landscape']
# 25H11 ['mountain']
# 25H213 ['river']
# 34B232(+51) ['chicken', 'cock', 'fowl', 'hen', 'male', 'maschile', 'maschio', 'mâle', 'männlich']
# 22E12 ['burning']
# 31AA2352 ['seat']
# 31B52 ['alcohol', 'drunkenness']
# 41C122 ['pouring']
# 41C326 ['jar', 'jug']
# 41C71 ['alcohol', 'drink']
# 54A43(+11) ['Frau', 'Misura', 'Ripa', 'donna', 'femme', 'temperance', 'woman']
# 58AA1 ['destruction']
# 98B(SARDANAPALUS) ['Sardanapalus']
# 25I1 ['city', 'ideal city', 'veduta']
# 46C24 ['sailing-ship', 'yacht']
# 25H13 ['coast', 'sea']
# 46C513 ['traveller']
# 48C161 ['pillar']
# 48C149 ['ruin']
# 25I151 ['fountain']
# 31D14 ['adult', 'man']
# 41A2 ['house', 'interior']
# 48C7311 ['violin']
# 48C75 ['musical instrument', 'musician']
# 31A231 ['leg', 'standing']
# 31A24(+1) ['Stirnansicht', 'front view', 'head', 'posture', 'veduta frontale', 'vue de face']
# 61B(+55) ['en pied', 'figura intera', 'full length', 'lebensgrosses Porträt']
# 61B(+53) ['Halbfigur', 'half-length', 'mezza figura', 'à mi-corps']

# %%
from sklearn.feature_extraction.text import CountVectorizer

def identity(x):
    return x

vec = CountVectorizer(analyzer=identity, max_features=1000)
X = vec.fit_transform(documents).toarray()
print(X.shape)

# %%
import pandas as pd

df = pd.DataFrame(X, columns=vec.get_feature_names())
df.head()

# %%
df_asint = df.astype(int)
coocc = df_asint.T.dot(df_asint)
coocc.head()

# %%
# https://stackoverflow.com/questions/58701337/how-to-construct-ppmi-matrix-from-a-text-corpus

import numpy as np

def pmi(df, positive=True):
    col_totals = df.sum(axis=0)
    total = col_totals.sum()
    row_totals = df.sum(axis=1)
    expected = np.outer(row_totals, col_totals) / total
    df = df / expected
    # Silence distracting warnings about log(0):
    with np.errstate(divide='ignore'):
        df = np.log(df)
    df[np.isinf(df)] = 0.0  # log(0) = 0
    if positive:
        df[df < 0] = 0.0
    return df

# %%
ppmi = pmi(coocc, positive=True)

# %%
from itertools import combinations

pairs = []
for a, b in combinations(ppmi.index.tolist(), 2):
    pairs.append((ppmi.loc[a][b], a, b))

# %%
pairs = sorted(pairs, reverse=True)

for sc, a, b in pairs[:200]:
    print('===================')
    try:
        print(iconclass.get(a)['kw']['en'], '&&&', iconclass.get(b)['kw']['en'], sc)
    except:
        pass

# %% [markdown]
# ## Show labels

# %% [markdown]
# Alternatively, model documents with word2vec:

# %%
for doc in documents[:10]:
    for term in doc:
        try:
            print(term, iconclass.get(term)['kw']['en'])
        except (KeyError, TypeError):
            pass

# %%
from gensim.models import Word2Vec
model = Word2Vec(documents, size=50, window=5, min_count=1, workers=4)

# %%
w = '41C326'
print(iconclass.get(w)['kw']['en'])
for t, sc in model.wv.most_similar(w):
    try:
        print(iconclass.get(t)['kw']['en'], sc)
    except KeyError:
        pass

# %%
from collections import Counter
cnt = Counter()
for doc in documents:
    cnt.update(doc)
print(cnt.most_common(10))
voc = [w for w, _ in cnt.most_common(350)]
voc[:30]

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering

# %matplotlib inline

plt.style.use('dark_background')
cmap = plt.cm.get_cmap("cool")
from bokeh.palettes import Accent

def tsne_plot(model, voc, lang='en', num_clust=8):
    "Creates and TSNE model and plots it"
    labels, tokens = [], []

    for word in voc:
        tokens.append(model.wv[word])
        try:
            l = iconclass.get(word)['kw'][lang]
            l = '-'.join(l)[:15]
            labels.append(l)
        except:
            labels.append('$' + word)
    
    tsne_model = TSNE(perplexity=40, n_components=2, init='pca', n_iter=2500, random_state=23)
    coor = tsne_model.fit_transform(tokens)
    
    # run clustering on TSNE-coordinates:
    clustering = AgglomerativeClustering(linkage='ward',
                                     affinity='euclidean',
                                     n_clusters=num_clust)
    clustering.fit(coor)
    clust_labels = clustering.labels_
    colors = [Accent[num_clust][i] for i in clust_labels]
    
    # plot:
    fig, ax1 = plt.subplots(figsize=(14, 14)) # larger canvas
    x1, x2 = coor[:, 0], coor[:, 1]
    for a, b in zip(x1, x2):
        ax1.scatter(a, b, edgecolors='none', facecolors='none')
    for x, y, w, c in zip(x1, x2, labels, colors):
        if not w.startswith('$'):
            ax1.text(x, y, w, ha='center', va="center",
                 color=c,
                 fontdict={'family': 'Arial', 'size': 12})

    # control aesthetics:
    ax1.set_xlabel(''); ax1.set_ylabel('')
    ax1.set_xticklabels([]); ax1.set_xticks([])
    ax1.set_yticklabels([]); ax1.set_yticks([])
    plt.tight_layout()

    plt.show()

# %%
tsne_plot(model, voc)

# %% [markdown]
# ## FastText

# %%
path_fr = '../data/vectors/wiki.fr.align.vec'

from gensim.models.keyedvectors import KeyedVectors
wv_fr = KeyedVectors.load_word2vec_format(path_fr)

# %%
wv_fr.most_similar('chien')
# Out:
# [('chien…', 0.7481318116188049),
#  ('chienne', 0.7443133592605591),
#  ('chiens', 0.7350468039512634),
#  ('chien»', 0.7269512414932251),
#  ('chiens…', 0.7169510126113892),
#  ('chat', 0.6941362619400024),
#  ('chiot', 0.6886463165283203),
#  ('dogue', 0.6747391819953918),
#  ('caniche', 0.6535861492156982),
#  ('aboie', 0.6478910446166992)]

# %%
iclass  = {}

for doc in documents:
    for code in doc:
        try:
            labels = iconclass.get(code)['kw']['fr']
            iclass[code] = tuple(labels)
        except (TypeError, KeyError):
            continue

iclass
# Out:
# {'31A235': ('asseoir',),
#  '31A24(+1)': ('position', 'tête'),
#  '41D92': ('femme',),
#  '25G41': ('fleur',),
#  '11H': ('saint',),
#  '11F25': ('Mater Dolorosa', 'buste', 'en pied', 'mère', 'tête', 'à mi-corps'),
#  '41E2': ("illusion d'optique", 'peinture', "trompe l'oeil"),
#  '25F3': ('oiseau',),
#  '25F38(PHEASANT)': ('faisan',),
#  '25H': ('paysage', 'paysage idéal'),
#  '25H11': ('montagne',),
#  '25H213': ('rivière',),
#  '34B232(+51)': ('coq', 'poule', 'poulet', 'volaille'),
#  '22E12': ('brûler',),
#  '31AA2352': ('siège',),
#  '31B52': ('alcool', 'ivresse'),
#  '41C122': ('verser',),
#  '41C326': ('bocal', 'pichet'),
#  '41C71': ('alcool', 'boisson'),
#  '54A43(+11)': ('Misura', 'Ripa', 'tempérance'),
#  '58AA1': ('destruction',),
#  '98B(SARDANAPALUS)': ('Sardanapale',),
#  '25I1': ('cité idéale', 'veduta', 'ville'),
#  '46C24': ('voilier', 'yacht'),
#  '25H13': ('côte', 'mer'),
#  '46C513': ('voyageur',),
#  '48C161': ('colonne',),
#  '48C149': ('ruine',),
#  '25I151': ('fontaine',),
#  '31D14': ('adulte', 'homme'),
#  '41A2': ('intérieur', 'maison'),
#  '48C7311': ('violon',),
#  '48C75': ('instrument de musique', 'musicien'),
#  '31A231': ('debout', 'jambe'),
#  '46C131': ('monter à cheval',),
#  '41A12': ('château',),
#  '25I': ('paysage',),
#  '25I144': ('place', 'rond-point', 'square'),
#  '45H3': ('bataille',),
#  '46B111': ('éventaire',),
#  '21C': ('feu',),
#  '31D111(+89)': ('bébé',),
#  '31D11221(+89)': ('garçon',),
#  '31D15': ('adulte', 'femme'),
#  '42A31': ('allaiter',),
#  '31A2421': ('gauche (contraire de droite)',),
#  '41D211': ('robe',),
#  '41D221(HAT)': ('couvre-chef',),
#  '11G1911': ('chérubin', 'tête'),
#  '11C13': ('tétragramme',),
#  '71O933': ('champ', 'os', 'vallée', 'Ézéchiel 37'),
#  '12EE13': ('demi-déesse', 'déesse', 'heroïne'),
#  '12FF13': ('demi-déesse', 'déesse', 'heroïne'),
#  '31A54': ('baigner', 'laver'),
#  '11Q331': ('ermite',),
#  '46C(+643)': ('trafic', 'transporter'),
#  '31A2422': ('droit (contraire de gauche)',),
#  '44F55': ('violence',),
#  '23U22': ('sablier',),
#  '25F(+342)': ('animal',),
#  '25F23(LION)(+33)': ('lion',),
#  '25F42(+343)': ('serpent',),
#  '25FF232': ('Chimera', 'Ripa', 'chimère', 'chèvre', 'lion', 'serpent'),
#  '31AA234': ("s'accroupir",),
#  '31A222(+89)': ('buste', 'poitrine'),
#  '31A2512(+9321)': ('bras étendu', 'en avant'),
#  '31A2512(+933)': ('bras étendu', 'en avant'),
#  '31A2515': ('en bas',),
#  '31A2515(+933)': ('en bas',),
#  '31A45231': ('Sfinge', 'lion', 'sphinx'),
#  '31D12': ('jeune homme',),
#  '31D15(+72)': ('adulte', 'femme'),
#  '31D15(+89)': ('adulte', 'femme'),
#  '34B11(+0)': ('chien',),
#  '41A3911': ('puits',),
#  '41B32': ('torche', 'tête en bas'),
#  '41D211(+82)': ('robe',),
#  '45C13(SWORD)': ('épée',),
#  '45C14(LANCE)': ('lance',),
#  '46C1271(+0)': ('porter sur le dos',),
#  '47D8(ROPE)': ('corde',),
#  '48C1613(+0)': ('base',),
#  '48C168(NICHE)': ('abaque', 'corniche'),
#  '49C111': ('Grammatica', 'Ripa', 'grammaire'),
#  '49C112': ('Dialectica', 'Dialettica', 'Ripa', 'logique'),
#  '49C113': ('Eloquentia',
#   'Rettorica',
#   'Rhetorica',
#   'Ripa',
#   'rhétorique',
#   'éloquence'),
#  '49K10': ('Historia', 'Ripa'),
#  '41A7122': ('bibliothèque',),
#  '49B43': ('professeur',),
#  '25G41(PASSION FLOWER)': ('aconit',),
#  '25G3': ('arbre',),
#  '25G4(REED)': ('lotus', 'menthe', 'orge', 'roseau'),
#  '25H192': ('poldérisation', 'récupérer'),
#  '26A': ('nuage',),
#  '48C24': ("oeuvre d'art", 'reproduction'),
#  '94N': ('Méléagre',),
#  '46C13141': ('cheval',),
#  '31D14(+9321)': ('adulte', 'homme'),
#  '34A9': ('maltraiter', 'tourmenter'),
#  '11Q712': ('chapelle', 'extérieur', 'église'),
#  '11Q7141': ('autel',),
#  '44B1212': ('trône',),
#  '11Q713': ('intérieur', 'église'),
#  '11Q73262': ('devant', 'prêtre'),
#  '43A4121': ('mariage',),
#  '46D1': ('crier', 'crieur', 'crieur public', 'nouvelles'),
#  '49C3': ('philosophe', 'savant'),
#  '34B11(+1)': ('chien',),
#  '31D14(+933)': ('adulte', 'homme'),
#  '25H1124': ('pierre',),
#  '57AA61': ('Amor di Virtù',
#   'Attione virtuosa',
#   "Guida sicura de' veri honori",
#   'Ripa',
#   'Vertu',
#   'Virtù',
#   'Virtù insuperabile',
#   'fausseté',
#   'malhonnêteté',
#   'vertu'),
#  '57AA6121': ('Adulatione',
#   "Purità et Sincerità d'animo",
#   'Sincerità',
#   'flatterie',
#   'pureté',
#   'sincérité'),
#  '33B2': ('duel',),
#  '43C55': ('jeux de dés',),
#  '31A2735': ('être jeté',),
#  '46C1318': ('cheval', 'mouvement'),
#  '41D212': ('manteau',),
#  '41D221': ('couvre-chef',),
#  '41A1': ('architecture', 'architecture civique', 'bâtiment', 'édifice'),
#  '45B': ('soldat',),
#  '31A5341': ('moustache',),
#  '49N': ('lire',),
#  '25F711': ('insecte',),
#  '25G41(AURICULA)': ('aconit',),
#  '73D353': ('bandeau sur les yeux', 'moquer', 'yeux bandés'),
#  '43C128': ('pêcheur',),
#  '25H112': ('rocher',),
#  '25H214': ('lac',),
#  '73C4': ('guérir', 'miracle'),
#  '45H3(+2)': ('bataille',),
#  '34B11': ('chien',),
#  '43A42': ('accueil public',
#   'entrer',
#   'entrée solennelle',
#   'joyeuse entrée',
#   'parade',
#   "recevoir quelqu'un",
#   'spectacle fastueux',
#   'triomphe'),
#  '73': ('Nouveau Testament',),
#  '73A42': ('Sposalizio', 'grand-prêtre', 'mariage'),
#  '11M31': ('Fede',
#   'Fede catholica',
#   'Fede christiana',
#   'Fede christiana catholica',
#   'Fides',
#   'Ripa',
#   'croix',
#   'foi'),
#  '11M32': ('Espérance', 'Ripa', 'Speranza divina e certa', 'Spes', 'ancre'),
#  '11M33': ('Caritas', 'Carità', 'Charité', 'Ripa', 'enfant'),
#  '48A9875': ('guirlande',),
#  '48A9876': ('cartouche',),
#  '41A421': ('rideau',),
#  '11G1923': ('torche',),
#  '73B65': ('reposer',),
#  '71D135': ('arrestation', 'prison'),
#  '49L17': ('initiale',),
#  '49M413': ('initiale', 'initiale historiée'),
#  '49M3': ('imprimé',),
#  '9': ('antiquité classique', 'histoire', 'histoire ancienne', 'mythologie'),
#  '31A511': ('miroir',),
#  '41A411': ('papier peint',),
#  '41A412': ('lambris',),
#  '41A44': ('plafond',),
#  '48A9863': ('rocaille',),
#  '41C741': ('pipe',),
#  '48C351': ('applique', 'en relief'),
#  '46C5135': ('dehors', 'reposer'),
#  '31A5331': ('perruque',),
#  '41D222(JABOT)': ('jabot',),
#  '41D242(+81)': ('vêtements habillés',),
#  '49L511': ("plume d'oie",),
#  '49M32': ('livre', 'livre fermé', 'livre ouvert'),
#  '44A11': ('devise',),
#  '49M42': ('ornement',),
#  '25G41(ROSE)': ('rose',),
#  '41A6': ('jardin',),
#  '73B4': ('Anne (prophétesse)',
#   'Luc 02',
#   'Siméon Christophore (St)',
#   'présenter (personne)',
#   'temple'),
#  '11A23': ('perfection',),
#  '11D51': ('âme',),
#  '11Q0': ('Divotione', 'Ripa', 'dévotion', 'piété'),
#  '22C311': ('halo', 'nimbe'),
#  '25D29': ('poussière',),
#  '25F3(+342)': ('oiseau',),
#  '31B6241': ('souffler',),
#  '31D13': ('fille', 'jeune'),
#  '41A712': ('buffet', 'casier', 'rayons'),
#  '47A21': ('atelier',),
#  "48C34(POTTER'S WHEEL)": ('potier', 'tour de potier'),
#  '47I15(SPADE)': ('bêche',),
#  '48C211': ('bozzetto', 'modèle', 'ébauche'),
#  '48C313': ('potier',),
#  '48C313(+63)': ('potier',),
#  '57A644(+4)': ('Ossequio', 'obséquiosité', 'soumission'),
#  '71A31(+0)': ('argile', 'bâtir', 'être humain'),
#  '25F72(OYSTER)(+93)': ('huître',),
#  '41D221(CHIGNON)': ('bonnet', 'chapeau', 'képi', 'turban'),
#  '41D26611': ('perle',),
#  '41D2668': ('boîte', 'boîte à bijoux'),
#  '43C9': ('danser', 'danseur'),
#  '92D1916': ('putti',),
#  '44A1': ('armoiries',),
#  '31D17': ('vieille femme',),
#  '48C524': ('esquisse', "oeuvre d'art"),
#  '41B31': ('bougie',),
#  '31D112': ('enfant',),
#  '31AA28': ('ombre',),
#  '43C71511': ('ombre', 'silhouette'),
#  '25H1': ('zone tempérée',),
#  '31E234631': ('épée',),
#  '45K14': ('ville',),
#  '45K4': ('capture (ville)',),
#  '45L12': ('entrer', 'marcher'),
#  '45L22': ('butin', 'partager'),
#  '45L3': ('piller',),
#  '45M11': ('bataille',),
#  '46B33': ('peser',),
#  '83(VALERIUS MAXIMUS, Facta et dicta memorabilia, 4.1.2)': ('scène',
#   'écrivain'),
#  '25H132': ('dunes littorales',),
#  '25H133': ('plage',),
#  '25H23': ('marine (peinture)', 'mer'),
#  '46C14': ('animal', 'conduire', 'tirer', 'véhicule'),
#  '46C24(BOMSCHUIT)': ('barque',
#   'boier',
#   'brick',
#   'goèlette',
#   'nef (navire)',
#   'schooner'),
#  '49G2': ('malade',),
#  '49G1': ('médecin',),
#  '31A2533': ('front',),
#  '31A461': ('douleur',),
#  '49G3': ('examen', 'traitement'),
#  '49E81': ('appareils', 'équipement'),
#  '25G41(CARNATION)': ('oeillet',),
#  '25G41(TULIP)': ('tulipe',),
#  '41A671': ('fleur', 'fruit', 'insecte', 'nature morte'),
#  '41A772': ('pierre', 'vase'),
#  '48A9861': ('bandelettes entrelacés', 'rouleaux entrelacés'),
#  '48C74': ('notation', 'notation musicale', 'partition', 'écrire'),
#  '43C114': ('chasseur', 'chasseuse'),
#  '33A35': ('conversation', 'dialogue', "scène d'intérieur"),
#  '41A711': ('table',),
#  '43C1147': ('chien', 'chien de chasse'),
#  '25F(+4591)': ('animal',),
#  '41E2(+0)': ("illusion d'optique", 'peinture', "trompe l'oeil"),
#  '48C511': ('atelier', 'peintre', 'travail'),
#  '48C5152': ('palette',),
#  '48C5153': ('brosse',),
#  '48C5157': ('appuie-main',),
#  '44B512': ('Chambre', 'Chambre Basse', 'parlement'),
#  '44C312': ('caricature', 'satire'),
#  '31B1': ('dormir',),
#  '41A322': ('fermer',),
#  '54DD311': ('attendre', 'continuation', 'surveiller'),
#  '25I41': ('moulin', 'moulin à vent'),
#  '11N36': ('Lussuria', 'Luxuria', 'Ripa', 'convoitise', 'luxe', 'luxure'),
#  '31D14(+72)': ('adulte', 'homme'),
#  '41A51': ("cour (d'immeuble)",),
#  '49E24(+0)': ('acoustique', 'son'),
#  '94I233': ('alarme', 'compagnon', 'nude', 'rencontrer'),
#  '71D': ('Genèse', 'Joseph (fils de Jacob)'),
#  '31A45': ('Mostri', 'animal', 'forme', 'monstre'),
#  '25FF': ('Mostri',
#   'Ripa',
#   'animal',
#   'animal fabuleux',
#   'fiction',
#   'grotesque'),
#  '31A53421': ('rouflaquettes',),
#  '11D': ('Christ',),
#  '41A3911(+0)': ('puits',),
#  '44E14(+0)': ('fontaine', 'pompe', 'pompe publique', 'utilité publique'),
#  '73C72212': ('boisson', 'cruche', 'demander', 'puits', 'puits de Jacob'),
#  '45K13': ('forteresse',),
#  '45C41': ('camp', 'tente'),
#  '25H114': ('colline', 'contrées vallonée'),
#  '45K122': ('bastion', 'rempart'),
#  '25C211': ('rose des vents',),
#  '83(OVID, Metamorphoses)': ('scène', 'écrivain'),
#  '25F24(DEER)': ('biche',),
#  '25H2323': ('baie (golfe)', 'golfe'),
#  '43C11': ('chasser', 'occupations humaines'),
#  '96A5(FAMA)': ('Fama', 'célébrité', 'renommée'),
#  '49L171': ('initiale historiée',),
#  '71H334': ('soldat', 'tuer'),
#  '11H(MACARIUS)': ('Macaire (St)', 'crâne', 'en forme de T', 'ermite', 'tau'),
#  '41D2632': ('ombrelle', 'parasol'),
#  '43C111243': ('sanglier',),
#  '46C13185': ('se cabrer',),
#  '73F22315': ('Lystre',),
#  '25K1': ('paysage en régions subtropicales', 'paysage en régions tropicales'),
#  '46C11': ('chemin', 'route'),
#  '73C41': ('cécité',),
#  '25G21(LEMON)': ('citron',),
#  '46C232': ('bateau à rames', "bras d'homme", 'canoë'),
#  '31A2743': ('frapper',),
#  '33A3': ('compagnie',
#   'compagnie élégante',
#   'hôte',
#   "recevoir quelqu'un",
#   'visiter'),
#  '33B3': ('combattre',),
#  '25F23(LION)(+491)': ('lion',),
#  '34F1(+0)': ('menacer',),
#  '54AA4': ('Ripa', 'Sforza con Inganno', 'Violenza', 'violence'),
#  '54C2(+4)': ('exhorter', 'recommandation'),
#  '57A6': ('Amor di Virtù',
#   'Attione virtuosa',
#   "Guida sicura de' veri honori",
#   'Ripa',
#   'Vertu',
#   'Virtù',
#   'Virtù insuperabile',
#   'vertu'),
#  '25F(+341)': ('animal',),
#  '25F23(LEOPARD)(+58)': ('léopard',),
#  '25F3(+33)': ('oiseau',),
#  '25F42(+49)': ('serpent',),
#  '25F42(+491)': ('serpent',),
#  '25G13': ('groupe',),
#  '25G21(+1)': ('fruit',),
#  '25I146': ('murailles',),
#  '41D2664': ('anneau',),
#  '44B191': ('couronne',),
#  '44B194': ('armoiries',),
#  '45C19(SHIELD)': ('bouclier',),
#  '92B11221': ('abondance',),
#  '31A22210': ('symbole', 'symbolisme du coeur'),
#  '44B': ('Auttorità o Potestà',
#   'Politica',
#   'Ripa',
#   'gouvernement',
#   'occupations humaines',
#   'état'),
#  '44B10': ('vertu',),
#  '44B127': ('sujet',),
#  '44B15131': ('père',),
#  '44B192': ('bâton', 'sceptre'),
#  '44G(+6)': ('justice', 'loi', 'occupations humaines'),
#  '46B31': ('argent',),
#  '49': ('occupations humaines', 'savoir', 'science'),
#  '52A51': ('Sagesse',
#   'Sapientia',
#   'Sapienza',
#   'Sapienza humana',
#   'Sapienza vera',
#   'sagesse'),
#  '53B5': ('Obedienza', 'Ripa', 'obéissance'),
#  '53C13': ('Rigore', 'Ripa', 'rigueur'),
#  '54A7': ('Fortezza',
#   'Fortezza & valore del corpo ...',
#   "Fortezza d'Animo e di corpo",
#   'Fortezza del corpo congiunta ...',
#   'Forza',
#   'Ripa',
#   'force',
#   'puissance'),
#  '54E42': ('Custodia',
#   'Difesa contra nimici, malefici ...',
#   'Difesa contra pericoli',
#   'Ripa',
#   'Riparo da i tradimenti',
#   'Securitas',
#   'protection'),
#  '54F11': ('Felicità publica',
#   'Prosperità della vita',
#   'Salute',
#   'Santé (personification romaine)',
#   'bien-être',
#   'bonheur',
#   'prospérité'),
#  '57A632': ('accuser', 'innocence'),
#  '57A77': ('Affabilità, piacevolezza, amabilità',
#   'Animo piacevole, trattabile & amorevole',
#   'Benignità',
#   'affabilité',
#   'amabilité',
#   'gentillesse'),
#  '57B1': ('Lode', 'Ripa', 'approbation', 'louer'),
#  '59B31': ('Ampiezza della Gloria',
#   'Gloria',
#   'Gloria & Honore',
#   'Gloria de prencipi',
#   'Honneur',
#   'Honore',
#   'Honos',
#   'Sublimatà della Gloria',
#   'gloire',
#   'honneur'),
#  '59C1': ('loi', 'maintien de la loi'),
#  '25A3': ('pays', 'région'),
#  '45K1': ('fortification', 'ingénierie'),
#  '31D11221': ('garçon',),
#  '43A2': ('compagnie',
#   'dehors',
#   'famille',
#   'fête champêtre',
#   'joyeuse compagnie',
#   'pique-nique',
#   'réjouissance dans le privé'),
#  '41C12': ('boire',),
#  '47H311': ('quenouille',),
#  '43B31': ('auberge', 'bistrot', 'café', 'salon (établissement public)'),
#  '46C1312': ('portrait', 'portrait officiel', 'équestre'),
#  '48C7324': ('balalaïka', 'cistre', 'guitare', 'mandoline'),
#  '11HH': ('femme',),
#  '11HH(CATHERINE)34': ('anneau de mariage',
#   'enfant Jésus',
#   'mariage mystique'),
#  '42D3': ('mari et femme', 'mariage', 'matrimonium'),
#  '34B12': ('chat',),
#  '41A773': ('cruche', 'céramique', 'jarre', 'pot', 'poterie', 'vase'),
#  '41B21': ('cheminée', 'feu ouvert'),
#  '41C4': ('repas', 'repas familial'),
#  '48C7354': ('cornemuse', 'musette'),
#  '25F(+36)': ('animal',),
#  '25F42': ('serpent',),
#  '25F43': ('crocodile',),
#  '25FF422': ('dragon',),
#  '25G4': ('herbe',),
#  '25H14': ('île',),
#  '25I5': ('château', 'tour'),
#  '31B62323': ('langue',),
#  '25F(+46)': ('animal',),
#  '25F(+63)': ('animal',),
#  '31A22141': ('langue',),
#  '44B1': ('souverain',),
#  '44G544': ('voler (prendre)',),
#  '54DD51': ('Pericolo', 'Ripa', 'danger', 'sécurité'),
#  '55B1': ('Opulentia', 'Opulenza', 'Richezza', 'Ripa', 'opulence', 'richesse'),
#  '57A42': ('Compuntione', 'Ripa', 'repentir'),
#  '57AA621': ('Fedeltà', 'Fides', 'Fraude', 'Inganno', 'fidélité', 'tromperie'),
#  '57BB25': ('Biasimo vitioso',
#   'Calunnia',
#   'Detrattione',
#   'Maledicenza',
#   'calomnie',
#   'détraction',
#   'honorer'),
#  '73D31211': ('apôtre', 'dormir', 'onze', 'trois'),
#  '34B232': ('coq', 'poule', 'poulet', 'volaille'),
#  '48A98311': ('feuillage',),
#  '45C221': ('casque',),
#  '31A41': ('difformité', 'infirme', 'maladie'),
#  '33C23': ('couple',),
#  '31D16': ('vieillard',),
#  '92L41': ('satyre',),
#  '48A98211': ('mascaron', 'masque'),
#  '48A9841': ('boeuf', 'bucrane', 'tête (animal)'),
#  '48C515': ('outil', 'outils de peintre'),
#  '11H(MARTIN)41': ('agenouiller',
#   'charité',
#   'couper',
#   'manteau',
#   'monter à cheval',
#   'partager',
#   'épée'),
#  '57AA51': ('Lascivia',
#   'Licenza',
#   'Pudicitia',
#   'Voluptas',
#   'décence',
#   'pudeur',
#   'réserve',
#   'sensualité'),
#  '49G43': ('infirmière',),
#  '31A22221': ('respirer',),
#  '45C23': ('carquois',),
#  '92K1': ('dieu de fleuve',),
#  '97': ('changement', 'métamorphose', 'transformation'),
#  '97AA1': ('Daphné', 'Ovide, Métamorphoses 01', 'Pénée', 'homme', 'laurier'),
#  '98B(PERILLUS)68': ('Phalaris',
#   'bronze',
#   'brûler vif',
#   'taureau',
#   'être jeté'),
#  '11N32': ('Envie (Invidia)', 'Ripa'),
#  '71F3631': ('Hébron', 'colline', 'porter sur les épaules'),
#  '31B19': ('reposer',),
#  '31B6235': ('parler',),
#  '11N1': ('Peccato', 'Ripa', 'mal', 'péché', 'vice'),
#  '31A2351': ('terre',),
#  '31A244': ('courber', 'en avant', 'incliner'),
#  '31A2512(+934)': ('bras étendu', 'en avant'),
#  '31A27411': ('relâcher',),
#  '31A2748': ('pousser',),
#  '31A46242': ('ulcère',),
#  '31D14(+89)': ('adulte', 'homme'),
#  '49G331': ('clystère', 'lavement'),
#  '11H(PETER)9': ('portrait',),
#  '25H15': ('arbre', 'forêt'),
#  '43C113': ('butin de chasse', 'carcasse (animal)', 'gibier', 'nature morte'),
#  '98': ("histoire de l'antiquité classique",),
#  '25F23(LION)': ('lion',),
#  '45C22': ('armure',),
#  '45(+26)': ('affaires militaires', 'occupations humaines'),
#  '48C532': ('autoportrait', "graveur d'art", 'portrait'),
#  '48C513': ('autoportrait', 'peintre', 'portrait'),
#  '48A9832': ('fruit', 'légumes'),
#  '46C112': ('pont',),
#  '47D31': ('moulin', 'moulin à vent'),
#  '73G11': ('Patmos', 'aigle', 'écrire', 'île'),
#  '31F11': ('crâne',),
#  '42E43': ('cimetière', 'tombe', 'tombeau'),
#  '43C41': ('jeu de balle',),
#  '43C785': ('souffler',),
#  '43C78721': ('cheval', 'cheval de bois'),
#  '46A17': ('classe', 'classe ouvrière', 'ouvrier', 'ouvrière'),
#  '47G1': ('chantier de construction',),
#  '25H216': ('cascade',),
#  '43C512': ('carte', 'cartes à jouer'),
#  '12B13': ('demi-dieu', 'demi-déesse', 'dieux', 'déesse', 'heroïne', 'héros'),
#  '92L5': ('Pan',),
#  '26C9': ('absence',
#   'calme',
#   'manque',
#   'nature',
#   'phénomène',
#   'phénomène météorologies',
#   'temps',
#   'vent'),
#  '11R6': ('Memento mori',
#   'Mort',
#   'Vanitas',
#   'Vanità',
#   'nature morte',
#   'vanité'),
#  '46E221': ('enveloppe', 'lettre (épître)'),
#  '48C7323': ('luth', 'théorbe'),
#  '25I14': ('route', 'route publique'),
#  '48C1431': ('fantaisie',),
#  '41D221(BOOGJESMUTS)': ('bonnet', 'chapeau', 'képi', 'turban'),
#  '25F36(DUCK)': ('canard',),
#  '25G3(+371)': ('arbre',),
#  '25G3(WILLOW)': ('saule',),
#  '25H212': ('ruisseau',),
#  '41A17': ('ferme',),
#  '46C2231': ('embarcadère', 'quai'),
#  '25F31': ('groupe',),
#  '25F711(BUTTERFLY)': ('libellule', 'papillon', 'poux', 'puce'),
#  '25G41(CYCLAMEN)': ('aconit',),
#  '25G41(JASMINE)': ('aconit',),
#  '25G41(LILY)': ('lis',),
#  '25G41(MARIGOLD)': ('aconit',),
#  '41A774': ('bocal', 'bouteille', 'carafe', 'flacon', 'vase', 'verre'),
#  '25I1461': ('porte de la ville',),
#  '46C13142': ('âne',),
#  '73D14': ('Jean 12',
#   'Jérusalem',
#   'Luc 19',
#   'Marc 11',
#   'Matthieu 21',
#   'dimanche des Rameaux',
#   'entrer',
#   'palme',
#   'vêtements',
#   'âne'),
#  '44A311': ('porte-drapeau', 'porte-étendard'),
#  '45H(+22)': ('combattre', 'guerre'),
#  '25H21': ("cours d'eau",),
#  '34B232(+921)': ('coq', 'poule', 'poulet', 'volaille'),
#  '11I62': ('homme', 'héros', 'juge', 'patriarche', 'prophète'),
#  '31A2361': ('dos',),
#  '31A21': ('os', 'squelette'),
#  '71': ('Ancien Testament',),
#  '71O9331': ('corps',),
#  '44F1': ('rue', 'émeute'),
#  '43A4': ('bateau', 'eaux', 'fêtes publiques', 'mer'),
#  '23R14': ('nuit',),
#  '41B33(+1)': ('lanterne',),
#  '25F42(VIPER)(+431)': ('vipère',),
#  '43B51': ('baigner', 'mer'),
#  '45B212': ('arme', 'manipuler'),
#  '45C1': ('arme',),
#  '54F12': ('Fato',
#   'Fortuna',
#   'Fortuna aurea',
#   'Fortuna buona',
#   'Fortuna pacifica overo clemente',
#   'Sorte'),
#  '41A7612': ('baldaquin',),
#  '42B112': ('fille', 'père et fille'),
#  '46E1': ('messager',),
#  '46E2322': ('mauvais', 'messager', 'nouvelles'),
#  '98C(TULLIA)68': ('mort',),
#  '32B321': ('nègre',),
#  '32B33': ('Asiatiques',),
#  '33A1': ('saluer',),
#  '45C16(CANNON)(+1)': ('canon (arme)',),
#  '46C(+53)': ('trafic', 'transporter'),
#  '47I211': ('bovins',),
#  '41A18': ('abri', 'cabane', 'hutte'),
#  '43B13': ('marcher', 'randonner'),
#  '33C232': ('baiser', 'embrasser'),
#  '43B144': ('cueillir', 'fleur'),
#  '56B1(+4)': ('Allegrezza',
#   'Allegrezza da le medaglie',
#   'Allegrezza, letitia e giubilo',
#   'Diletto',
#   'Piacere',
#   'Piacere honesto',
#   'Ripa',
#   'joie'),
#  '56BB1(+4)': ('Dolore', 'Dolore di Zeusi', 'Ripa', 'chagrin', 'douleur'),
#  '56F2(+4)': ('Amore (secondo Seneca)', 'Amour', 'Ripa'),
#  '92D162': ("Amour piqué (l')",
#   'abeille',
#   'cueillir',
#   'miel',
#   "piqûre d'abeille",
#   'rose',
#   'voler (prendre)'),
#  '31A534': ('barbe',),
#  '41A7751': ('corbeille',),
#  '43A1451': ('Nicolas de Myre (St)',
#   'Saint-Nicholas',
#   'Sinterklaas',
#   'décembre 5',
#   'veille de Saint-Nicolas'),
#  '11Q652': ('reliquaire', 'relique'),
#  '25F32(MAGPIE)': ('pie',),
#  '25G3(+21)': ('arbre',),
#  '31A(+822)': ('Corpo humano',
#   'Ripa',
#   'corps',
#   'femme',
#   'figure humaine',
#   'homme',
#   'nu'),
#  '31B6(+933)': ('expression',),
#  '46A5': ('communication', 'langage'),
#  '54A11': ('Assiduità', 'Industria', 'Ripa', 'Zelo', 'Zèle', 'assiduité'),
#  '55A1': ('acquisition', 'gain', 'profit'),
#  '58B3': ('Immortalità', 'Ripa', 'immortalité', 'impérissable (état)'),
#  '58BB1': ('mort', 'vie'),
#  '31A25552': ('en avant', 'indiquer'),
#  '47I221': ('berger',
#   'bergère',
#   'gardien de troupeaux',
#   'gardienne de troupeaux',
#   'vacher',
#   'vachère'),
#  '71C1311': ('Moriyya', 'serviteur', 'voyager', 'âne'),
#  '11C21': ('Christ', 'adulte', 'jeune homme'),
#  '22C31': ('rayon de lumière',),
#  '31A2331': ('deux',),
#  '41A251': ('cabinet de travail', 'studiolo'),
#  '41B31(+1)': ('bougie',),
#  '41C37': ('tissu',),
#  '49L62': ('encrier', 'encrier (encastré)'),
#  '54A1': ('activité',),
#  '54AA11': ('Dapocaggine', 'Paresse', 'Pigritia', 'Ripa', 'activité'),
#  '46A12': ('chevalerie', 'classe', 'noblesse', 'patriciat'),
#  '43C92': ('couple', 'paire'),
#  '71W51': ('cendres', 'furoncle', 'gratter', 'tesson', 'ulcère'),
#  '71W5311': ('insulter',),
#  '71A311': ('animer', 'main', 'narine', 'étendre'),
#  '71A3421': ('émerger',),
#  '11H(FRANCIS)': ('Franciscains',
#   "François d'Assise (St)",
#   'crucifix',
#   'crâne',
#   'lis',
#   'livre',
#   'moine',
#   'stigmates'),
#  '45D313': ('hussard', 'soldat (simple)', 'soldat à cheval'),
#  '46C1112': ('traverser en bateau',),
#  '46C21': ('bateau',),
#  '41B312': ('applique (éclairage)', 'bougeoir mural'),
#  '48C73513': ('flûte traversière', 'traverse'),
#  '14C': ('signe', 'symbole]SEQ['),
#  '23O11': ('Capricorn', 'Capricorne', 'décembre'),
#  '23O12': ('Aquarius', 'Verseau', 'janvier'),
#  '23O13': ('Pisces', 'Poissons', 'février'),
#  '23O21': ('Aries', 'Bélier', 'Mars'),
#  '23O22': ('Taureau', 'Taurus', 'avril'),
#  '23O23': ('Gemini', 'Gémeaux', 'mai'),
#  '11M42': ('Ripa', 'Temperantia', 'Temperanza', 'tempérance'),
#  '49M3(+0)': ('imprimé',),
#  '57A65(+4)': ('sacrifice de soi',),
#  '26D1': ('neige',),
#  '46A151': ('loques', 'mendiant'),
#  '22E2': ('froid',),
#  '31BB13': ('terre',),
#  '48C7335': ('accordéon',),
#  '11I62(EZEKIEL)': ('double', 'livre', 'roue', 'rouleau', 'sosie', 'Ézéchiel'),
#  '11H(JUDE THADDAEUS)': ('Jude Thaddée (St)',
#   'apôtre',
#   'hallebarde',
#   'livre',
#   'massue',
#   'rouleau'),
#  '11H(MATTHIAS)': ('Matthias (St)',
#   'apôtre',
#   'croix',
#   'hache',
#   'hallebarde',
#   'livre',
#   'rouleau',
#   'épée'),
#  '11H(SIMON)': ('Simon le Zélote (St)', 'apôtre', 'livre', 'rouleau', 'scie'),
#  '42E22': ('cortège funèbre', 'procession'),
#  '46A1241(GOLDEN FLEECE)': ("toison d'or",),
#  '45K': ('guerre', 'guerre de siège'),
#  '73C221': ('commander', 'pain', 'pierre', 'transformation'),
#  '73C222': ('sauter', 'temple', 'être jeté'),
#  '73C223': ('gloire',),
#  '25F23(FOX)': ('renard',),
#  '25H12': ('champ', 'vallée'),
#  '52A23': ('Guardia',
#   'Vigilanza',
#   'Vigilanza per difendersi ...',
#   'vigilance'),
#  '56DD2': ('Ripa', 'Sospitione', 'soupçon'),
#  '11H(NICHOLAS)': ('Bari',
#   'Myre',
#   'Nicolas de Myre (St)',
#   'ancre',
#   'bateau',
#   'boule',
#   'bourse',
#   'cuve',
#   'enfant',
#   'fille',
#   'livre',
#   'trois',
#   'évêque'),
#  '42E31': ('tombe', 'tombeau'),
#  '25M1': ('pyramide', 'Égypte'),
#  '47B13': ('pierre',),
#  '25F(+3)': ('animal',),
#  '25F26(RABBIT)': ('lapin',),
#  '25H119': ('caverne', 'grotte'),
#  '48C162': ('arc', 'archivolte'),
#  '25H154': ('Lichtung im Wald', 'clairière'),
#  '25H156': ('sentier', 'sentier forestier'),
#  '47I214': ('chèvre',),
#  '25F26(HARE)': ('lièvre',),
#  '25F32(FINCH)': ('pinson',),
#  '25F37(SNIPE)': ('bécassine',),
#  '25F38(PARTRIDGE)': ('perdrix',),
#  '25G4(THISTLE)': ('chardon', 'lotus', 'menthe', 'orge'),
#  '34B131': ('cage à oiseaux',),
#  '43C11(+415)': ('chasser', 'occupations humaines'),
#  '43B5': ('plage',),
#  '49M13': ('lettre (caractère)', "type d'impression"),
#  '25F37(STORK)': ('cicogne',),
#  '11F4': ("Madonna (Vierge avec l'Enfant)", 'enfant Jésus'),
#  '73B57': ('adoration',
#   'encens',
#   'myrrhe',
#   'offrir',
#   'or',
#   'présent (cadeau)',
#   'épice'),
#  '46A1252': ('porte-bouclier', 'écuyeur'),
#  '43A433': ('couronner', 'laurier'),
#  '92C4': ('Vénus',),
#  '48A9851': ('banderole', 'rouleau', 'ruban'),
#  '25F35(PARROT)': ('perroquet',),
#  '46C1151': ('panneau de signalisation', 'signe'),
#  '46C13143': ('mule', 'mulet'),
#  '25F716(CRAB)': ('crabe',),
#  '25F716(LOBSTER)': ('homard',),
#  '41C323': ('verre', 'verre à pied (grand)'),
#  '48C741': ('imprimé', 'livre'),
#  '25F24(DEER)(+45)': ('biche',),
#  '25H211': ('source',),
#  '56F1(+4)': ('Desiderio', 'Ripa', 'désir'),
#  '54DD51(+123)': ('Pericolo', 'Ripa', 'danger', 'sécurité'),
#  '23F41': ('hiver',),
#  '25G': ('plante',),
#  '25G31': ('buisson',),
#  '25I152': ('monument', 'statue'),
#  '45C11(SPEAR)': ('lance',),
#  '98B(NERO)': ('Néron', 'empereur'),
#  '41B3': ('lampe', 'lumière'),
#  '24C2': ('Planetenkinder', 'influence', 'lune', 'soleil'),
#  '45C16(CANNON)': ('canon (arme)',),
#  '49E12': ('carte', 'carte stellaire'),
#  '49M43': ('page', 'page de titre'),
#  '92B1': ('Jupiter',),
#  '25F23(LION)(+5246)': ('lion',),
#  '34A11': ('animal domestique', 'dompter'),
#  '45C15(ARROW)': ('flèche',),
#  '45C15(BOW)': ('arc',),
#  '46C131612': ('mors',),
#  '46C131613': ('rênes',),
#  '53C11(+4)': ('Dominio', 'Giurisdittione', 'Ripa', 'puissance'),
#  '92D1511': ('Amor vincit Omnia',
#   'Amour le Conquérant',
#   'Omnia vincit Amor',
#   'triomphe',
#   'vainqueur'),
#  '25G41(HYACINTH)': ('hyacinthe', 'jacinthe'),
#  '71E11732': ('ange',
#   'destruction',
#   'massacre',
#   'premier-né',
#   'tuer (animal)'),
#  '42B742': ('mère', 'mère et enfant'),
#  '33B9': ('fuir', 'poursuivre'),
#  '25C14': ('soufre', 'vapeurs'),
#  '25C11': ('volcan', 'éruption'),
#  '25C15': ('dommage', 'effet', 'tremblement de terre'),
#  '48C7352': ('corne',
#   'cornet à pistons',
#   'souffler',
#   'trombone',
#   'trompette',
#   'tuba'),
#  '5(+1)': ('allégorie',
#   'concept',
#   'idée',
#   'idée abstraite',
#   'personnification'),
#  '59B32': ('Fama', 'Fama buona', 'Fama chiara', 'célébrité', 'renommée'),
#  '29A': ('animal', 'imitation'),
#  '25F32(RAVEN)': ('corbeau',),
#  '25F39(DOVE)': ('colombe',),
#  '25H213(+1)': ('rivière',),
#  '49M41': ('illustration', "livre d'illustration"),
#  '25G41(DAFFODIL)': ('aconit',),
#  '25G41(HOLLYHOCK)': ('aconit',),
#  '25G41(NARCISSUS)': ('narcisse',),
#  '41A711(+2)': ('table',),
#  '71I432': ('Chroniques-2 02-07', 'Rois-1 05-09', 'temple'),
#  '92B1218': ('Europa', 'blanc', 'enlever', 'mer', 'taureau', 'transformation'),
#  '48C1631': ('ordre dorique',),
#  '48C1612': ('chapiteau (architecture)',),
#  '48A9857(OVE)': ('ove',),
#  '51BB5(+113)': ('Contrarietà', 'Ripa', 'contrariété'),
#  '24A6': ('roue', 'visage'),
#  '25G4(IVY)': ('lierre', 'lotus', 'menthe', 'orge'),
#  '54A6': ('aide',),
#  '25D13(TIN)': ('étain',),
#  '25G21(CHERRY)': ('cerise',),
#  '25G21(FIG)': ('figue',),
#  '25G21(MELON)': ('melon',),
#  '25G21(PEACH)': ('pêche (fruit)',),
#  '25G21(PRUNE)': ('mûre',),
#  '41C341': ('plat',),
#  '47I422': ('plante', 'vigne'),
#  '47I4223': ('grappe',),
#  '25I141': ('rue',),
#  '49G81': ('médicament',),
#  '49G82': ('apothicaire', 'droguiste', 'pharmacien'),
#  '45H3(+3)': ('bataille',),
#  '46C232(+21)': ('bateau à rames', "bras d'homme", 'canoë'),
#  '45L42': ('incendier',),
#  '45A141': ('cruauté', 'horreur', 'épouvante'),
#  '45A14': ('effet',),
#  '56BB21': ('Calamità',
#   'Calamità o miseria',
#   'bonheur',
#   'calamité',
#   'désolation'),
#  '56BB22': ('Miseria mondana', 'bonheur', 'chagrin'),
#  '45': ('affaires militaires', 'occupations humaines'),
#  '25F24': ('ongulé',),
#  '41A722': ('divan',),
#  '25H113': ('colline',),
#  '41D2653': ('bord', 'galon (garniture)', 'ruban'),
#  '47C42(+0)': ('attacher', 'lier'),
#  '56F23(+4)': ('Amicitia', 'amitié'),
#  '25A4': ('ville',),
#  '49D36': ('cercle',),
#  '11D3': ('adulte', 'barbe', 'imberbe'),
#  '46A633': ('discuter', 'dispute'),
#  '25F24(STAG)': ('cerf',),
#  '45C15': ('archer',),
#  '48C752': ('jouer de la musique',),
#  '48A9833': ('fleur',),
#  '48A98312': ('vrille',),
#  '45C13(DAGGER)': ('poignard',),
#  '25FF6': ('poisson',),
#  '25FF3': ('oiseau',),
#  '24A81': ('rayon de lumière',),
#  '31A27112': ('courir',),
#  '31A282': ('suivre',),
#  '47K4(+0)': ('filet', 'tricoter'),
#  '42F51': ('servante',),
#  '22C8': ('ombre',),
#  '25A14': ('direction', 'quatre'),
#  '49D321': ('ligne droite',),
#  '23U21': ('cadran solaire',),
#  '33C4': ('rapport sexuel',),
#  '33C8911': ('flagellation', 'fouetter'),
#  '33C893': ('fétichisme',),
#  '44G251': ('menottes',),
#  '23K11': ('janvier',),
#  '41C661(+6)': ('sel',),
#  '47F32': ('boîte', 'conservation', 'mettre en boîte', 'moule'),
#  '11E1': ('colombe', 'flamme'),
#  '11H(PAUL)': ('Paul (St)', 'apôtre', 'livre', 'rouleau', 'épée'),
#  '11P5': ('mission', 'prêcher', 'Évangile', 'évangélisation'),
#  '73F22382': ('dispute', 'prêcher'),
#  '73F422': ('Tite',),
#  '11G191': ('enfant',),
#  '11HH(ELISABETH OF HUNGARY)': ('Franciscains',
#   'Tiers Ordre',
#   'couronne',
#   'cruche',
#   'estropié',
#   'lèpre',
#   'mendiant',
#   'modèle',
#   'pain',
#   'poisson',
#   'reine',
#   'rose',
#   'teigne',
#   'trois',
#   'veuve',
#   'Élisabeth de Hongrie (Ste)',
#   'église'),
#  '41C111': ('donner', 'nourrir', 'nourriture'),
#  '71E12221': ('voyager',),
#  '71E12222': ('poursuivre',),
#  '71H2663': ('fête',),
#  '71H26624': ('guider',),
#  '46C13141(+733)': ('cheval',),
#  '46A1241': ('ordre', 'ordre de chevalerie'),
#  '49D22': ('diagramme', 'pictogramme'),
#  '31A2352': ('siège',),
#  '31A5111': ('admiration', 'beauté', 'contemplation'),
#  '41A7211': ('tabouret',),
#  '47B152(+21)': ('miroitier',),
#  '41A77': ('récipient',),
#  '11H(STEPHEN)': ('diacre', 'encensoir', 'martyr', 'pierre', 'Étienne (St)'),
#  '26D4': ('glace',),
#  '43C24': ('glace', 'hiver', 'neige', "sports d'hiver"),
#  '46C2': ('eaux', 'marine (peinture)'),
#  '33C233': ('embrasser', 'symplegma'),
#  '25H23241': ("Colonnes d'Hercule (les)", 'Hercule', 'colonne'),
#  '92I74911': ('lion', 'lion de Némée'),
#  '48C85431': ('type',),
#  '57A611': ('Lealtà', 'Realtà', 'franchise', 'loyauté'),
#  '82A(KING GARAMENTES)': ('homme',),
#  '25F6': ('poisson',),
#  '41A23': ('chambre', 'chambre à coucher'),
#  '41C74(+1)': ('tabac',),
#  '47D8(AXE)': ('hache',),
#  '73E12': ('bannière', 'dormir', 'peur', 'soldat'),
#  '25F3(+4712)': ('oiseau',),
#  '25F3(+91)': ('oiseau',),
#  '31A533': ('mode', 'styles de coiffure'),
#  '41D2661': ('collier',),
#  '92B5221': ('corbeille', 'coup de foudre', 'fleur', 'temple'),
#  '25F23(ERMINE)(+351)': ('hermine',),
#  '48A98212': ('feuillage', 'tête'),
#  '98B(SCIPIO AFRICANUS MAJOR)51': ('Allucius',
#   'agenouiller',
#   'cadeau de mariage',
#   'captif',
#   'continence',
#   'devant',
#   'jeune marié',
#   'marié',
#   'rançon',
#   'relâcher',
#   'rendre',
#   'renoncer à'),
#  '25H1123': ('formation des roches',),
#  '46B451': ('dette', 'débit'),
#  '48A98313': ('Astwerk', 'branche'),
#  '25F711(LADYBIRD)': ('coccinelle', 'libellule', 'poux', 'puce'),
#  '25F23(WOLF)': ('loup',),
#  '31D160': ('Ripa', 'Senectus', 'Vecchiezza', 'Vieillesse'),
#  '25F36(GOOSE)': ('oie',),
#  '41B34': ('lampe à huile',),
#  '25F22': ('singe',),
#  '25H224': ('fossé',),
#  '41A16': ('maison', 'maison rurale'),
#  '41C714': ('ale', 'bière (boisson)'),
#  '46B': ('affaires',
#   'commerce',
#   'finance',
#   'occupations humaines',
#   'économie'),
#  '25G11': ('arbre', 'groupe'),
#  '25H17': ('herbe', 'prairie', 'pré'),
#  '44B113': ('roi',),
#  '31A25193': ('estomac', 'poitrine', 'robe'),
#  '41A721': ('chaise',),
#  '41B23(+0)': ('chaufferette', 'chaufferette pour les pieds'),
#  '41C317': ('refroidir', 'seau à rafraîchir'),
#  '41C7111': ('verre',),
#  '11D32': ('type',),
#  '11I42': ('bête', "bêtes de l'Apocalypse", 'quatre', 'symbole'),
#  '35': ('Arcadie', 'berger', 'pastorale'),
#  '73F3563': ('lapider', 'vêtements'),
#  '25H15(+1)': ('arbre', 'forêt'),
#  '47I2111': ('taureau',),
#  '23E41': ('hiver',),
#  '25H221': ('écluse',),
#  '45D311': ('commandant', 'général', 'maréchal'),
#  '31E23431': ('fouetter',),
#  '25F': ('animal',),
#  '11G184': ('Gabriel',),
#  '73A523': ('agenouiller',),
#  '41C22(+0)': ('occupations humaines',
#   'personnel',
#   'personnel de cuisine',
#   'serviteur'),
#  '41C2543': ('four',),
#  '41C264': ('battre', 'lisser'),
#  '41C312(+0)': ('fourchette',),
#  '41C621': ('pain',),
#  '47B1811(+11)': ('boulanger',),
#  '47B1811(+21)': ('boulanger',),
#  '47D8(KNIFE)': ('couteau',),
#  '92C321': ('Endymion', 'Lune', 'amoureux', 'dormir'),
#  '48A9854': ('vase',),
#  '41D225': ('gant', 'mitaine'),
#  '45C21': ('uniforme',),
#  '45F6': ('adresser', 'chef', 'général'),
#  '25I2': ('village',),
#  '12A7': ('Juif', 'cérémonie', 'rite'),
#  '46E231': ('emballer', 'envoyer'),
#  '11I62(MOSES)': ('Moïse',
#   'Tables de la Loi',
#   'baguette',
#   'corne',
#   'rayon de lumière'),
#  '73E5': ('Actes 02',
#   'Marie (Vierge)',
#   'Pentecôte',
#   'Saint-Esprit',
#   'descendre',
#   'nation'),
#  '73D71': ("Joseph d'Arimathie (St)",
#   'Nicodème',
#   'croix',
#   'descente de croix',
#   'échelle'),
#  '71F64': ('Booz', 'Ruth 02', 'champ'),
#  '71F642': ('interrogation', 'serviteur'),
#  '31B71': ('génie',),
#  '61B11': ('enfant', 'femme', 'homme', 'portrait'),
#  '21D': ('eau',),
#  '31A2321': ('en avant',),
#  '31A244(+51)': ('courber', 'en avant', 'incliner'),
#  '31A2511(+933)': ('bras levé', 'vers le haut'),
#  '31A2512': ('bras étendu', 'en avant'),
#  '31A5462': ('brosse', 'éponge'),
#  '31A5463': ('tissu',),
#  '31AA54': ('baigner', 'laver'),
#  '31B6212': ('en bas',),
#  '31D14(+73)': ('adulte', 'homme'),
#  '32B31(+51)': ('blanc',),
#  '32B321(ETHIOPIAN)(+51)': ('Bantous',),
#  '32B321(MOOR)': ('Bantous',),
#  '41A2415': ('broc', 'cruche', 'cuvette'),
#  '41A54': ('barrière', 'enclos', 'mur', 'palissades'),
#  '41D231(+81)': ('pantalon',),
#  '41D233(+81)': ('chausette', 'chaussure', 'jambe'),
#  '11R5': ('Fragilità humana',
#   'Fugacità delle grandezze & ...',
#   'Meditatione della morte',
#   'Memento mori',
#   'Mort',
#   'Opera vana',
#   'Piacere vano',
#   'Ripa',
#   'Vana gloria',
#   'Vanitas',
#   'Vanità',
#   'fragilité',
#   'méditer',
#   'personnification',
#   'vanité'),
#  '52BB42(+4)': ('impossibilité', 'vérification'),
#  '25G3(+351)': ('arbre',),
#  '31A2245(+939)': ('main',),
#  '48A983': ('plante',),
#  '49L73': ('banderole',),
#  '49L8': ('inscription',),
#  '25I12': ('panorama', 'silhouette'),
#  '25F24(BOAR)': ('sanglier',),
#  '25F35(PEACOCK)': ('paon',),
#  '25G22(ASPARAGUS)': ('asperge',),
#  '25G4(ARTICHOKE)': ('artichaut', 'lotus', 'menthe', 'orge'),
#  '41A3211': ('porte ouverte',),
#  '41A33': ('fausse fenêtre', 'fenêtre', "illusion d'optique"),
#  '41C3212': ('conque', 'nautile'),
#  '41C622': ('gâteau', 'pâtisserie', 'tarte'),
#  '11C15': ('rayon de lumière',),
#  '11G1926': ('arme',),
#  '22C32': ('ciel', 'rayon de lumière'),
#  '25G3(LAUREL)(+22)': ('laurier',),
#  '31A25551': ('vers le haut',),
#  '31G1': ('vie',),
#  '41A361': ('tour',),
#  '46C1215': ('porter sur les épaules', 'tête'),
#  '49N21': ('lutrin',),
#  '56F2(+1331)': ('Amore (secondo Seneca)', 'Amour', 'Ripa'),
#  '57A75(+4)': ('Compassione', 'Misericordia', 'miséricorde', 'pitié'),
#  '57B11(+4)': ('bon', 'récompenser'),
#  '25H2': ('eaux', "paysage avec étendues d'eau"),
#  '49D': ('mathématiques',),
#  '48A9879': ('Laub- und Bandelwerk',),
#  '41A646': ('vase',),
#  '44B155': ('vie quotidienne',),
#  '41A652': ('étang',),
#  '11F3': ('groupe',),
#  '11H(...)0': ('groupe',),
#  '11H(ALL SAINTS)': ('Toussaint',),
#  '11H(STEPHEN)0': ('groupe',),
#  '11HH(...)0': ('groupe',),
#  '11HH(CATHERINE)0': ('groupe',),
#  '11P3113': ('archevêque', 'évêque'),
#  '31A4632': ('infection', 'plaie'),
#  '25F23(TIGER)': ('tigre',),
#  '44B112': ('empereur', 'tsar'),
#  '42E213': ('commémoration', 'médaille'),
#  '98B(GORDIAN)9': ('portrait',),
#  '48C852': ('acteur', 'actrice', 'groupe', 'troupe'),
#  '48A712': ('audience',),
#  '48C8133': ('rideau',),
#  '41D3': ('costume', 'folklore'),
#  '31A2245(+933)': ('main',),
#  '53DD2(+4)': ('manque de parole', 'promettre', 'volonté interindividuel'),
#  '57A4(+4)': ('honte',),
#  '46C23221': ('galère',),
#  '48C2': ('sculpture',),
#  '43C1(+4241)': ('animal', 'exercice', 'jeux', 'sport'),
#  '23R113': ('midi',),
#  '25G3(+34)': ('arbre',),
#  '51GG1': ('matière', 'petit'),
#  '57A641': ('Discretione', 'Modestia', 'discrétion', 'modestie'),
#  '71E12541': ('corbeille', 'pot', 'ramasser'),
#  '73D24': ('Jean 13', 'Luc 22', 'Marc 14', 'Matthieu 26'),
#  '25F42(VIPER)(+22)': ('vipère',),
#  '25F42(VIPER)(+23)': ('vipère',),
#  '25F42(VIPER)(+5251)': ('vipère',),
#  '25F42(VIPER)(+432)': ('vipère',),
#  '25F42(VIPER)(+47)': ('vipère',),
#  '25F42(VIPER)(+63)': ('vipère',),
#  '25I3': ('ferme', 'maison'),
#  '31A2352(+55)': ('siège',),
#  '31AA2352(+55)': ('siège',),
#  '41D211(+81)': ('robe',),
#  '41D2339': ('pieds nus',),
#  '54AA42(+4)': ('calme',
#   'imperturbabilité',
#   'indompté',
#   'sauvagerie',
#   'équanimité'),
#  '58AA1(+4)': ('destruction',),
#  '41B162': ('fumée',),
#  '43C4211': ('oiseau', 'perche', 'tir au pigeon'),
#  '61B2(JACOBA VAN BEIEREN, gravin van Holland)21': ('vie',),
#  '11Q651': ('croix', 'crucifix'),
#  '31A25161': ('poitrine',),
#  '48B3': ('autoportrait', 'portrait'),
#  '11H(JOHN)12': ('Évangile', 'écrire'),
#  '48A2': ('critiquer', 'discuter'),
#  '480': ('Arte', 'Ripa', 'allégorie', 'emblème', 'symbole'),
#  '41A6711': ('bouquet', 'vase'),
#  '25G41(IRIS)': ('aconit',),
#  '25G41(MORNING GLORY)': ('aconit',),
#  '25G21(APPLE)': ('pomme',),
#  '31A2361(+52)': ('dos',),
#  '31A2544(+918)': ('tête',),
#  '31B181': ("s'évanouir",),
#  '54AA7(+4)': ('Infermità', 'Ripa', 'impuissance'),
#  '57A77(+4)': ('Affabilità, piacevolezza, amabilità',
#   'Animo piacevole, trattabile & amorevole',
#   'Benignità',
#   'affabilité',
#   'amabilité',
#   'gentillesse'),
#  '44B1311': ('jurer', 'loyauté', 'serment'),
#  '46A124': ('chevalier',),
#  '82A(JOFFRIT VON BRABANT)': ('homme',),
#  '82A(WILHELM VON ORLENS)': ('homme',),
#  '11S6': ('bienheureux (les)',),
#  '41D2': ('costume', 'vêtements'),
#  '46A14': ('fermier', 'fermière'),
#  '31D15(+2)': ('adulte', 'femme'),
#  '25G21(MEDLAR)': ('nèfle',),
#  '25G21(ORANGE)': ('orange',),
#  '48C33(+631)': ("oeuvre d'art",),
#  '26C125': ('Notus', 'vent du sud'),
#  '26C32': ('tempête sur mer',),
#  '31A(+72)': ('Corpo humano',
#   'Ripa',
#   'corps',
#   'femme',
#   'figure humaine',
#   'homme',
#   'nu'),
#  '31B6(+922)': ('expression',),
#  '41B4': ('brûler', 'feu'),
#  '45D323': ('marin',),
#  '46C215(MAST)': ('cabestan', 'guindeau'),
#  '46C291': ('naufrage',),
#  '44B6': ('bien et mal',),
#  '44C': ('citoyen', 'droits', 'droits civiques'),
#  '45L43': ('ruine',),
#  '46A180': ('Ripa', 'Servitù'),
#  '54E31': ('Concordia',
#   'Concordia di Pace',
#   'Concordia insuperabile',
#   'Concordia militare',
#   'Ripa',
#   'Unione civile',
#   'traité',
#   'unité'),
#  '25F33(EAGLE)': ('aigle',),
#  '25F37(HERON)': ('héron',),
#  '47I1111': ('épi de blé',),
#  '25F24(HIND)': ('renne',),
#  '49M123': ('imprimeur',),
#  '49L11': ('écrire', 'écriture'),
#  '49M1': ('imprimer',),
#  '11M41': ('Prudence', 'Prudentia', 'Prudenza', 'Ripa'),
#  '54BB3': ('Nocumento',
#   "Nocumento d'ogni cosa",
#   'Ripa',
#   'inutilité',
#   'nocivité'),
#  '41A191': ('tente',),
#  '46B355': ('carte', 'marque', 'signe'),
#  '11H(CHRISTOPHER)51': ('bâton',
#   'chapelle',
#   'eaux',
#   'ermite',
#   'lanterne',
#   'palmier',
#   'patauger',
#   'porter',
#   'porter sur les épaules',
#   'rive'),
#  '71E43': ('Deutéronome 31', 'Loi (biblique)', 'vieillard', 'écrire'),
#  '25F711(+4813)': ('insecte',),
#  '25F711(CATERPILLAR)': ('chenille', 'libellule', 'poux', 'puce'),
#  '11L13': ('Legge nuova', 'Loi (biblique)', 'Nouveau Testament', 'Ripa'),
#  '11L53': ('théologien',),
#  '11L6': ('livre', 'traité'),
#  '73C6113': ('eau', 'jarre', 'six'),
#  '11A3': ('colère',),
#  '25F(+547)': ('animal',),
#  '25F42(+521)': ('serpent',),
#  '25G3(OLIVE-TREE)(+22)': ('olivier',),
#  '26E2': ('foudre', 'électricité'),
#  '31A2531(+9161)': ('courber',),
#  '31A2741': ('jetter',),
#  '31A2762': ("voler (dans l'air)",),
#  '31AA233': ('agenouiller',),
#  '31AA27321': ('tomber', 'trébucher'),
#  '31B6211': ('vers le haut',),
#  '42E321': ('caverne', 'grotte', 'rocher', 'tombe'),
#  '52DD1(+4)': ('Ripa',
#   'Secretezza',
#   'cacher',
#   'clandestinité',
#   'communication de la pensée',
#   'parler',
#   'pensée',
#   'qualité'),
#  '54D5(+4)': ('sécurité',),
#  '49L26': ('ars memorandi', 'mnémotechnique', 'mémoire'),
#  '46A32': ('soin', 'vieillesse'),
#  '11HH(URSULA)34': ('ange', 'songe', 'vision'),
#  '49G91': ('charlatan', 'marché', 'saltimbanco', 'saltimbanque'),
#  '48C5151': ('chevalet',),
#  '23O41': ('Balance', 'Libra', 'septembre'),
#  '73C422': ('Luc 05', 'Marc 02', 'Matthieu 09', 'coucher', 'lit', 'prêcher'),
#  '73C4223': ('marcher',),
#  '73C7115': ('Luc 05',
#   'Marc 02',
#   'Matthieu (St)',
#   'Matthieu 09',
#   'argent',
#   "collecteur d'impôts",
#   'payer'),
#  '73C851': ('Luc 12', 'avare', 'fou', 'richesse', 'sauver'),
#  '92D427': ('Polinnia', 'Polymnie'),
#  '25A13': ('globe',),
#  '48C7321': ('cithare', 'lyre', 'psaltérion'),
#  '44D4': ('fonctionnaire', 'homme politique', 'officiel'),
#  '49D511': ('instrument', 'instruments pour tracer'),
#  '31A71': ('mâle',),
#  '41A3212': ('porte ouverte', 'porte à vantaux'),
#  '47I21111': ('boeuf',),
#  '47I2271': ('bergerie',),
#  '73B25': ('berger',),
#  '73B8': ('Sainte Famille',),
#  '25H131': ('rocher',),
#  '45D22(+32)': ('marine',),
#  '31A214': ('bras',),
#  '31A2141': ('humérus',),
#  '31A2142': ('cubitus', 'radius'),
#  '61B2(SANAZZARO, JACOPO)2(+1)(+513)': ('scène',),
#  '25I145': ('canal',),
#  '23U11': ('perpétuité',),
#  '24B6': ('clair de la lune', 'lumière'),
#  '25G3(+33)': ('arbre',),
#  '41A771': ('bidon',
#   'boîte',
#   'boîte métallique',
#   'moule',
#   'métal',
#   'seau',
#   'vase'),
#  '41B23': ('chaufferette', 'chaufferette pour les pieds'),
#  '41C74': ('tabac',),
#  '41D2321': ('tablier',),
#  '48C7312': ('alto', 'basse de viole', 'contrebasse', 'violoncelle'),
#  '48C735': ('instrument à vent',),
#  '48C7351': ('aulos', 'flûte', 'tibia'),
#  '48C755': ('chanter', 'jouer de la musique'),
#  '85': ('fable',),
#  '11G': ('ange',),
#  '47I2223': ('abreuvoir',),
#  '73B13(+31)': ('Nativité',),
#  '48A986': ('fantaisie',),
#  '25G41(ROSA)': ('aconit',),
#  '43C1145': ('hallali',),
#  '73G571': ('Christ',
#   'Jérusalem céleste',
#   'agneau',
#   'ange',
#   'berger',
#   'mener',
#   'montrer'),
#  '25F3(+53)': ('oiseau',),
#  '31D112(+89)': ('enfant',),
#  '41A141': ('rangée', 'rue'),
#  '41D232(+82)': ('jupe',),
#  '42A3': ('enfant', 'mère', 'mère et enfant'),
#  '42B29': ('tuer',),
#  '94A74(+0)': ('aile',
#   'char',
#   'dragon',
#   'enfant',
#   'fuir',
#   'mère',
#   'mère et enfant',
#   'tuer'),
#  '55C11(+4)': ('Prodigalità', 'Ripa', 'dilapider'),
#  '56D29(+4)': ('Pax Falsa',
#   'Ripa',
#   'Speranza fallace',
#   'crédulité',
#   'fausse confiance'),
#  '31A311': ('lunettes', 'verre'),
#  '31A5339': ('chauve',),
#  '44A51(FRANCE)': ('Espagne',),
#  '48C85441': ('tableau vivant',),
#  '73B692': ('Nazareth', 'arrivée'),
#  ...}

# %%
with open(f'../data/fabritius/json/fr.json', 'r', encoding='utf8') as json_file:
    instances = json.load(json_file)

fabritius = []
for record_id, iconography in list(instances.items())[:1000]:
    for dict_ in iconography:
        for top_term, sub_terms in dict_.items():
            tt =  [top_term]
            if sub_terms:
                for sub_term in sub_terms:
                    fabritius.append(tt + sub_term)
            else:
                fabritius.append(tt)

fabritius
# Out:
# [['effet de ligne'],
#  ['figure', 'homme'],
#  ['figure', 'barbe'],
#  ['groupe de figures', 'chapeau', 'homme'],
#  ['groupe de figures', 'assis', 'femme'],
#  ['groupe de figures', 'pinceau'],
#  ['intérieur', 'atelier'],
#  ['intérieur', 'chevalet'],
#  ['intérieur', 'tableau'],
#  ['intérieur', 'toile'],
#  ['intérieur', 'table'],
#  ['intérieur', 'livre'],
#  ['intérieur', 'fleur'],
#  ['figure', 'en buste', 'femme'],
#  ['figure', 'de profil'],
#  ['figure', 'en pied', 'homme', 'nu'],
#  ['figure', 'joint', 'main'],
#  ['intérieur', 'ouvert', 'porte'],
#  ['effet de ligne'],
#  ['groupe de figures', 'homme'],
#  ['groupe de figures', 'femme'],
#  ['groupe de figures', 'foule'],
#  ['groupe de figures', 'soldat'],
#  ['groupe de figures', 'casque'],
#  ['groupe de figures', 'arme', 'lance'],
#  ['groupe de figures', 'animal', 'cheval', 'chien'],
#  ['groupe de figures', 'coiffure'],
#  ['groupe de figures', 'couronne', 'épine'],
#  ['groupe de figures', 'nu'],
#  ['abstrait'],
#  ['effet de ligne'],
#  ['figure', 'en pied', 'femme'],
#  ['figure', 'de profil'],
#  ['figure', 'robe', 'vêtement'],
#  ['figure', 'noeud'],
#  ['figure', 'chapeau'],
#  ['figure', 'animal', 'chien'],
#  ['mer'],
#  ['plage'],
#  ['nuage'],
#  ['bateau'],
#  ['figure', 'assis', 'femme'],
#  ['figure', 'nu'],
#  ['figure', 'miroir'],
#  ['géométrie'],
#  ['figure', 'femme', 'à mi-corps'],
#  ['figure', 'couvre-chef'],
#  ['figure', 'parure'],
#  ['figure', 'vêtement'],
#  ['figure', 'harnachement'],
#  ['figure', 'homme'],
#  ['figure', 'habit', 'veste'],
#  ['figure', 'livre'],
#  ['figure', 'pinceau'],
#  ['groupe de figures', 'jeune fille'],
#  ['groupe de figures', 'enfant', 'fillette'],
#  ['groupe de figures', 'coiffe'],
#  ['groupe de figures', 'vêtement'],
#  ['groupe de figures', 'chapelet'],
#  ['groupe de figures', 'gonfanon'],
#  ['<UNK>', 'intérieur', 'église'],
#  ['<UNK>', 'chandelle'],
#  ['figure', 'homme', 'tête'],
#  ['figure', 'homme', 'nu'],
#  ['figure', 'en pied'],
#  ['figure', 'sans tête'],
#  ['figure', 'sans jambe'],
#  ['figure', 'muscle'],
#  ['figure', 'enfant', 'garçon'],
#  ['figure', 'nu'],
#  ['figure', 'sans pied'],
#  ['bras'],
#  ['muscle'],
#  ['jambe'],
#  ['pied'],
#  ['pied'],
#  ['main'],
#  ['outil'],
#  ['figure', 'en buste', 'femme'],
#  ['figure', 'de profil'],
#  ['paysage', 'village'],
#  ['paysage', 'maison'],
#  ['paysage', 'arbre'],
#  ['figure', 'homme', 'à mi-corps'],
#  ['groupe de figures', 'homme'],
#  ['groupe de figures', 'femme'],
#  ['groupe de figures', 'vêtement'],
#  ['groupe de figures', 'chapeau', 'couvre-chef'],
#  ['groupe de figures', 'bonnet'],
#  ['groupe de figures', 'costume religieux', 'mitre'],
#  ['groupe de figures', 'aube'],
#  ['groupe de figures', 'chape'],
#  ['groupe de figures', 'gant'],
#  ['groupe de figures', 'coiffure'],
#  ['fond de paysage', 'colline'],
#  ['fond de paysage', 'arbre'],
#  ['fond de paysage', 'soleil'],
#  ['représentation animalière', 'animal', 'chien'],
#  ['miroir'],
#  ['gant'],
#  ['canne'],
#  ['figure', 'assis', 'femme'],
#  ['figure', 'robe', 'vêtement'],
#  ['figure', 'tissu'],
#  ['figure', 'bijou'],
#  ['intérieur'],
#  ['fauteuil'],
#  ['coussin'],
#  ['chaise'],
#  ['<UNK>', 'port'],
#  ['<UNK>', 'quai'],
#  ['<UNK>', 'bateau', 'bateau à voiles'],
#  ['paysage', 'pont'],
#  ['paysage', 'rocher'],
#  ['paysage', 'arbre'],
#  ['paysage', 'rive'],
#  ['groupe de figures', 'auréole', 'homme'],
#  ['groupe de figures', 'dans les airs'],
#  ['groupe de figures', 'femme'],
#  ['groupe de figures', 'animal', 'hybride'],
#  ['groupe de figures', 'être imaginaire'],
#  ['groupe de figures', 'oiseau'],
#  ['groupe de figures', 'tête'],
#  ['groupe de figures', 'arbre'],
#  ['<UNK>', 'arbre', 'tronc'],
#  ['<UNK>', 'colline'],
#  ['<UNK>', 'incendie'],
#  ['<UNK>', 'croix'],
#  ['<UNK>', 'livre'],
#  ['groupe de figures', 'homme', 'vieux'],
#  ['groupe de figures', 'communication par le geste'],
#  ['groupe de figures', 'livre'],
#  ['groupe de figures', 'petite cloche'],
#  ['groupe de figures', 'femme'],
#  ['groupe de figures', 'cavalier'],
#  ['groupe de figures', 'animal', 'hybride'],
#  ['groupe de figures', 'être imaginaire'],
#  ['groupe de figures', 'dans les airs'],
#  ['groupe de figures', 'faucon', 'oiseau'],
#  ['groupe de figures', 'cheval'],
#  ['groupe de figures', 'porc'],
#  ['<UNK>', 'instrument de musique', 'luth'],
#  ['<UNK>', 'cornet à bouquin'],
#  ['<UNK>', 'cornemuse'],
#  ['<UNK>', 'arme', 'épée'],
#  ['<UNK>', 'flèche'],
#  ['<UNK>', 'arc'],
#  ['<UNK>', 'couteau'],
#  ['<UNK>', 'bateau'],
#  ['<UNK>', 'bâtiment', 'incendie'],
#  ['<UNK>', 'ruine'],
#  ['<UNK>', 'eau'],
#  ['<UNK>', 'air'],
#  ['<UNK>', 'feu'],
#  ['architecture', 'intérieur', 'église'],
#  ['architecture', 'voûte'],
#  ['architecture', 'colonne'],
#  ['architecture', 'vitrail'],
#  ['architecture', 'chapelle'],
#  ['architecture', 'jubé'],
#  ['architecture', 'pavement'],
#  ['architecture', 'autel', 'mobilier religieux'],
#  ['architecture', 'chaire à prêcher'],
#  ['architecture', 'retable'],
#  ['architecture', 'instrument de musique', 'orgue'],
#  ['groupe de figures', 'homme', 'prêtre'],
#  ['groupe de figures', 'femme'],
#  ['groupe de figures', 'enfant'],
#  ['groupe de figures', 'fidèles'],
#  ['groupe de figures', 'vêtement'],
#  ['animal : chien'],
#  ['bijou'],
#  ['figure', 'assis', 'homme'],
#  ['figure', 'en appui'],
#  ['figure', 'vêtement'],
#  ['figure', 'assis', 'homme'],
#  ['figure', 'voile', 'vêtement'],
#  ['groupe de figures', 'homme', 'mort'],
#  ['groupe de figures', 'religieux'],
#  ['groupe de figures', 'couvre-chef', 'tiare'],
#  ['groupe de figures', 'costume religieux', 'vêtement'],
#  ['groupe de figures', 'gonfanon'],
#  ['groupe de figures', 'femme'],
#  ['groupe de figures', 'enfant', 'nourrisson'],
#  ['groupe de figures', 'cercueil'],
#  ['groupe de figures', 'tombeau'],
#  ['groupe de figures', 'aile', 'être imaginaire'],
#  ['groupe de figures', 'croix'],
#  ['groupe de figures', 'épée'],
#  ['architecture', 'colonne'],
#  ['architecture', 'pont'],
#  ['architecture', 'pavement'],
#  ['architecture', 'escalier'],
#  ['fond de paysage', 'bateau'],
#  ['fond de paysage', 'animal', 'poisson'],
#  ['fond de paysage', 'rive'],
#  ['fond de paysage', 'bord de mer'],
#  ['scène', 'naufrage'],
#  ['scène', 'procession'],
#  ['groupe de figures', 'femme', 'nu'],
#  ['groupe de figures', 'fleur'],
#  ['groupe de figures', 'coiffure'],
#  ['groupe de figures', 'bijou'],
#  ['groupe de figures', 'agenouillé', 'homme'],
#  ['groupe de figures', 'crâne'],
#  ['groupe de figures', 'livre'],
#  ['groupe de figures', 'animal', 'hibou'],
#  ['marine', 'bateau', 'bateau à voiles'],
#  ['marine', 'petit voilier'],
#  ['marine', 'mer'],
#  ['figure', 'en pied', 'homme'],
#  ['figure', 'chaussure'],
#  ['figure', 'marteau', 'outil'],
#  ['figure', "tête d'animal"],
#  ['figure', 'assis', 'homme'],
#  ['figure', 'communication par le geste'],
#  ['figure', 'de profil', 'homme', 'tête'],
#  ['groupe de figures', 'en pied', 'homme'],
#  ['groupe de figures', 'assise', 'femme'],
#  ['groupe de figures', 'travail'],
#  ['groupe de figures', 'filet'],
#  ['paysage', 'colline'],
#  ['paysage', 'eau'],
#  ['paysage', 'rive'],
#  ['paysage', 'barque', 'bateau'],
#  ['paysage', 'pannier'],
#  ['figure', 'en buste', 'homme'],
#  ['figure', 'homme', 'nu'],
#  ['figure', 'assis'],
#  ['figure', 'homme', 'tête'],
#  ['figure', 'barbe'],
#  ['figure', 'en buste', 'homme'],
#  ['figure', 'moustache'],
#  ['figure', 'toge', 'vêtement'],
#  ['figure', 'en buste', 'homme'],
#  ['figure', 'couvre-chef'],
#  ['figure', 'hache', 'outil'],
#  ['figure', 'en buste', 'enfant'],
#  ['figure', 'en buste', 'femme'],
#  ['figure', 'homme', 'tête'],
#  ['figure', 'moustache'],
#  ['figure', 'homme', 'tête'],
#  ['figure', 'de profil'],
#  ['figure', 'en buste', 'homme'],
#  ['figure', 'moustache'],
#  ['figure', 'homme', 'tête'],
#  ['figure', 'barbe'],
#  ['marine', 'eau', 'mer'],
#  ['marine', 'bateau', 'bateau à voiles\xad'],
#  ['marine', 'arbre'],
#  ['marine', 'ciel', 'nuage'],
#  ['marine', 'ville'],
#  ['figure', 'en pied', 'homme'],
#  ['figure', 'assis', 'homme'],
#  ['figure', 'de profil'],
#  ['figure', 'bâton'],
#  ['figure', 'arbre'],
#  ['groupe de figures', 'ouvrier'],
#  ['bâtiment', 'voûte'],
#  ['bâtiment', 'machine'],
#  ['groupe de figures', 'foule', 'homme'],
#  ['groupe de figures', 'arme'],
#  ['groupe de figures', 'animal', 'cheval'],
#  ['groupe de figures', 'croix'],
#  ['groupe de figures', 'drapeau'],
#  ['figure', 'homme'],
#  ['groupe', 'couché', 'homme'],
#  ['groupe', 'nu'],
#  ['groupe', 'femme'],
#  ['groupe', 'couronne', 'épine'],
#  ['figure', 'homme', 'à mi-corps'],
#  ['figure', 'de profil'],
#  ['figure', 'couvre-chef'],
#  ['figure', 'houe', 'outil'],
#  ['<UNK>', 'cheminée'],
#  ['<UNK>', 'fumée'],
#  ['<UNK>', 'bâtiment', 'toit'],
#  ['groupe de figures', 'homme'],
#  ['groupe de figures', 'femme'],
#  ['groupe de figures', 'enfant'],
#  ['groupe de figures', 'échelle'],
#  ['paysage', 'eau', 'mer'],
#  ['paysage', 'montagne'],
#  ['paysage', 'falaise'],
#  ['paysage', 'ville'],
#  ['paysage', 'bâtiment'],
#  ['figure', 'en pied', 'homme'],
#  ['figure', 'arme', 'épée'],
#  ['figure', 'bouclier'],
#  ['figure', 'casque'],
#  ['figure', 'cuirasse'],
#  ['groupe de figures', 'homme'],
#  ['architecture', 'usine'],
#  ['architecture', 'fourneau'],
#  ['groupe de figures', 'ouvrier'],
#  ['groupe de figures', 'outil', 'pince'],
#  ['groupe de figures', 'machine'],
#  ['figure', 'assis', 'homme'],
#  ['figure', 'couvre-chef'],
#  ['fourneau'],
#  ['figure', 'agenouillé', 'homme'],
#  ['figure', 'joint', 'main'],
#  ['figure', 'chandelle'],
#  ['figure', 'autel'],
#  ['groupe de figures', 'en pied', 'femme'],
#  ['groupe de figures', 'homme'],
#  ['groupe de figures', 'combat'],
#  ['groupe de figures', 'flamme'],
#  ['intérieur', 'tabouret'],
#  ['groupe de figures', 'foule'],
#  ['groupe de figures', 'homme'],
#  ['groupe de figures', 'femme'],
#  ['groupe de figures', 'enfant'],
#  ['groupe de figures', 'local', 'vêtement'],
#  ['groupe de figures', 'couvre-chef'],
#  ['groupe de figures', 'coiffure'],
#  ['groupe de figures', 'coiffe'],
#  ['groupe de figures', 'fleur'],
#  ['groupe de figures', 'panier'],
#  ['groupe de figures', 'croix'],
#  ['architecture', 'église'],
#  ['architecture', 'façade'],
#  ['groupe de figures', 'homme', 'religieux'],
#  ['groupe de figures', 'femme'],
#  ['groupe de figures', 'costume religieux', 'vêtement'],
#  ['paysage', 'dune'],
#  ['paysage', 'mer'],
#  ['groupe de figures', 'homme', 'soldat'],
#  ['groupe de figures', 'assis'],
#  ['groupe de figures', 'femme'],
#  ['groupe de figures', 'enfant', 'nourrisson'],
#  ['groupe de figures', 'animal', 'cheval'],
#  ['groupe de figures', 'chien'],
#  ['groupe de figures', 'uniforme'],
#  ['groupe de figures', 'armure', 'casque'],
#  ['groupe de figures', 'plume'],
#  ['groupe de figures', 'chaumière'],
#  ['groupe de figures', 'seau'],
#  ['groupe de figures', 'panier'],
#  ['groupe de figures', 'hache'],
#  ['groupe de figures', 'échelle'],
#  ['groupe de figures', 'pot'],
#  ['groupe de figures', 'palissade'],
#  ['groupe de figures', 'mare'],
#  ['groupe de figures', 'arbre'],
#  ['groupe de figures', 'plante'],
#  ['groupe de figures', 'homme'],
#  ['groupe de figures', 'femme'],
#  ['groupe de figures', 'enfant', 'nourrisson'],
#  ['groupe de figures', 'habit', 'vêtement'],
#  ['groupe de figures', 'col', 'dentelle'],
#  ['groupe de figures', 'coiffe', 'couvre-chef'],
#  ['groupe de figures', 'aliment', 'fruit', 'raisin'],
#  ['groupe de figures', 'moustache'],
#  ['groupe de figures', 'toile'],
#  ['groupe de figures', 'statue'],
#  ['figure', 'assis', 'femme'],
#  ['figure', 'lettre'],
#  ['figure', 'arbre', 'chêne'],
#  ['figure', 'montagne'],
#  ['figure', 'homme', 'à mi-corps'],
#  ['figure', 'armure', 'vêtement'],
#  ['figure', 'casque', 'couvre-chef'],
#  ['figure', 'bijou'],
#  ['figure', 'moustache'],
#  ['figure', 'en pied', 'homme'],
#  ['figure', 'habit', 'vêtement'],
#  ['figure', 'manteau'],
#  ['figure', 'tissu'],
#  ['figure', 'croix'],
#  ['figure', 'botte', 'chaussure'],
#  ['figure', 'épée'],
#  ['figure', 'étui'],
#  ['figure', 'figure', 'noir'],
#  ['figure', 'fortification', 'plan'],
#  ['figure', 'chaise'],
#  ['figure', 'rideau'],
#  ['figure', 'tente'],
#  ['groupe de figures', 'homme'],
#  ['groupe de figures', 'femme'],
#  ['groupe de figures', 'en pied', 'enfant'],
#  ['groupe de figures', 'chapeau', 'couvre-chef'],
#  ['groupe de figures', 'coiffe'],
#  ['groupe de figures', 'bâton'],
#  ['groupe de figures', 'bateau', 'bateau à rames'],
#  ['fond de paysage', 'eau'],
#  ['fond de paysage', 'arbre'],
#  ['fond de paysage', 'buisson'],
#  ['fond de paysage', 'plante aquatique', 'roseau'],
#  ['fond de paysage', 'bâtiment', 'maison'],
#  ['fond de paysage', 'moulin à eau'],
#  ['fond de paysage', 'lune'],
#  ['groupe de figures', 'homme'],
#  ['groupe de figures', 'en pied', 'femme'],
#  ['groupe de figures', 'casque', 'couvre-chef'],
#  ['groupe de figures', 'coiffure'],
#  ['groupe de figures', 'arme', 'lance'],
#  ['groupe de figures', 'arc'],
#  ['groupe de figures', 'barbe'],
#  ['groupe de figures', 'animal', 'chien'],
#  ['groupe de figures', 'arbre'],
#  ['figure', 'homme', 'à mi-corps'],
#  ['figure', 'habit', 'vêtement'],
#  ['figure', 'feuillet'],
#  ['figure', 'homme', 'à mi-corps'],
#  ['figure', 'habit', 'vêtement'],
#  ['figure', 'livre'],
#  ['figure', 'feuillet'],
#  ['figure', 'assis', 'femme'],
#  ['figure', 'de profil'],
#  ['figure', 'coiffe', 'couvre-chef'],
#  ['fond de paysage', 'champ'],
#  ['fond de paysage', 'colline'],
#  ['fond de paysage', 'arbre'],
#  ['fond de paysage', 'buisson'],
#  ['fond de paysage', 'animal', 'vache'],
#  ['fond de paysage', 'chèvre'],
#  ['fond de paysage', 'mouton'],
#  ['fond de paysage', 'oiseau'],
#  ['groupe de figures', 'homme'],
#  ['groupe de figures', 'port'],
#  ['groupe de figures', 'bateau'],
#  ['figure', 'en pied', 'homme'],
#  ['figure', 'outil'],
#  ['figure', 'agenouillé'],
#  ['figure', 'cape'],
#  ['figure', 'en pied', 'homme'],
#  ['figure', 'de dos'],
#  ['figure', 'religieux'],
#  ['figure', 'costume religieux', 'froc'],
#  ['groupe de figures', 'femme', 'penché'],
#  ['groupe de figures', 'homme', 'mort'],
#  ['groupe de figures', 'cercueil'],
#  ['figure', 'en buste', 'homme'],
#  ['figure', 'de profil'],
#  ['figure', 'cavalier', 'homme'],
#  ['figure', 'uniforme', 'vêtement'],
#  ['figure', 'botte'],
#  ['figure', 'couvre-chef'],
#  ['figure', 'arme', 'épée'],
#  ['figure', 'animal', 'cheval'],
#  ['figure', 'communication par le geste'],
#  ['groupe de figures', 'en pied', 'homme'],
#  ['groupe de figures', 'chapeau', 'couvre-chef'],
#  ['groupe de figures', 'animal', 'âne'],
#  ['groupe de figures', 'mouton'],
#  ['groupe de figures', 'chien'],
#  ['fond de paysage', 'forêt'],
#  ['fond de paysage', 'eau'],
#  ['fond de paysage', 'cascade'],
#  ['fond de paysage', 'pont'],
#  ['fond de paysage', 'animal', 'oiseau'],
#  ['figure', 'en pied', 'homme'],
#  ['figure', 'armure'],
#  ['figure', 'couvre-chef'],
#  ['figure', 'arme', 'épée'],
#  ['figure', 'bâton'],
#  ['groupe de figures', 'homme'],
#  ['groupe de figures', 'couché', 'femme'],
#  ['groupe de figures', 'agenouillé'],
#  ['groupe de figures', 'coiffe', 'couvre-chef'],
#  ['groupe de figures', 'auréole'],
#  ['groupe de figures', 'couronne', 'épine'],
#  ['groupe de figures', 'barbe'],
#  ['groupe de figures', 'clou'],
#  ['groupe de figures', 'cruche'],
#  ['groupe de figures', 'feuillet'],
#  ['scène', 'homme'],
#  ['scène', 'femme'],
#  ['scène', 'enfant'],
#  ['scène', 'robe', 'vêtement'],
#  ['scène', 'coiffe', 'couvre-chef'],
#  ['scène', 'chaîne'],
#  ['scène', 'barbe'],
#  ['scène', 'toile'],
#  ['scène', 'mort'],
#  ['fond de paysage', 'montagne'],
#  ['fond de paysage', 'arbre'],
#  ['fond de paysage', 'rocher'],
#  ['fond de paysage', 'croix'],
#  ['paysage', 'rocher'],
#  ['paysage', 'arbre'],
#  ['paysage', 'eau'],
#  ['figure', 'assis', 'femme'],
#  ['figure', 'robe', 'vêtement'],
#  ['figure', 'gant'],
#  ['figure', 'chaussure'],
#  ['figure', 'anneau', 'bijou'],
#  ['figure', 'noeud'],
#  ['figure', 'canapé', 'éventail intérieur meuble'],
#  ['figure', 'tapis'],
#  ['groupe de figures', 'femme'],
#  ['groupe de figures', 'homme'],
#  ['groupe de figures', 'enfant'],
#  ['groupe de figures', 'animal', 'chien'],
#  ['groupe de figures', 'couvre-chef'],
#  ['figure', 'homme'],
#  ['figure', 'de profil', 'tête'],
#  ['groupe de figures', 'femme'],
#  ['groupe de figures', 'barbe', 'homme'],
#  ['groupe de figures', 'enfant'],
#  ['groupe de figures', 'agneau', 'animal'],
#  ['groupe de figures', 'coiffe'],
#  ['groupe de figures', 'croix'],
#  ['figure', 'de profil', 'homme'],
#  ['figure', 'en buste'],
#  ['figure', 'barbe'],
#  ['figure', 'moustache'],
#  ['figure', 'couvre-chef', 'local'],
#  ['architecture', 'kiosque'],
#  ['architecture', 'colonne'],
#  ['architecture', 'chapiteau'],
#  ['groupe de figures', 'homme'],
#  ['groupe de figures', 'femme'],
#  ['groupe de figures', 'enfant', 'fillette'],
#  ['groupe de figures', 'en pied'],
#  ['groupe de figures', 'assis'],
#  ['groupe de figures', 'animal', 'chien'],
#  ['groupe de figures', 'habit', 'vêtement'],
#  ['groupe de figures', 'robe'],
#  ['groupe de figures', 'tablier'],
#  ['groupe de figures', 'coiffe', 'couvre-chef'],
#  ['groupe de figures', 'chapeau'],
#  ['groupe de figures', 'lunettes'],
#  ['groupe de figures', 'moustache'],
#  ['groupe de figures', 'bâton'],
#  ['groupe de figures', 'coffre'],
#  ['intérieur', 'armoire', 'meuble'],
#  ['intérieur', 'chaise'],
#  ['intérieur', 'table'],
#  ['intérieur', 'escalier'],
#  ['intérieur', 'fenêtre'],
#  ['intérieur', 'rideau'],
#  ['intérieur', 'pavement'],
#  ['intérieur', 'statue'],
#  ['intérieur', 'affiche'],
#  ['intérieur', 'tableau'],
#  ['intérieur', 'plante'],
#  ['intérieur', 'fleur'],
#  ['intérieur', 'assiette'],
#  ['intérieur', 'bouteille'],
#  ['intérieur', 'gobelet'],
#  ['intérieur', 'boîte'],
#  ['figure', 'en appui', 'femme'],
#  ['groupe de figures', 'homme'],
#  ['groupe de figures', 'local', 'vêtement'],
#  ['groupe de figures', 'couvre-chef'],
#  ['groupe de figures', 'animal', 'dromadaire'],
#  ['groupe de figures', 'caravane'],
#  ['groupe de figures', 'désert'],
#  ['groupe de figures', 'arbre', 'palmier'],
#  ['paysage', 'désert'],
#  ['paysage', 'arbre'],
#  ['paysage', 'montagne'],
#  ['paysage', 'architecture'],
#  ['figure', 'assis', 'femme'],
#  ['figure', 'de profil'],
#  ['figure', 'coiffe', 'couvre-chef', 'local'],
#  ['figure', 'panier'],
#  ['figure', 'bijou'],
#  ['figure', 'aliment'],
#  ['architecture', 'rempart'],
#  ['architecture', 'ville'],
#  ['architecture', 'escalier'],
#  ['architecture', 'maison'],
#  ['architecture', 'colonne'],
#  ['architecture', 'ville'],
#  ['architecture', 'mosquée'],
#  ['architecture', 'coupole'],
#  ['architecture', 'arbre'],
#  ['groupe de figures', 'de profil', 'homme'],
#  ['groupe de figures', 'barbe'],
#  ['groupe de figures', 'femme', 'à mi-corps'],
#  ['figure', 'en pied', 'femme'],
#  ['figure', 'draperie', 'vêtement'],
#  ['groupe de figures', 'homme'],
#  ['groupe de figures', 'femme'],
#  ['groupe de figures', 'aile', 'être imaginaire'],
#  ['groupe de figures', 'lune'],
#  ['paysage', 'maison'],
#  ['paysage', 'mosquée'],
#  ['paysage', 'minaret'],
#  ['paysage', 'arbre'],
#  ['architecture', 'maison'],
#  ['architecture', 'coupole'],
#  ['architecture', 'minaret'],
#  ['architecture', 'arbre', 'désert', 'palmier'],
#  ['bijou'],
#  ['groupe de figures', 'en buste', 'homme'],
#  ['groupe de figures', 'barbe'],
#  ['groupe de figures', 'moustache'],
#  ['groupe de figures', 'couvre-chef', 'local'],
#  ['figure', 'femme', 'nu'],
#  ['figure', 'couché'],
#  ['figure', 'lit'],
#  ['figure', 'coussin'],
#  ['figure', 'assis', 'homme'],
#  ['figure', 'local', 'vêtement'],
#  ['figure', 'couvre-chef'],
#  ['groupe de figures', 'homme'],
#  ['groupe de figures', 'assis', 'enfant'],
#  ['groupe de figures', 'couvre-chef', 'local'],
#  ['groupe de figures', 'livre'],
#  ['groupe de figures', 'architecture'],
#  ['figure', 'en pied', 'homme'],
#  ['figure', 'profil'],
#  ['figure', 'serviteur'],
#  ['figure', 'couvre-chef', 'local', 'vêtement'],
#  ['groupe de figures', 'femme'],
#  ['groupe de figures', 'enfant'],
#  ['groupe de figures', 'local', 'vêtement'],
#  ['groupe de figures', 'panier'],
#  ['groupe de figures', 'de dos'],
#  ['figure', 'femme', 'à mi-corps'],
#  ['figure', 'de trois-quarts'],
#  ['figure', 'couvre-chef', 'local'],
#  ['figure', 'bijou'],
#  ['groupe de figures', 'assis', 'homme'],
#  ['groupe de figures', 'femme'],
#  ['groupe de figures', 'enfant'],
#  ['groupe de figures', 'local', 'vêtement'],
#  ['groupe de figures', 'couvre-chef'],
#  ['groupe de figures', 'échoppe'],
#  ['figure', 'assis', 'femme'],
#  ['marine', 'bateau', 'péniche'],
#  ['marine', 'quai'],
#  ['marine', 'drapeau'],
#  ['figure', 'assis', 'femme'],
#  ['figure', 'lecture'],
#  ['paysage', 'bateau'],
#  ['paysage', 'quai'],
#  ['paysage', 'bâtiment', 'clocher'],
#  ['paysage', 'maison'],
#  ['paysage', 'arbre'],
#  ['figure', 'assis', 'femme'],
#  ['figure', 'nu'],
#  ['figure', 'penché'],
#  ['groupe de figures', 'homme'],
#  ['marine', 'bateau', 'bateau à voiles'],
#  ['marine', 'péniche'],
#  ['marine', 'quai'],
#  ['groupe de figures', 'femme'],
#  ['groupe de figures', 'enfant'],
#  ['groupe de figures', 'étreinte'],
#  ['figure', 'assis', 'homme'],
#  ['paysage', 'forêt'],
#  ['paysage', 'arbre'],
#  ['paysage', 'maison'],
#  ['figure', 'homme', 'à mi-corps'],
#  ['figure', 'habit'],
#  ['figure', 'assis', 'femme'],
#  ['figure', 'de dos'],
#  ['figure', 'assis', 'femme'],
#  ['figure', 'de profil'],
#  ['figure', 'vêtement'],
#  ['figure', 'livre'],
#  ['groupe de figures', 'homme'],
#  ['groupe de figures', 'assis', 'femme'],
#  ['groupe de figures', 'chapeau'],
#  ['paysage', 'arbre'],
#  ['paysage', 'montagne'],
#  ['figure', 'couché', 'femme'],
#  ['figure', 'fenêtre'],
#  ["représentation d'objet", 'cruche'],
#  ['figure', 'assis', 'femme'],
#  ['figure', 'accoudé'],
#  ['figure', 'châle'],
#  ['figure', 'chaise'],
#  ['figure', 'table'],
#  ['figure', 'tasse'],
#  ['représentation animalière', 'animal', 'chien'],
#  ['représentation animalière', 'couché'],
#  ['figure', 'femme'],
#  ['figure', 'femme', 'nu'],
#  ['figure', 'de dos'],
#  ['figure', 'assis', 'femme'],
#  ['figure', 'en buste'],
#  ['figure', 'accoudé'],
#  ['figure', 'livre'],
#  ['représentation animalière', 'animal', 'chat'],
#  ['figure', 'assis', 'femme'],
#  ['figure', 'à mi-corps'],
#  ['figure', "travaux d'aiguille"],
#  ['groupe de figures', 'assis', 'femme'],
#  ['groupe de figures', 'à mi-corps'],
#  ['groupe de figures', 'fenêtre'],
#  ['groupe de figures', 'rideau'],
#  ['figure', 'assis', 'femme'],
#  ['figure', 'tasse'],
#  ['figure', 'cuillère'],
#  ['figure', 'animal', 'chien'],
#  ['représentation animalière', 'animal', 'cheval'],
#  ['maison'],
#  ['paysage', 'maison'],
#  ['paysage', 'arbre'],
#  ['paysage', 'animal', 'oiseau'],
#  ['paysage', 'forêt'],
#  ['paysage', 'arbre'],
#  ['groupe de figures', 'homme'],
#  ['groupe de figures', 'femme'],
#  ['groupe de figures', 'animal', 'chien'],
#  ['groupe de figures', 'arbre'],
#  ['figure', 'homme', 'à mi-corps'],
#  ['figure', 'de trois-quarts'],
#  ['figure', 'habit', 'vêtement'],
#  ['figure', 'barbe'],
#  ['figure', 'lunettes'],
#  ['figure', 'en pied', 'femme'],
#  ['figure', 'robe', 'vêtement'],
#  ['figure', "Corne d'abondance"],
#  ['figure', 'fleur'],
#  ['paysage', 'montagne'],
#  ['paysage', 'eau'],
#  ['paysage', 'arbre'],
#  ['paysage', 'herbe'],
#  ['paysage', 'bâtiment', 'maison'],
#  ['groupe de figures', 'assis', 'femme'],
#  ['groupe de figures', 'voile', 'vêtement'],
#  ['groupe de figures', 'table'],
#  ['figure', 'assis', 'femme'],
#  ['figure', 'animal', 'chien'],
#  ['figure', 'en pied', 'homme'],
#  ['figure', 'sport'],
#  ['figure', 'bal'],
#  ['paysage', 'bateau'],
#  ['paysage', 'eau'],
#  ['groupe de figures', 'assis', 'homme'],
#  ['groupe de figures', 'eau'],
#  ['groupe de figures', 'bateau'],
#  ['groupe de figures', 'péniche'],
#  ['figure', 'en pied', 'homme'],
#  ['figure', 'chapeau', 'vêtement'],
#  ['<UNK>', 'de dos', 'femme'],
#  ['groupe de figures', 'couché'],
#  ['scène', 'ivresse'],
#  ['figure', 'homme'],
#  ['figure', 'en buste'],
#  ['<UNK>', 'nu'],
#  ['figure', 'en pied', 'femme'],
#  ['figure', 'manteau'],
#  ['figure', 'assis', 'femme'],
#  ['figure', 'à mi-corps'],
#  ['scène', 'parure'],
#  ['figure', 'femme', 'nu'],
#  ['figure', 'assis'],
#  ['figure', 'en pied'],
#  ['figure', 'couché'],
#  ['figure', 'femme'],
#  ['figure', 'accoudé'],
#  ['figure', 'en pied'],
#  ['figure', 'gant'],
#  ['figure', 'femme', 'nu'],
#  ['figure', 'tête'],
#  ['figure', 'penché'],
#  ['figure', 'en pied'],
#  ['figure', 'assis', 'femme'],
#  ['figure', 'assis', 'femme'],
#  ['<UNK>', 'animal', 'cheval'],
#  ['<UNK>', 'charrette'],
#  ['figure', 'femme'],
#  ['figure', 'couché sur le côté'],
#  ['groupe de figures', 'homme'],
#  ['groupe de figures', 'tête'],
#  ['groupe de figures', 'en buste'],
#  ['figure', 'femme', 'tête'],
#  ['figure', 'sommeil'],
#  ['groupe de figures', 'assis', 'femme'],
#  ['groupe de figures', 'extension'],
#  ['groupe de figures', 'accroupi'],
#  ['groupe de figures', 'chaise'],
#  ['figure', 'homme'],
#  ['figure', 'charrette'],
#  ['figure', 'boeuf'],
#  ['figure', 'femme', 'nu'],
#  ['figure', 'couché sur le côté'],
#  ['figure', 'accoudé'],
#  ['groupe de figures', 'assis'],
#  ['groupe de figures', 'en pied'],
#  ['figure', 'assis', 'femme'],
#  ['figure', 'à mi-corps'],
#  ['figure', 'nu'],
#  ['groupe de figures', 'assis', 'femme'],
#  ['intérieur', 'table'],
#  ['intérieur', 'chaise'],
#  ['intérieur', 'armoire'],
#  ['figure', 'nu'],
#  ['figure', 'couché'],
#  ['groupe de figures', 'homme'],
#  ['groupe de figures', 'femme'],
#  ['groupe de figures', 'enfant'],
#  ['groupe de figures', 'veste'],
#  ['groupe de figures', 'cravate'],
#  ['groupe de figures', 'tablier'],
#  ['groupe de figures', 'coiffe', 'couvre-chef'],
#  ['groupe de figures', 'animal', 'chien'],
#  ['<UNK>', 'chaise', 'intérieur'],
#  ['<UNK>', 'berceau'],
#  ['<UNK>', 'âtre'],
#  ['<UNK>', 'panier'],
#  ['<UNK>', 'cruche', 'vaisselle'],
#  ['<UNK>', 'écuelle'],
#  ['<UNK>', 'assiette'],
#  ['<UNK>', 'légume', 'oignon'],
#  ['<UNK>', 'linge de maison'],
#  ['paysage', 'colline'],
#  ['paysage', 'rocher'],
#  ['paysage', 'arbre'],
#  ['paysage', 'eau', 'ruisseau'],
#  ['paysage', 'animal', 'bétail'],
#  ['paysage', 'figure'],
#  ['groupe de figures', 'homme'],
#  ['groupe de figures', 'femme'],
#  ['groupe de figures', 'en pied'],
#  ['groupe de figures', 'assis'],
#  ['groupe de figures', 'uniforme', 'vêtement'],
#  ['groupe de figures', 'robe'],
#  ['groupe de figures', 'botte'],
#  ['groupe de figures', 'coiffe', 'couvre-chef'],
#  ['groupe de figures', 'chapeau'],
#  ['groupe de figures', 'arme', 'épée'],
#  ['groupe de figures', 'fusil'],
#  ['groupe de figures', 'animal', 'chien'],
#  ['intérieur', 'banc', 'meuble'],
#  ['intérieur', 'table'],
#  ['intérieur', 'pavement'],
#  ['intérieur', 'porte'],
#  ['intérieur', 'fenêtre'],
#  ['intérieur', 'chandelier'],
#  ['intérieur', 'chandelle'],
#  ['intérieur', 'vase'],
#  ['intérieur', 'pipe'],
#  ['intérieur', "matériel d'écriture"],
#  ['intérieur', 'feuillet'],
#  ['intérieur', 'toile'],
#  ['figure', 'assis', 'femme'],
#  ['figure', 'accoudé'],
#  ['figure', 'chien'],
#  ['figure', 'fauteuil'],
#  ['figure', 'table'],
#  ['figure', 'verrerie'],
#  ['paysage'],
#  ['marine', 'rive'],
#  ['marine', 'bateau', 'petit voilier'],
#  ['groupe de figures', 'homme'],
#  ['groupe de figures', 'femme'],
#  ['groupe de figures', 'assis', 'enfant'],
#  ['groupe de figures', 'couché'],
#  ['groupe de figures', 'en pied'],
#  ['groupe de figures', 'chapeau', 'couvre-chef'],
#  ['groupe de figures', 'coiffe'],
#  ['groupe de figures', 'ombrelle'],
#  ['groupe de figures', 'panier'],
#  ['groupe de figures', 'animal', 'cheval'],
#  ['groupe de figures', 'mouette', 'oiseau'],
#  ['groupe de figures', 'plage'],
#  ['groupe de figures', 'dune'],
#  ['groupe de figures', 'eau', 'mer'],
#  ['groupe de figures', 'bateau', 'bateau à voiles'],
#  ['groupe de figures', 'ancre'],
#  ['figure', 'assis', 'femme'],
#  ['figure', 'table'],
#  ['paysage', 'arbre'],
#  ['paysage', 'étang'],
#  ['paysage', 'électricité'],
#  ['figure', 'assis', 'homme'],
#  ['figure', 'penché'],
#  ['figure', 'en appui'],
#  ['figure', 'repos'],
#  ['intérieur', 'table'],
#  ['intérieur', 'verre à pied'],
#  ['groupe de figures', 'assis', 'homme'],
#  ['groupe de figures', 'femme'],
#  ['groupe de figures', 'coiffe'],
#  ['intérieur', 'table'],
#  ['intérieur', 'tabouret'],
#  ['intérieur', 'banc'],
#  ['intérieur', 'assiette'],
#  ['intérieur', 'pot'],
#  ['figure', 'assis', 'femme'],
#  ['figure', 'chaise'],
#  ['figure', 'table'],
#  ['figure', 'rideau'],
#  ['scène', "travaux d'aiguille"],
#  ['figure', 'en buste', 'homme'],
#  ['figure', 'tête'],
#  ['groupe de figures', 'assis', 'femme'],
#  ['intérieur', 'meuble', 'siège à plusieurs places', 'table'],
#  ['intérieur', 'vase'],
#  ['intérieur', 'fleur', 'tulipe'],
#  ['figure', 'femme', 'nu'],
#  ['figure', 'assis'],
#  ['figure', 'de dos'],
#  ['figure', 'lit'],
#  ['figure', 'cruche'],
#  ['figure', 'de dos', 'femme'],
#  ['figure', 'en pied'],
#  ['figure', 'miroir'],
#  ['figure', 'assis', 'femme'],
#  ['groupe de figures', 'femme'],
#  ['groupe de figures', 'ménage', 'repassage'],
#  ['figure', 'couché sur le côté', 'femme'],
#  ['figure', 'accoudé'],
#  ['figure', 'lit'],
#  ['figure', 'livre'],
#  ['figure', 'femme', 'jeune fille', 'nu'],
#  ['figure', 'assis', 'femme'],
#  ['figure', 'costume religieux', 'vêtement'],
#  ['figure', 'coiffe', 'couvre-chef'],
#  ['figure', 'livre'],
#  ['figure', 'fleur', 'rose'],
#  ['figure', 'rideau'],
#  ['paysage', 'forêt'],
#  ['paysage', 'eau'],
#  ['paysage', 'rocher'],
#  ['paysage', 'gouffre'],
#  ['représentation animalière', 'animal', 'cheval'],
#  ['représentation animalière', 'route'],
#  ['représentation animalière', 'herbe'],
#  ['représentation animalière', 'arbre'],
#  ['représentation animalière', 'eau'],
#  ['représentation animalière', 'bâtiment'],
#  ['figure', 'en buste', 'homme'],
#  ['figure', 'habit', 'vêtement'],
#  ['figure', 'col'],
#  ['groupe de figures', 'femme', 'nue'],
#  ['groupe de figures', 'enfant', 'être imaginaire'],
#  ['groupe de figures', 'aile'],
#  ['groupe de figures', 'dans les airs'],
#  ['groupe de figures', 'en vol'],
#  ['groupe de figures', 'barbe', 'homme'],
#  ['groupe de figures', 'bouc', 'patte'],
#  ['groupe de figures', 'animal', 'cheval'],
#  ['groupe de figures', 'dauphin'],
#  ['groupe de figures', 'poisson'],
#  ['groupe de figures', 'raie'],
#  ['groupe de figures', 'plie'],
#  ['groupe de figures', 'anguille'],
#  ['groupe de figures', 'étoile de mer'],
#  ['groupe de figures', 'homard'],
#  ['groupe de figures', 'crustacé', 'huître'],
#  ['groupe de figures', 'coquillage'],
#  ['<UNK>', 'fête'],
#  ['<UNK>', 'banquet'],
#  ['<UNK>', 'table'],
#  ['<UNK>', 'assiette'],
#  ['<UNK>', 'plat'],
#  ['<UNK>', 'bol'],
#  ['<UNK>', 'cruche'],
#  ['<UNK>', 'vaisselle'],
#  ['<UNK>', 'verrerie'],
#  ['<UNK>', 'verre à pied'],
#  ['<UNK>', 'hanap'],
#  ['<UNK>', 'instrument de musique', 'tambourin'],
#  ['<UNK>', 'cor'],
#  ['<UNK>', 'danse'],
#  ['<UNK>', 'plante'],
#  ['<UNK>', 'fleur'],
#  ['<UNK>', 'guirlande'],
#  ['<UNK>', 'artichaut', 'légume'],
#  ['<UNK>', 'fruit', 'melon'],
#  ['<UNK>', 'fruit de la passion'],
#  ['<UNK>', 'raisin'],
#  ['<UNK>', 'arme', 'flèche'],
#  ['<UNK>', 'arc'],
#  ['<UNK>', 'trident'],
#  ['<UNK>', 'tonneau'],
#  ['<UNK>', 'grotte'],
#  ['<UNK>', 'eau', 'mer'],
#  ['architecture', 'quai'],
#  ['architecture', 'bâtiment'],
#  ['architecture', 'façade'],
#  ['architecture', 'tour'],
#  ['architecture', 'eau'],
#  ['architecture', 'bateau', 'bateau à voiles\xad'],
#  ['architecture', 'barque'],
#  ['architecture', 'figure'],
#  ['figure', 'en buste', 'jeune homme'],
#  ['figure', 'uniforme', 'vêtement'],
#  ['paysage', 'hiver', 'saison'],
#  ['paysage', 'neige'],
#  ['paysage', 'village'],
#  ['paysage', 'bâtiment', 'église'],
#  ['paysage', 'ferme'],
#  ['paysage', 'glace', 'rivière'],
#  ['paysage', 'arbre', 'scène homme'],
#  ['paysage', 'femme'],
#  ['paysage', 'enfant'],
#  ['paysage', 'vêtement'],
#  ['paysage', 'chapeau'],
#  ['paysage', 'animal', 'cheval'],
#  ['paysage', 'chien'],
#  ['paysage', 'traîneau'],
#  ['paysage', 'jeu', 'jeu de ballon'],
#  ['groupe de figures', 'femme', 'nu'],
#  ['groupe de figures', 'assis'],
#  ['groupe de figures', 'robe', 'vêtement'],
#  ['groupe de figures', 'chaussure'],
#  ['fond de paysage', 'eau'],
#  ['fond de paysage', 'plante aquatique', 'roseau'],
#  ['fond de paysage', 'herbe'],
#  ...]

# %%
print(len(fabritius))
print(len(iclass))
# Out:
# 6007
# 18454

# %%
icodes = list(iclass.keys())
iclass = list(iclass.values())
all_docs = fabritius + iclass

# %%
#from gensim.models import FastText
#wv_fr = FastText(size=30, window=3, min_count=1, sentences=all_docs)
#wv_fr.wv.most_similar('temple')

# %%
from gensim.models import WordEmbeddingSimilarityIndex
from gensim.similarities import SparseTermSimilarityMatrix
from gensim.corpora import Dictionary

# %%
termsim_index = WordEmbeddingSimilarityIndex(wv_fr)

# %%
dictionary = Dictionary(all_docs)

# %%
similarity_matrix = SparseTermSimilarityMatrix(termsim_index, dictionary)  # construct similarity matrix

# %%
bow_corpus = [dictionary.doc2bow(document) for document in iclass]
bow_corpus
# Out:
# [[(1046, 1)],
#  [(61, 1), (1047, 1)],
#  [(7, 1)],
#  [(16, 1)],
#  [(1048, 1)],
#  [(19, 1), (46, 1), (61, 1), (628, 1), (1049, 1), (1050, 1)],
#  [(1034, 1), (1051, 1), (1052, 1)],
#  [(101, 1)],
#  [(1053, 1)],
#  [(71, 1), (1054, 1)],
#  [(184, 1)],
#  [(364, 1)],
#  [(389, 1), (516, 1), (762, 1), (1055, 1)],
#  [(1056, 1)],
#  [(1057, 1)],
#  [(291, 1), (1003, 1)],
#  [(1058, 1)],
#  [(1059, 1), (1060, 1)],
#  [(972, 1), (1003, 1)],
#  [(1061, 1), (1062, 1), (1063, 1)],
#  [(1064, 1)],
#  [(1065, 1)],
#  [(172, 1), (1066, 1), (1067, 1)],
#  [(1068, 1), (1069, 1)],
#  [(40, 1), (1070, 1)],
#  [(915, 1)],
#  [(126, 1)],
#  [(120, 1)],
#  [(584, 1)],
#  [(2, 1), (1071, 1)],
#  [(10, 1), (73, 1)],
#  [(402, 1)],
#  [(111, 1), (842, 1)],
#  [(68, 1), (655, 1)],
#  [(1072, 1)],
#  [(503, 1)],
#  [(71, 1)],
#  [(585, 1), (1073, 1), (1074, 1)],
#  [(849, 1)],
#  [(1075, 1)],
#  [(123, 1)],
#  [(1076, 1)],
#  [(65, 1)],
#  [(7, 1), (1071, 1)],
#  [(1077, 1)],
#  [(1078, 1)],
#  [(37, 1)],
#  [(47, 1)],
#  [(61, 1), (1079, 1)],
#  [(1080, 1)],
#  [(230, 1), (721, 1), (722, 1), (1081, 1)],
#  [(1082, 1), (1083, 1), (1084, 1)],
#  [(1082, 1), (1083, 1), (1084, 1)],
#  [(1085, 1), (1086, 1)],
#  [(1087, 1)],
#  [(1088, 1), (1089, 1)],
#  [(1090, 1)],
#  [(1007, 1)],
#  [(945, 1)],
#  [(30, 1)],
#  [(458, 1)],
#  [(456, 1)],
#  [(232, 1), (456, 1), (458, 1), (1062, 1), (1091, 1), (1092, 1)],
#  [(1093, 1)],
#  [(628, 1), (1094, 1)],
#  [(1095, 1), (1096, 1)],
#  [(1095, 1), (1096, 1)],
#  [(1097, 1)],
#  [(1097, 1)],
#  [(458, 1), (573, 1), (1098, 1)],
#  [(358, 1)],
#  [(7, 1), (1071, 1)],
#  [(7, 1), (1071, 1)],
#  [(32, 1)],
#  [(506, 1)],
#  [(542, 1), (1099, 1)],
#  [(37, 1)],
#  [(115, 1)],
#  [(29, 1)],
#  [(1100, 1)],
#  [(399, 1)],
#  [(1101, 1)],
#  [(1102, 1), (1103, 1)],
#  [(1062, 1), (1104, 1), (1105, 1)],
#  [(1062, 1), (1106, 1), (1107, 1), (1108, 1)],
#  [(1062, 1), (1109, 1), (1110, 1), (1111, 1), (1112, 1), (1113, 1)],
#  [(1062, 1), (1114, 1)],
#  [(1115, 1)],
#  [(1116, 1)],
#  [(1117, 1)],
#  [(74, 1)],
#  [(226, 1), (1118, 1), (1119, 1), (1120, 1)],
#  [(1121, 1), (1122, 1)],
#  [(42, 1)],
#  [(1123, 1), (1124, 1)],
#  [(1125, 1)],
#  [(31, 1)],
#  [(2, 1), (1071, 1)],
#  [(1126, 1), (1127, 1)],
#  [(59, 1), (128, 1), (1128, 1)],
#  [(131, 1)],
#  [(533, 1)],
#  [(10, 1), (59, 1)],
#  [(136, 1), (1129, 1)],
#  [(1130, 1)],
#  [(1131, 1), (1132, 1), (1133, 1), (1134, 1)],
#  [(1135, 1), (1136, 1)],
#  [(32, 1)],
#  [(2, 1), (1071, 1)],
#  [(385, 1)],
#  [(1062, 1),
#   (1137, 1),
#   (1138, 1),
#   (1139, 1),
#   (1140, 1),
#   (1141, 1),
#   (1142, 1),
#   (1143, 1),
#   (1144, 1),
#   (1145, 1)],
#  [(1146, 1), (1147, 1), (1148, 1), (1149, 1), (1150, 1), (1151, 1)],
#  [(1152, 1)],
#  [(1153, 1)],
#  [(1154, 1)],
#  [(31, 1), (1155, 1)],
#  [(215, 1)],
#  [(47, 1)],
#  [(119, 1), (124, 1), (1156, 1), (1157, 1)],
#  [(26, 1)],
#  [(167, 1)],
#  [(1158, 1)],
#  [(692, 1)],
#  [(1117, 1)],
#  [(1159, 1), (1160, 1), (1161, 1)],
#  [(988, 1)],
#  [(95, 1)],
#  [(589, 1)],
#  [(1162, 1), (1163, 1)],
#  [(849, 1)],
#  [(32, 1)],
#  [(1164, 1),
#   (1165, 1),
#   (1166, 1),
#   (1167, 1),
#   (1168, 1),
#   (1169, 1),
#   (1170, 1),
#   (1171, 1)],
#  [(1172, 1)],
#  [(1130, 1), (1173, 1), (1174, 1)],
#  [(104, 1),
#   (1062, 1),
#   (1175, 1),
#   (1176, 1),
#   (1177, 1),
#   (1178, 1),
#   (1179, 1),
#   (1180, 1)],
#  [(317, 1), (1062, 1), (1181, 1), (1182, 1), (1183, 1)],
#  [(53, 1), (1062, 1), (1184, 1), (1185, 1), (1186, 1)],
#  [(350, 1)],
#  [(574, 1)],
#  [(221, 1)],
#  [(542, 1)],
#  [(1187, 1)],
#  [(1188, 1), (1189, 1)],
#  [(1190, 1)],
#  [(1190, 1), (1191, 1)],
#  [(1192, 1)],
#  [(1193, 1), (1194, 1), (1195, 1), (1196, 1)],
#  [(44, 1)],
#  [(1197, 1)],
#  [(1198, 1)],
#  [(565, 1)],
#  [(1199, 1)],
#  [(312, 1)],
#  [(1200, 1), (1201, 1)],
#  [(1187, 1), (1202, 1)],
#  [(555, 1)],
#  [(1203, 1)],
#  [(1204, 1)],
#  [(1205, 1)],
#  [(15, 1), (1206, 1), (1207, 1)],
#  [(1208, 1)],
#  [(1209, 1)],
#  [(326, 1)],
#  [(433, 1)],
#  [(407, 1), (1210, 1), (1211, 1), (1212, 1), (1213, 1)],
#  [(1214, 1)],
#  [(1215, 1)],
#  [(1062, 1), (1216, 1), (1217, 1), (1218, 1)],
#  [(1219, 1), (1220, 1)],
#  [(1221, 1)],
#  [(101, 1)],
#  [(1222, 1)],
#  [(702, 1), (1223, 1)],
#  [(564, 1), (1224, 1), (1225, 1)],
#  [(9, 1)],
#  [(1226, 1), (1227, 1)],
#  [(1228, 1)],
#  [(1229, 1), (1230, 1), (1231, 1)],
#  [(1226, 1)],
#  [(1226, 1)],
#  [(1232, 1), (1233, 1), (1234, 1)],
#  [(1235, 1), (1236, 1), (1237, 1)],
#  [(340, 1)],
#  [(4, 1), (75, 1), (1238, 1), (1239, 1)],
#  [(451, 1)],
#  [(261, 1), (1240, 1)],
#  [(534, 1), (1241, 1)],
#  [(1242, 1)],
#  [(442, 1)],
#  [(1243, 1)],
#  [(1123, 1), (1244, 1)],
#  [(1245, 1)],
#  [(53, 1)],
#  [(808, 1)],
#  [(808, 1), (823, 1)],
#  [(1246, 1)],
#  [(115, 1)],
#  [(172, 1)],
#  [(1247, 1)],
#  [(1165, 1), (1248, 1)],
#  [(1249, 1), (1250, 1)],
#  [(1251, 1)],
#  [(849, 1)],
#  [(1252, 1)],
#  [(152, 1), (1253, 1)],
#  [(1254, 1)],
#  [(41, 1)],
#  [(40, 1), (1255, 1)],
#  [(30, 1), (1256, 1), (1257, 1), (1258, 1)],
#  [(165, 1), (1259, 1), (1260, 1), (1261, 1), (1262, 1), (1263, 1)],
#  [(1264, 1)],
#  [(1265, 1)],
#  [(1266, 1)],
#  [(1267, 1)],
#  [(1268, 1), (1269, 1)],
#  [(1270, 1), (1271, 1)],
#  [(888, 1)],
#  [(323, 1)],
#  [(16, 1), (210, 1), (428, 1), (692, 1)],
#  [(311, 1), (385, 1)],
#  [(1272, 1), (1273, 1)],
#  [(437, 1), (1274, 1), (1275, 1), (1276, 1)],
#  [(547, 1), (1277, 1)],
#  [(1278, 1), (1279, 1), (1280, 1)],
#  [(14, 1)],
#  [(32, 1), (1281, 1)],
#  [(30, 1)],
#  [(1034, 1), (1051, 1), (1052, 1)],
#  [(9, 1), (163, 1), (1039, 1)],
#  [(1282, 1)],
#  [(1283, 1)],
#  [(1284, 1)],
#  [(1285, 1), (1286, 1), (1287, 1)],
#  [(1288, 1), (1289, 1)],
#  [(1290, 1)],
#  [(1291, 1)],
#  [(1292, 1), (1293, 1), (1294, 1)],
#  [(372, 1), (626, 1)],
#  [(1062, 1), (1295, 1), (1296, 1), (1297, 1), (1298, 1), (1299, 1)],
#  [(2, 1), (1071, 1)],
#  [(1300, 1)],
#  [(1301, 1), (1302, 1)],
#  [(1303, 1), (1304, 1), (1305, 1), (1306, 1)],
#  [(1307, 1), (1308, 1)],
#  [(30, 1), (1309, 1), (1310, 1), (1311, 1)],
#  [(30, 1), (978, 1), (1062, 1), (1309, 1), (1312, 1), (1313, 1)],
#  [(1314, 1)],
#  [(1315, 1)],
#  [(506, 1)],
#  [(584, 1), (1316, 1), (1317, 1), (1318, 1)],
#  [(242, 1), (506, 1), (972, 1), (1319, 1), (1320, 1)],
#  [(1321, 1)],
#  [(222, 1), (1322, 1)],
#  [(81, 1), (1323, 1)],
#  [(266, 1), (1324, 1)],
#  [(1325, 1)],
#  [(152, 1), (1253, 1)],
#  [(1326, 1)],
#  [(1327, 1), (1328, 1)],
#  [(1329, 1), (1330, 1)],
#  [(1331, 1), (1332, 1), (1333, 1)],
#  [(1191, 1)],
#  [(26, 1), (1334, 1)],
#  [(155, 1), (1087, 1), (1335, 1), (1336, 1), (1337, 1)],
#  [(315, 1), (1338, 1)],
#  [(724, 1)],
#  [(1339, 1)],
#  [(1340, 1)],
#  [(1341, 1), (1342, 1)],
#  [(328, 1), (482, 1)],
#  [(1343, 1)],
#  [(616, 1)],
#  [(223, 1), (1344, 1), (1345, 1)],
#  [(1346, 1)],
#  [(1169, 1), (1347, 1), (1348, 1), (1349, 1), (1350, 1)],
#  [(1351, 1)],
#  [(458, 1)],
#  [(1352, 1)],
#  [(1007, 1), (1062, 1), (1353, 1), (1354, 1)],
#  [(1355, 1), (1356, 1)],
#  [(1062, 1),
#   (1137, 1),
#   (1138, 1),
#   (1139, 1),
#   (1140, 1),
#   (1141, 1),
#   (1142, 1),
#   (1145, 1)],
#  [(30, 1)],
#  [(1357, 1)],
#  [(101, 1)],
#  [(456, 1)],
#  [(456, 1)],
#  [(178, 1)],
#  [(210, 1)],
#  [(1358, 1)],
#  [(244, 1)],
#  [(34, 1)],
#  [(442, 1)],
#  [(186, 1)],
#  [(1359, 1)],
#  [(1360, 1), (1361, 1)],
#  [(1062, 1), (1330, 1), (1362, 1), (1363, 1), (1364, 1), (1365, 1)],
#  [(1145, 1)],
#  [(1366, 1)],
#  [(1367, 1)],
#  [(173, 1), (489, 1)],
#  [(1330, 1), (1368, 1), (1369, 1)],
#  [(1370, 1)],
#  [(1330, 1), (1371, 1), (1372, 1)],
#  [(1373, 1), (1374, 1), (1375, 1), (1376, 1), (1377, 1), (1378, 1)],
#  [(1062, 1), (1379, 1), (1380, 1)],
#  [(1062, 1), (1381, 1), (1382, 1)],
#  [(1062, 1),
#   (1383, 1),
#   (1384, 1),
#   (1385, 1),
#   (1386, 1),
#   (1387, 1),
#   (1388, 1),
#   (1389, 1)],
#  [(1062, 1), (1390, 1), (1391, 1), (1392, 1), (1393, 1), (1394, 1), (1395, 1)],
#  [(1396, 1), (1397, 1), (1398, 1), (1399, 1), (1400, 1), (1401, 1), (1402, 1)],
#  [(1403, 1), (1404, 1)],
#  [(1405, 1), (1406, 1), (1407, 1), (1408, 1), (1409, 1), (1410, 1)],
#  [(1062, 1), (1411, 1), (1412, 1), (1413, 1)],
#  [(1414, 1),
#   (1415, 1),
#   (1416, 1),
#   (1417, 1),
#   (1418, 1),
#   (1419, 1),
#   (1420, 1),
#   (1421, 1),
#   (1422, 1),
#   (1423, 1)],
#  [(1369, 1), (1424, 1)],
#  [(1425, 1), (1426, 1)],
#  [(219, 1), (1427, 1)],
#  [(65, 1)],
#  [(639, 1), (1202, 1), (1347, 1), (1428, 1), (1429, 1), (1430, 1), (1431, 1)],
#  [(1432, 1)],
#  [(1433, 1)],
#  [(730, 1), (1434, 1), (1435, 1), (1436, 1)],
#  [(1437, 1), (1438, 1), (1439, 1)],
#  [(470, 1), (1440, 1), (1441, 1), (1442, 1)],
#  [(7, 1)],
#  [(1443, 1), (1444, 1), (1445, 1)],
#  [(1130, 1), (1446, 1), (1447, 1)],
#  [(284, 1)],
#  [(203, 1), (242, 1), (311, 1), (767, 1), (1448, 1), (1449, 1)],
#  [(180, 1), (1450, 1)],
#  [(902, 1), (1451, 1)],
#  [(114, 1), (1452, 1)],
#  [(30, 1)],
#  [(456, 1)],
#  [(1453, 1)],
#  [(1454, 1)],
#  [(288, 1)],
#  [(749, 1)],
#  [(357, 1), (503, 1)],
#  [(1455, 1)],
#  [(30, 1)],
#  [(30, 1)],
#  [(1455, 1)],
#  [(1456, 1)],
#  [(1457, 1)],
#  [(1062, 1), (1458, 1), (1459, 1), (1460, 1)],
#  [(1062, 1), (1461, 1), (1462, 1), (1463, 1), (1464, 1), (1465, 1)],
#  [(1062, 1), (1466, 1), (1467, 1)],
#  [(1179, 1), (1468, 1), (1469, 1), (1470, 1), (1471, 1), (1472, 1)],
#  [(1473, 1), (1474, 1), (1475, 1), (1476, 1), (1477, 1), (1478, 1), (1479, 1)],
#  [(1290, 1), (1480, 1), (1481, 1), (1482, 1)],
#  [(389, 1), (516, 1), (762, 1), (1055, 1)],
#  [(1483, 1)],
#  [(27, 1)],
#  [(486, 1), (1484, 1), (1485, 1)],
#  [(739, 1)],
#  [(1486, 1)],
#  [(1487, 1)],
#  [(610, 1), (1488, 1)],
#  [(297, 1), (1489, 1), (1490, 1)],
#  [(70, 1), (1491, 1)],
#  [(115, 1), (215, 1), (1072, 1), (1250, 1), (1492, 1), (1493, 1), (1494, 1)],
#  [(1495, 1),
#   (1496, 1),
#   (1497, 1),
#   (1498, 1),
#   (1499, 1),
#   (1500, 1),
#   (1501, 1),
#   (1502, 1)],
#  [(1503, 1)],
#  [(1504, 1)],
#  [(412, 1)],
#  [(1505, 1)],
#  [(1506, 1), (1507, 1), (1508, 1)],
#  [(2, 1), (1509, 1), (1510, 1), (1511, 1), (1512, 1)],
#  [(614, 1), (1154, 1), (1513, 1), (1514, 1), (1515, 1)],
#  [(1062, 1), (1516, 1)],
#  [(81, 1), (1517, 1), (1518, 1)],
#  [(1187, 1)],
#  [(1519, 1)],
#  [(1062, 1), (1520, 1), (1521, 1), (1522, 1), (1523, 1)],
#  [(1524, 1)],
#  [(1096, 1), (1525, 1), (1526, 1)],
#  [(1095, 1), (1096, 1)],
#  [(1527, 1)],
#  [(1528, 1)],
#  [(1529, 1)],
#  [(2, 1), (1071, 1)],
#  [(1530, 1), (1531, 1)],
#  [(1437, 1)],
#  [(74, 1), (239, 1)],
#  [(428, 1), (469, 1), (1532, 1), (1533, 1)],
#  [(1534, 1)],
#  [(458, 1)],
#  [(199, 1)],
#  [(1330, 1), (1535, 1)],
#  [(1437, 1), (1536, 1), (1537, 1)],
#  [(1039, 1), (1437, 1), (1536, 1)],
#  [(210, 1), (1538, 1)],
#  [(94, 1)],
#  [(372, 1), (626, 1)],
#  [(457, 1), (749, 1), (1276, 1), (1539, 1)],
#  [(155, 1)],
#  [(146, 1), (1540, 1), (1541, 1)],
#  [(1542, 1)],
#  [(1222, 1)],
#  [(31, 1), (1543, 1)],
#  [(174, 1), (1544, 1), (1545, 1), (1546, 1)],
#  [(1547, 1)],
#  [(240, 1)],
#  [(454, 1), (1548, 1)],
#  [(1082, 1), (1083, 1), (1084, 1), (1549, 1), (1550, 1), (1551, 1)],
#  [(1552, 1)],
#  [(835, 1),
#   (1553, 1),
#   (1554, 1),
#   (1555, 1),
#   (1556, 1),
#   (1557, 1),
#   (1558, 1),
#   (1559, 1)],
#  [(428, 1), (1560, 1), (1561, 1), (1562, 1), (1563, 1), (1564, 1)],
#  [(1565, 1), (1566, 1)],
#  [(112, 1), (1567, 1)],
#  [(328, 1), (1568, 1)],
#  [(1569, 1)],
#  [(4, 1), (75, 1), (1238, 1), (1239, 1)],
#  [(480, 1)],
#  [(74, 1)],
#  [(410, 1)],
#  [(306, 1)],
#  [(362, 1)],
#  [(92, 1), (1570, 1)],
#  [(178, 1)],
#  [(693, 1), (696, 1), (1571, 1), (1572, 1)],
#  [(1117, 1)],
#  [(1117, 1)],
#  [(530, 1)],
#  [(1117, 1)],
#  [(259, 1), (311, 1), (624, 1), (1059, 1), (1573, 1), (1574, 1)],
#  [(1575, 1)],
#  [(238, 1)],
#  [(238, 1),
#   (495, 1),
#   (633, 1),
#   (1165, 1),
#   (1576, 1),
#   (1577, 1),
#   (1578, 1),
#   (1579, 1),
#   (1580, 1),
#   (1581, 1)],
#  [(1582, 1), (1583, 1)],
#  [(1351, 1), (1584, 1)],
#  [(1585, 1)],
#  [(389, 1), (516, 1), (762, 1), (1055, 1)],
#  [(2, 1), (1551, 1), (1586, 1), (1587, 1), (1588, 1)],
#  [(1589, 1)],
#  [(487, 1), (721, 1)],
#  [(1590, 1)],
#  [(1591, 1)],
#  [(382, 1), (1592, 1)],
#  [(40, 1), (43, 1), (1593, 1), (1594, 1)],
#  [(425, 1)],
#  [(579, 1)],
#  [(1595, 1)],
#  [(40, 1), (1085, 1)],
#  [(28, 1), (1596, 1)],
#  [(28, 1)],
#  [(1597, 1), (1598, 1), (1599, 1), (1600, 1), (1601, 1), (1602, 1)],
#  [(498, 1)],
#  [(1223, 1), (1603, 1)],
#  [(1604, 1)],
#  [(1134, 1), (1604, 1), (1605, 1)],
#  [(141, 1)],
#  [(1606, 1)],
#  [(1607, 1)],
#  [(1608, 1)],
#  [(1609, 1)],
#  [(1088, 1), (1089, 1)],
#  [(1610, 1)],
#  [(576, 1), (1611, 1), (1612, 1)],
#  [(1248, 1), (1613, 1)],
#  [(424, 1), (1614, 1)],
#  [(16, 1), (1615, 1)],
#  [(1062, 1),
#   (1616, 1),
#   (1617, 1),
#   (1618, 1),
#   (1619, 1),
#   (1620, 1),
#   (1621, 1),
#   (1622, 1)],
#  [(1062, 1), (1267, 1), (1623, 1), (1624, 1), (1625, 1)],
#  [(1062, 1), (1626, 1), (1627, 1)],
#  [(326, 1), (1457, 1), (1615, 1), (1628, 1), (1629, 1), (1630, 1), (1631, 1)],
#  [(3, 1)],
#  [(813, 1)],
#  [(1632, 1), (1633, 1), (1634, 1), (1635, 1), (1636, 1)],
#  [(1637, 1), (1638, 1)],
#  [(1639, 1)],
#  [(74, 1)],
#  [(2, 1), (7, 1), (20, 1), (1062, 1), (1591, 1), (1640, 1), (1641, 1)],
#  [(1642, 1)],
#  [(1643, 1), (1644, 1)],
#  [(1062, 1), (1645, 1), (1646, 1), (1647, 1), (1648, 1), (1649, 1)],
#  [(1650, 1), (1651, 1), (1652, 1)],
#  [(1062, 1), (1653, 1), (1654, 1), (1655, 1)],
#  [(141, 1), (1656, 1)],
#  [(1096, 1), (1657, 1)],
#  [(768, 1), (1658, 1), (1659, 1), (1660, 1), (1661, 1), (1662, 1)],
#  [(238, 1), (273, 1), (1006, 1), (1663, 1)],
#  [(358, 1), (1071, 1), (1315, 1)],
#  [(1664, 1)],
#  [(1665, 1)],
#  [(1666, 1), (1667, 1)],
#  [(1245, 1)],
#  [(86, 1)],
#  [(418, 1), (1668, 1)],
#  [(1669, 1)],
#  [(1062, 1), (1669, 1), (1670, 1), (1671, 1), (1672, 1)],
#  [(1544, 1), (1673, 1), (1674, 1), (1675, 1)],
#  [(739, 1), (1676, 1)],
#  [(1529, 1), (1677, 1), (1678, 1), (1679, 1), (1680, 1)],
#  [(1681, 1)],
#  [(22, 1), (1682, 1), (1683, 1), (1684, 1)],
#  [(1685, 1)],
#  [(15, 1),
#   (155, 1),
#   (530, 1),
#   (554, 1),
#   (824, 1),
#   (1686, 1),
#   (1687, 1),
#   (1688, 1)],
#  [(1689, 1), (1690, 1), (1691, 1)],
#  [(1692, 1)],
#  [(43, 1)],
#  [(1693, 1), (1694, 1)],
#  [(1695, 1), (1696, 1)],
#  [(1697, 1), (1698, 1)],
#  [(1699, 1), (1700, 1), (1701, 1)],
#  [(1702, 1), (1703, 1), (1704, 1)],
#  [(1705, 1), (1706, 1), (1707, 1)],
#  [(1708, 1), (1709, 1), (1710, 1)],
#  [(1711, 1), (1712, 1), (1713, 1)],
#  [(1714, 1), (1715, 1), (1716, 1)],
#  [(1062, 1), (1063, 1), (1717, 1), (1718, 1)],
#  [(1192, 1)],
#  [(1719, 1)],
#  [(361, 1)],
#  [(1720, 1), (1721, 1)],
#  [(1722, 1)],
#  [(1524, 1)],
#  [(1723, 1)],
#  [(15, 1), (384, 1), (642, 1), (1724, 1), (1725, 1), (1726, 1)],
#  [(15, 1), (384, 1), (440, 1), (670, 1), (1480, 1), (1727, 1)],
#  [(15, 1),
#   (104, 1),
#   (115, 1),
#   (169, 1),
#   (384, 1),
#   (440, 1),
#   (1480, 1),
#   (1728, 1)],
#  [(15, 1), (384, 1), (1480, 1), (1729, 1), (1730, 1)],
#  [(153, 1), (1731, 1)],
#  [(1732, 1)],
#  [(1584, 1), (1733, 1)],
#  [(381, 1), (385, 1), (1508, 1), (1734, 1)],
#  [(407, 1), (1154, 1), (1735, 1)],
#  [(1422, 1)],
#  [(1736, 1)],
#  [(230, 1), (722, 1)],
#  [(1737, 1), (1738, 1), (1739, 1), (1740, 1)],
#  [(1062, 1), (1741, 1), (1742, 1)],
#  [(15, 1),
#   (43, 1),
#   (53, 1),
#   (317, 1),
#   (548, 1),
#   (1223, 1),
#   (1482, 1),
#   (1632, 1),
#   (1743, 1),
#   (1744, 1),
#   (1745, 1),
#   (1746, 1),
#   (1747, 1)],
#  [(146, 1), (1541, 1)],
#  [(622, 1), (1748, 1)],
#  [(385, 1)],
#  [(30, 1)],
#  [(747, 1)],
#  [(356, 1), (1749, 1)],
#  [(117, 1), (1750, 1)],
#  [(1751, 1), (1752, 1)],
#  [(1753, 1), (1754, 1)],
#  [(232, 1)],
#  [(448, 1)],
#  [(1755, 1)],
#  [(1756, 1)],
#  [(447, 1)],
#  [(1118, 1), (1119, 1), (1120, 1), (1757, 1)],
#  [(1758, 1)],
#  [(1329, 1), (1330, 1)],
#  [(41, 1)],
#  [(1759, 1), (1760, 1)],
#  [(1761, 1)],
#  [(1444, 1), (1762, 1)],
#  [(840, 1), (1763, 1), (1764, 1), (1765, 1), (1766, 1), (1767, 1), (1768, 1)],
#  [(1769, 1), (1770, 1)],
#  [(1512, 1), (1771, 1)],
#  [(1772, 1)],
#  [(384, 1), (484, 1), (1773, 1)],
#  [(906, 1)],
#  [(1697, 1), (1774, 1)],
#  [(952, 1), (1775, 1)],
#  [(796, 1)],
#  [(338, 1)],
#  [(624, 1), (1776, 1)],
#  [(15, 1), (1192, 1)],
#  [(1326, 1)],
#  [(499, 1)],
#  [(1062, 1), (1777, 1), (1778, 1)],
#  [(1062, 1), (1458, 1), (1459, 1), (1460, 1)],
#  [(359, 1)],
#  [(206, 1)],
#  [(224, 1)],
#  [(212, 1), (1779, 1)],
#  [(29, 1)],
#  [(1780, 1), (1781, 1)],
#  [(931, 1), (1016, 1)],
#  [(83, 1), (228, 1), (1782, 1), (1783, 1)],
#  [(1609, 1)],
#  [(454, 1), (1784, 1)],
#  [(1785, 1), (1786, 1)],
#  [(1787, 1)],
#  [(458, 1)],
#  [(1788, 1), (1789, 1)],
#  [(116, 1)],
#  [(117, 1)],
#  [(1790, 1)],
#  [(1791, 1)],
#  [(1062, 1), (1389, 1), (1792, 1), (1793, 1)],
#  [(1171, 1), (1794, 1), (1795, 1), (1796, 1), (1797, 1)],
#  [(695, 1), (890, 1)],
#  [(1064, 1), (1798, 1), (1799, 1), (1800, 1), (1801, 1)],
#  [(1050, 1), (1802, 1)],
#  [(1803, 1), (1804, 1)],
#  [(1805, 1), (1806, 1)],
#  [(904, 1), (1807, 1)],
#  [(1808, 1), (1809, 1), (1810, 1)],
#  [(468, 1), (471, 1), (1222, 1), (1811, 1), (1812, 1), (1813, 1)],
#  [(648, 1), (1814, 1), (1815, 1), (1816, 1), (1817, 1)],
#  [(1331, 1), (1332, 1), (1333, 1), (1818, 1), (1819, 1)],
#  [(30, 1), (1820, 1)],
#  [(955, 1)],
#  [(529, 1)],
#  [(364, 1)],
#  [(1821, 1), (1822, 1)],
#  [(1117, 1)],
#  [(1117, 1)],
#  [(691, 1)],
#  [(14, 1)],
#  [(407, 1), (1823, 1), (1824, 1)],
#  [(40, 1), (614, 1), (1508, 1), (1825, 1), (1826, 1), (1827, 1)],
#  [(1828, 1)],
#  [(1829, 1)],
#  [(1830, 1)],
#  [(1062, 1), (1831, 1), (1832, 1)],
#  [(642, 1), (1833, 1)],
#  [(871, 1), (1118, 1), (1119, 1), (1120, 1)],
#  [(1834, 1)],
#  [(1835, 1)],
#  [(1836, 1)],
#  [(991, 1)],
#  [(352, 1)],
#  [(1837, 1)],
#  [(1838, 1)],
#  [(344, 1)],
#  [(206, 1), (1839, 1)],
#  [(1840, 1)],
#  [(382, 1)],
#  [(1841, 1)],
#  [(1842, 1), (1843, 1), (1844, 1)],
#  [(849, 1)],
#  [(223, 1), (1344, 1), (1345, 1)],
#  [(1845, 1)],
#  [(1846, 1), (1847, 1), (1848, 1)],
#  [(1809, 1)],
#  [(1401, 1), (1849, 1), (1850, 1), (1851, 1), (1852, 1)],
#  [(1401, 1), (1625, 1), (1853, 1)],
#  [(1330, 1), (1535, 1)],
#  [(1854, 1)],
#  [(1855, 1)],
#  [(81, 1)],
#  [(546, 1), (1773, 1), (1856, 1)],
#  [(1857, 1), (1858, 1)],
#  [(1859, 1), (1860, 1)],
#  [(172, 1)],
#  [(543, 1)],
#  [(3, 1), (1071, 1), (1861, 1)],
#  [(1862, 1), (1863, 1)],
#  [(553, 1)],
#  [(1864, 1)],
#  [(1865, 1)],
#  [(16, 1)],
#  [(1866, 1)],
#  [(397, 1)],
#  [(149, 1)],
#  [(101, 1)],
#  [(1664, 1)],
#  [(1867, 1)],
#  [(1868, 1)],
#  [(164, 1), (1869, 1)],
#  [(1870, 1)],
#  [(808, 1)],
#  [(1871, 1), (1872, 1)],
#  [(1873, 1)],
#  [(1874, 1)],
#  [(1875, 1)],
#  [(1876, 1), (1877, 1)],
#  [(1878, 1)],
#  [(1879, 1)],
#  [(1704, 1)],
#  [(948, 1)],
#  [(261, 1), (1880, 1), (1881, 1), (1882, 1)],
#  [(192, 1), (529, 1)],
#  [(15, 1), (115, 1), (384, 1), (1480, 1), (1883, 1)],
#  [(1884, 1), (1885, 1), (1886, 1), (1887, 1)],
#  [(1863, 1), (1885, 1)],
#  [(1888, 1)],
#  [(53, 1)],
#  [(34, 1),
#   (59, 1),
#   (149, 1),
#   (242, 1),
#   (326, 1),
#   (381, 1),
#   (647, 1),
#   (1230, 1),
#   (1482, 1),
#   (1686, 1),
#   (1721, 1),
#   (1889, 1),
#   (1890, 1),
#   (1891, 1),
#   (1892, 1),
#   (1893, 1),
#   (1894, 1)],
#  [(1895, 1), (1896, 1), (1897, 1)],
#  [(1006, 1)],
#  [(1804, 1)],
#  [(342, 1)],
#  [(1898, 1)],
#  [(31, 1)],
#  [(1899, 1), (1900, 1)],
#  [(1901, 1), (1902, 1)],
#  [(1057, 1)],
#  [(1903, 1), (1904, 1), (1905, 1)],
#  [(193, 1)],
#  [(1906, 1)],
#  [(501, 1)],
#  [(385, 1), (413, 1), (1907, 1), (1908, 1), (1909, 1)],
#  [(363, 1)],
#  [(359, 1), (361, 1), (363, 1), (1910, 1)],
#  [(1255, 1), (1593, 1)],
#  [(1614, 1), (1911, 1)],
#  [(126, 1), (1912, 1), (1913, 1)],
#  [(458, 1), (1914, 1)],
#  [(1915, 1)],
#  [(1916, 1), (1917, 1), (1918, 1), (1919, 1)],
#  [(2, 1)],
#  [(149, 1)],
#  [(1920, 1), (1921, 1)],
#  [(1922, 1)],
#  [(169, 1)],
#  [(26, 1), (686, 1), (928, 1), (1290, 1)],
#  [(101, 1)],
#  [(101, 1)],
#  [(1923, 1), (1924, 1)],
#  [(1925, 1)],
#  [(16, 1), (407, 1), (813, 1), (1926, 1)],
#  [(491, 1)],
#  [(61, 1), (1483, 1)],
#  [(841, 1),
#   (1129, 1),
#   (1492, 1),
#   (1527, 1),
#   (1927, 1),
#   (1928, 1),
#   (1929, 1),
#   (1930, 1),
#   (1931, 1),
#   (1932, 1),
#   (1933, 1),
#   (1934, 1)],
#  [(1935, 1)],
#  [(1936, 1), (1937, 1)],
#  [(588, 1), (1938, 1)],
#  [(696, 1), (898, 1), (1571, 1), (1572, 1)],
#  [(718, 1)],
#  [(1062, 1), (1939, 1), (1940, 1), (1941, 1)],
#  [(918, 1)],
#  [(1942, 1)],
#  [(848, 1)],
#  [(1943, 1)],
#  [(73, 1), (1944, 1)],
#  [(1945, 1), (1946, 1)],
#  [(1330, 1), (1947, 1), (1948, 1), (1949, 1), (1950, 1)],
#  [(74, 1), (178, 1)],
#  [(288, 1), (913, 1), (1951, 1)],
#  [(1952, 1)],
#  [(37, 1), (1094, 1), (1953, 1)],
#  [(90, 1)],
#  [(1954, 1), (1955, 1)],
#  [(1956, 1), (1957, 1)],
#  [(624, 1)],
#  [(1915, 1)],
#  [(1360, 1), (1872, 1), (1958, 1), (1959, 1)],
#  [(768, 1), (1960, 1), (1961, 1)],
#  [(633, 1), (1962, 1)],
#  [(74, 1), (239, 1)],
#  [(614, 1)],
#  [(359, 1)],
#  [(1963, 1)],
#  [(1964, 1), (1965, 1), (1966, 1)],
#  [(1877, 1)],
#  [(30, 1)],
#  [(1967, 1)],
#  [(1492, 1)],
#  [(273, 1), (1330, 1), (1968, 1), (1969, 1)],
#  [(1970, 1)],
#  [(1971, 1), (1972, 1)],
#  [(1973, 1)],
#  [(381, 1)],
#  [(1974, 1)],
#  [(1974, 1)],
#  [(118, 1)],
#  [(1290, 1), (1975, 1), (1976, 1), (1977, 1)],
#  [(311, 1)],
#  [(80, 1), (1978, 1)],
#  [(198, 1)],
#  [(1965, 1), (1979, 1), (1980, 1)],
#  [(72, 1)],
#  [(1981, 1), (1982, 1), (1983, 1)],
#  [(1984, 1), (1985, 1)],
#  [(471, 1), (1664, 1), (1986, 1), (1987, 1), (1988, 1)],
#  [(1989, 1), (1990, 1), (1991, 1), (1992, 1), (1993, 1), (1994, 1)],
#  [(104, 1), (183, 1), (1995, 1), (1996, 1), (1997, 1)],
#  [(230, 1), (1998, 1), (1999, 1)],
#  [(273, 1), (2000, 1)],
#  [(2001, 1)],
#  [(2, 1), (7, 1), (53, 1), (1437, 1)],
#  [(121, 1)],
#  [(1096, 1)],
#  [(1096, 1), (1525, 1), (1526, 1)],
#  [(2002, 1), (2003, 1)],
#  [(1095, 1), (1096, 1)],
#  [(539, 1), (1283, 1)],
#  [(86, 1)],
#  [(1085, 1), (1086, 1)],
#  [(1097, 1)],
#  [(2, 1), (1071, 1)],
#  [(1826, 1)],
#  [(2004, 1)],
#  [(2004, 1)],
#  [(242, 1), (2005, 1), (2006, 1)],
#  [(396, 1), (536, 1), (745, 1), (2007, 1)],
#  [(679, 1)],
#  [(68, 1), (159, 1), (2008, 1)],
#  [(1062, 1),
#   (1560, 1),
#   (1561, 1),
#   (1562, 1),
#   (1563, 1),
#   (1564, 1),
#   (1817, 1),
#   (2009, 1),
#   (2010, 1),
#   (2011, 1),
#   (2012, 1),
#   (2013, 1),
#   (2014, 1),
#   (2015, 1),
#   (2016, 1)],
#  [(2017, 1), (2018, 1)],
#  [(74, 1)],
#  [(22, 1)],
#  [(206, 1)],
#  [(484, 1)],
#  [(2019, 1)],
#  [(823, 1), (2020, 1)],
#  [(724, 1)],
#  [(2021, 1)],
#  [(2022, 1)],
#  [(351, 1), (1118, 1), (1119, 1), (1120, 1)],
#  [(2023, 1)],
#  [(256, 1), (1051, 1), (2024, 1)],
#  [(839, 1), (2025, 1)],
#  [(430, 1), (2026, 1), (2027, 1)],
#  [(1664, 1)],
#  [(28, 1)],
#  [(171, 1), (1664, 1)],
#  [(1512, 1)],
#  [(2003, 1)],
#  [(1656, 1)],
#  [(357, 1)],
#  [(61, 1), (1518, 1)],
#  [(2028, 1)],
#  [(1062, 1), (1626, 1), (1627, 1)],
#  [(2029, 1), (2030, 1), (2031, 1), (2032, 1)],
#  [(2033, 1), (2034, 1)],
#  [(1593, 1), (2035, 1)],
#  [(2036, 1)],
#  [(2037, 1)],
#  [(311, 1)],
#  [(2038, 1)],
#  [(318, 1)],
#  [(178, 1)],
#  [(178, 1)],
#  [(2039, 1)],
#  [(178, 1)],
#  [(178, 1)],
#  [(178, 1)],
#  [(1747, 1), (2040, 1)],
#  [(2041, 1), (2042, 1)],
#  [(784, 1)],
#  [(1781, 1), (2043, 1)],
#  [(2044, 1), (2045, 1)],
#  [(1437, 1)],
#  [(178, 1), (2046, 1), (2047, 1), (2048, 1)],
#  [(2049, 1)],
#  [(221, 1)],
#  [(2050, 1), (2051, 1)],
#  [(22, 1)],
#  [(2052, 1), (2053, 1), (2054, 1)],
#  [(2055, 1)],
#  [(976, 1)],
#  [(968, 1)],
#  [(30, 1), (289, 1), (2056, 1), (2057, 1)],
#  [(2058, 1)],
#  [(74, 1)],
#  [(2059, 1), (2060, 1)],
#  [(2061, 1), (2062, 1), (2063, 1), (2064, 1)],
#  [(203, 1), (813, 1), (2065, 1)],
#  [(2066, 1), (2067, 1), (2068, 1), (2069, 1)],
#  [(1595, 1)],
#  [(1595, 1)],
#  [(1595, 1)],
#  [(1595, 1)],
#  [(1595, 1)],
#  [(1595, 1)],
#  [(73, 1), (362, 1)],
#  [(1057, 1)],
#  [(1057, 1)],
#  [(37, 1)],
#  [(2070, 1)],
#  [(1554, 1), (2071, 1), (2072, 1), (2073, 1), (2074, 1)],
#  [(1064, 1)],
#  [(181, 1)],
#  [(101, 1), (2075, 1), (2076, 1)],
#  [(1656, 1)],
#  [(104, 1), (554, 1)],
#  [(1094, 1)],
#  [(1437, 1), (1536, 1)],
#  [(1276, 1), (1886, 1)],
#  [(1862, 1), (2077, 1)],
#  [(648, 1), (1062, 1), (1360, 1), (2078, 1), (2079, 1)],
#  [(311, 1), (369, 1)],
#  [(1117, 1)],
#  [(1117, 1)],
#  [(390, 1)],
#  [(1589, 1)],
#  [(61, 1)],
#  [(2080, 1)],
#  [(1062, 1), (2081, 1), (2082, 1)],
#  [(1405, 1), (1406, 1), (1407, 1), (1408, 1), (1409, 1), (1410, 1)],
#  [(1919, 1), (2083, 1), (2084, 1)],
#  [(2085, 1)],
#  [(2, 1)],
#  [(2, 1)],
#  [(2086, 1)],
#  [(633, 1), (2050, 1)],
#  [(2087, 1), (2088, 1)],
#  [(7, 1), (1071, 1)],
#  [(2089, 1)],
#  [(417, 1)],
#  [(1123, 1)],
#  [(2090, 1), (2091, 1)],
#  [(2092, 1)],
#  [(2, 1), (7, 1), (20, 1), (1062, 1), (1591, 1), (1640, 1), (1641, 1)],
#  [(1642, 1)],
#  [(123, 1), (1056, 1)],
#  [(2093, 1)],
#  [(2094, 1), (2095, 1)],
#  [(151, 1)],
#  [(2096, 1)],
#  [(2097, 1), (2098, 1), (2099, 1)],
#  [(120, 1)],
#  [(1062, 1), (2100, 1)],
#  [(1062, 1),
#   (2101, 1),
#   (2102, 1),
#   (2103, 1),
#   (2104, 1),
#   (2105, 1),
#   (2106, 1),
#   (2107, 1)],
#  [(457, 1)],
#  [(1017, 1)],
#  [(2108, 1)],
#  [(2109, 1)],
#  [(2110, 1)],
#  [(1037, 1), (1276, 1)],
#  [(2111, 1)],
#  [(1062, 1), (2112, 1), (2113, 1), (2114, 1)],
#  [(1062, 1), (2115, 1), (2116, 1), (2117, 1), (2118, 1)],
#  [(222, 1)],
#  [(454, 1), (1697, 1), (2119, 1)],
#  [(96, 1),
#   (128, 1),
#   (173, 1),
#   (265, 1),
#   (579, 1),
#   (1087, 1),
#   (1518, 1),
#   (1593, 1),
#   (2120, 1),
#   (2121, 1)],
#  [(1276, 1), (1486, 1), (2122, 1), (2123, 1)],
#  [(692, 1)],
#  [(696, 1), (816, 1), (1571, 1), (1572, 1)],
#  [(1062, 1), (1172, 1), (2123, 1), (2124, 1)],
#  [(2125, 1)],
#  [(15, 1), (2106, 1)],
#  [(121, 1), (1448, 1), (2126, 1)],
#  [(2127, 1)],
#  [(30, 1)],
#  [(456, 1)],
#  [(2128, 1)],
#  [(319, 1), (455, 1)],
#  [(1525, 1)],
#  [(2129, 1)],
#  [(2130, 1)],
#  [(1492, 1)],
#  [(2131, 1), (2132, 1)],
#  [(2003, 1)],
#  [(95, 1), (356, 1), (1541, 1), (1749, 1)],
#  [(1062, 1),
#   (1519, 1),
#   (2133, 1),
#   (2134, 1),
#   (2135, 1),
#   (2136, 1),
#   (2137, 1),
#   (2138, 1)],
#  [(1460, 1)],
#  [(2139, 1), (2140, 1), (2141, 1)],
#  [(2142, 1), (2143, 1)],
#  [(1798, 1), (2144, 1), (2145, 1)],
#  [(732, 1), (2146, 1), (2147, 1), (2148, 1)],
#  [(11, 1)],
#  [(2149, 1), (2150, 1), (2151, 1)],
#  [(271, 1), (1885, 1), (2152, 1), (2153, 1), (2154, 1), (2155, 1)],
#  [(1248, 1)],
#  [(1370, 1), (2152, 1), (2153, 1), (2154, 1), (2156, 1), (2157, 1), (2158, 1)],
#  [(1465, 1), (2159, 1), (2160, 1), (2161, 1), (2162, 1)],
#  [(2163, 1), (2164, 1)],
#  [(527, 1)],
#  [(400, 1), (2165, 1), (2166, 1)],
#  [(2167, 1), (2168, 1), (2169, 1)],
#  [(2170, 1), (2171, 1)],
#  [(2172, 1)],
#  [(2023, 1), (2173, 1)],
#  [(297, 1)],
#  [(2174, 1)],
#  [(768, 1)],
#  [(2175, 1)],
#  [(95, 1)],
#  [(157, 1)],
#  [(67, 1)],
#  [(2176, 1)],
#  [(2177, 1), (2178, 1)],
#  [(152, 1)],
#  [(544, 1)],
#  [(2179, 1)],
#  [(1016, 1), (2180, 1)],
#  [(74, 1)],
#  [(202, 1), (261, 1), (311, 1), (1882, 1), (2181, 1), (2182, 1), (2183, 1)],
#  [(1954, 1), (1955, 1)],
#  [(1922, 1)],
#  [(251, 1)],
#  [(2184, 1), (2185, 1), (2186, 1), (2187, 1)],
#  [(2188, 1)],
#  [(850, 1), (2189, 1), (2190, 1)],
#  [(1865, 1), (2191, 1)],
#  [(2192, 1)],
#  [(1798, 1)],
#  [(2193, 1)],
#  [(2194, 1)],
#  [(1569, 1)],
#  [(1117, 1)],
#  [(2195, 1)],
#  [(248, 1), (768, 1), (1315, 1), (1798, 1), (2196, 1), (2197, 1), (2198, 1)],
#  [(101, 1)],
#  [(53, 1)],
#  [(382, 1), (2199, 1)],
#  [(2200, 1)],
#  [(53, 1), (1050, 1), (1802, 1)],
#  [(1334, 1)],
#  [(53, 1),
#   (147, 1),
#   (519, 1),
#   (1050, 1),
#   (1334, 1),
#   (1454, 1),
#   (1802, 1),
#   (1803, 1)],
#  [(1062, 1), (2201, 1), (2202, 1)],
#  [(1062, 1), (2203, 1), (2204, 1), (2205, 1), (2206, 1)],
#  [(252, 1), (624, 1)],
#  [(2207, 1)],
#  [(2208, 1)],
#  [(2209, 1)],
#  [(2210, 1), (2211, 1)],
#  ...]

# %%
from gensim.similarities import MatrixSimilarity, WmdSimilarity, SoftCosineSimilarity
docsim_index = SoftCosineSimilarity(bow_corpus, similarity_matrix, num_best=10)

# %%
for query in fabritius[:100]:
    print('============')
    print(' '.join(query).split())
    q = dictionary.doc2bow(query)
    sims = docsim_index[q]
    for idx, score in sims:
        print('   ', score, ':', iclass[idx], icodes[idx])
# Out:
# ============
# ['effet', 'de', 'ligne']
# ============
# ['figure', 'homme']
#     0.7071067690849304 : ('homme',) 82A(VALERIO)
#     0.7071067690849304 : ('Cérès', 'Ovide, Métamorphoses 05', 'Proserpine', 'Sirènes', 'chercher', 'compagnon', 'homme', 'mer') 97EE2
#     0.7071067690849304 : ('adulte', 'homme') 31D14(+55)
#     0.7071067690849304 : ('Lotis', 'Ovide, Métamorphoses 09', 'Priape', 'amour non partagé', 'fuir', 'homme', 'lotus') 97BB3
#     0.7071067690849304 : ('Grecs', 'Romains', 'homme', 'identité', 'nom', 'personnage historique') 98B(PROTOGENES)
#     0.7071067690849304 : ('homme',) 43C911
#     0.7071067690849304 : ('homme',) 11I72
#     0.7071067690849304 : ('adulte', 'homme') 31D14(+51)
#     0.7071067690849304 : ('homme',) 82A(NUMA POMPILIUS)
#     0.7071067690849304 : ('homme',) 82A(GUY OF WARWICK)
# ============
# ['figure', 'barbe']
#     0.7071067690849304 : ('barbe', 'vieillard') 11C23(+31)
#     0.7071067690849304 : ('barbe', 'droit (contraire de gauche)', 'gauche (contraire de droite)', 'poignard', 'poignarder') 71H8751
#     0.7071067690849304 : ('Ancien des jours', 'barbe', 'robe', 'trône', 'vieillard') 71P512
#     0.7071067690849304 : ('Hanûn (roi)', 'barbe', 'couper', 'maltraiter', 'messager', 'raser', 'roi', 'vêtements') 71H5251
#     0.7071067690849304 : ('barbe', 'vieillard') 11C23
#     0.7071067690849304 : ('barbe', 'vieillard') 11C23(+3)
#     0.7071067690849304 : ('Asie', 'barbe') 73B591
#     0.7071067690849304 : ('barbe',) 31A2532
#     0.7071067690849304 : ('barbe', 'enfant', 'paidogeron') 31D71
#     0.7071067690849304 : ('barbe',) 31A2532(+9341)
# ============
# ['groupe', 'de', 'figures', 'chapeau', 'homme']
#     0.5773502588272095 : ('adulte', 'homme') 31D14(+4)
#     0.5773502588272095 : ('homme',) 82A(CORYDON)
#     0.5773502588272095 : ('homme',) 82A(DON PIRLONE)
#     0.5773502588272095 : ('adulte', 'homme') 31D14(+78)
#     0.5773502588272095 : ('homme',) 43C911(+0)
#     0.5773502588272095 : ('adulte', 'homme') 31D14(+54)
#     0.5773502588272095 : ('homme',) 82A(FRITZ HAHNENFEDER)
#     0.5773502588272095 : ('homme',) 82A(MENALCAS)
#     0.5773502588272095 : ('adulte', 'homme') 31D14(+811)
#     0.5773502588272095 : ('aile', 'chapeau', 'pétase') 92B58(PETASUS)(+0)
# ============
# ['groupe', 'de', 'figures', 'assis', 'femme']
#     0.5773502588272095 : ('Grecs', 'Romains', 'femme', 'identité', 'nom', 'personnage historique') 98C(WIFE OF DRIGIAGONTIS)
#     0.5773502588272095 : ('belle', 'femme') 41D132
#     0.5773502588272095 : ('femme',) 48C8422(+1)
#     0.5773502588272095 : ('adulte', 'femme') 31D15(+912)
#     0.5773502588272095 : ('adulte', 'femme') 31D15(+923)
#     0.5773502588272095 : ('Weiberlisten', 'femme', 'femmes fatales', 'influence', 'influence pernicieuse') 33C1
#     0.5773502588272095 : ('Jérusalem', 'consoler', 'femme', 'lamenter', 'pleureuses') 73D414
#     0.5773502588272095 : ('femme',) 48C75512(+2)
#     0.5773502588272095 : ('Grecs', 'Romains', 'femme', 'identité', 'nom', 'personnage historique') 98C(PAULINA)
#     0.5773502588272095 : ('Goliath', 'Israélites', 'accueillir', 'chanter', 'danser', 'femme', 'jouer de la musique', 'lyre', 'montrer', 'tambourin', 'triomphe', 'tête') 71H1521
# ============
# ['groupe', 'de', 'figures', 'pinceau']
#     0.3451106548309326 : ('crayon',) 49L52
#     0.3202933669090271 : ('Joseph (St)', "Madonna (Vierge avec l'Enfant)", 'dessin', 'peinture') 11H(LUKE)51
#     0.3202933669090271 : ('amoureux', 'dessin', 'ombre', 'origine', 'peinture', 'silhouette') 98C(DEBUTADES)51(+0)
#     0.29088878631591797 : ('Franciscains', "Pierre d'Alcantara (St)", 'colombe', 'crucifix', 'crâne', 'encre', 'fouet', 'livre', 'moine', 'plume') 11H(PETER OF ALCANTARA)
#     0.29088878631591797 : ('Yves (St)', 'colombe', 'encre', 'livre', 'plume', 'rouleau') 11H(IVO)
#     0.2889707684516907 : ('encre',) 49L61
#     0.2580738365650177 : ('calligraphie', 'écrire avec soin') 49L4
#     0.2580738365650177 : ('calligraphie', 'écrire avec soin') 49L4(+3)
#     0.2531426250934601 : ('peinture',) 48C3531
#     0.2531426250934601 : ('Apelle', 'atelier', 'peintre', 'peinture') 98B(APELLES)
# ============
# ['intérieur', 'atelier']
#     0.7071067690849304 : ('intérieur',) 48C1426
#     0.7071067690849304 : ('intérieur', 'maison') 41A2
#     0.7071067690849304 : ('atelier',) 48C6111
#     0.7071067690849304 : ('intérieur',) 51A51(+4)
#     0.7071067690849304 : ('atelier',) 47A21(+21)
#     0.7071067690849304 : ('intérieur',) 51A51
#     0.7071067690849304 : ('atelier',) 47A11
#     0.7071067690849304 : ('intérieur',) 41A3372
#     0.7071067690849304 : ('intérieur',) 48C1412
#     0.7071067690849304 : ('atelier',) 47A11(+4)
# ============
# ['intérieur', 'chevalet']
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
#     0.7071067690849304 : ('chevalet',) 48C5151(+671)
#     0.7071067690849304 : ('intérieur',) 51A51
#     0.7071067690849304 : ('intérieur',) 41A3372
#     0.7071067690849304 : ('intérieur',) 46C216
#     0.7071067690849304 : ('intérieur',) 48C1412
#     0.7071067690849304 : ('intérieur',) 41A3362
#     0.7071067690849304 : ('intérieur',) 41A3362(+0)
#     0.7071067690849304 : ('chevalet',) 44G321(RACK)
#     0.7071067690849304 : ('intérieur',) 41C211
#     0.7071067690849304 : ('intérieur',) 51A51(+4)
# ============
# ['intérieur', 'tableau']
#     0.7071067690849304 : ('intérieur',) 48C1412
#     0.7071067690849304 : ('intérieur',) 41A3372
#     0.7071067690849304 : ('intérieur',) 51A51(+4)
#     0.7071067690849304 : ('intérieur',) 41A3362
#     0.7071067690849304 : ('intérieur',) 51A51
#     0.7071067690849304 : ('intérieur',) 46C216
#     0.7071067690849304 : ('intérieur', 'maison') 41A2
#     0.7071067690849304 : ('intérieur',) 48C1426
#     0.7071067690849304 : ('intérieur',) 41A3362(+0)
#     0.7071067690849304 : ('intérieur', 'église') 11Q713
# ============
# ['intérieur', 'toile']
#     0.7071067690849304 : ('intérieur',) 46C216
#     0.7071067690849304 : ('intérieur',) 51A51
#     0.7071067690849304 : ('intérieur',) 51A51(+4)
#     0.7071067690849304 : ('intérieur',) 48C1426
#     0.7071067690849304 : ('intérieur',) 41A3372
#     0.7071067690849304 : ('intérieur',) 41C211
#     0.7071067690849304 : ('intérieur',) 41A3362
#     0.7071067690849304 : ('intérieur', 'maison') 41A2
#     0.7071067690849304 : ('intérieur',) 48C1412
#     0.7071067690849304 : ('intérieur', 'église') 11Q713
# ============
# ['intérieur', 'table']
#     0.7071067690849304 : ('intérieur',) 41A3362(+0)
#     0.7071067690849304 : ('bureau', 'table') 49L66
#     0.7071067690849304 : ('nature morte', 'table') 41C38
#     0.7071067690849304 : ('table',) 41A711(+0)
#     0.7071067690849304 : ('grâce', 'repas', 'table') 11Q2111
#     0.7071067690849304 : ('intérieur',) 48C1412
#     0.7071067690849304 : ('intérieur',) 41A3362
#     0.7071067690849304 : ('intérieur', 'maison') 41A2
#     0.7071067690849304 : ('table',) 41A711(+4)
#     0.7071067690849304 : ('repas', 'table') 71H53122
# ============
# ['intérieur', 'livre']
#     0.7071067690849304 : ('intérieur',) 51A51
#     0.7071067690849304 : ('intérieur',) 51A51(+4)
#     0.7071067690849304 : ('livre', 'ordre') 48C163
#     0.7071067690849304 : ('Antoine de Padoue (St)', 'Franciscains', 'coeur enflammé', 'croix', 'crucifix', 'enfant Jésus', 'fleur', 'lis', 'livre', 'moine', 'âne') 11H(ANTONY OF PADUA)
#     0.7071067690849304 : ('Odile (Ste)', 'abbesse', 'coq', 'couronne', 'fonts baptismaux', 'livre', 'oeil', 'plat', 'reine') 11HH(ODILIA)
#     0.7071067690849304 : ('Matthias (St)', 'Paul (St)', 'apôtre', 'douze', 'groupe', 'livre', 'rouleau', 'substitution') 11I3(+0)
#     0.7071067690849304 : ('Augustin (St)', 'coeur', 'coeur enflammé', 'cuiller', 'enfant', 'flèche', 'livre', 'percer', 'plume', 'poitrine', 'évêque') 11H(AUGUSTINE)
#     0.7071067690849304 : ('Augustiniens', 'Nicolas de Tolentino (St)', 'colombe', 'corbeille', 'crucifix', 'ermite', 'lis', 'livre', 'pain', 'plat', 'poitrine', "voler (dans l'air)", 'étoile') 11H(NICHOLAS OF TOLENTINO)
#     0.7071067690849304 : ('agneau', 'livre', 'sceau', 'sept', 'vision') 73G22
#     0.7071067690849304 : ('Bernardin de Sienne (St)', 'Franciscains', 'IHS monogramme', 'livre', 'mitre', 'moine', 'tablette') 11H(BERNARDINO)
# ============
# ['intérieur', 'fleur']
#     0.7071067690849304 : ('fleur',) 48A9833(+2)
#     0.7071067690849304 : ('fleur',) 25G41(+35)
#     0.7071067690849304 : ('intérieur',) 48C1412
#     0.7071067690849304 : ('Chloris', 'Flore', 'enlever', 'fleur', 'répandre') 92E5421
#     0.7071067690849304 : ('fleur',) 25G41(+15)
#     0.7071067690849304 : ('fleur',) 25G41
#     0.7071067690849304 : ('Cupidon', 'Péristère', 'Vénus', 'colombe', 'combat', 'compétition', 'cueillir', 'défier', 'fleur', 'se vanter') 97DD29
#     0.7071067690849304 : ('fleur',) 25G41(+32)
#     0.7071067690849304 : ('intérieur',) 41A3362
#     0.7071067690849304 : ('caresser', 'décorer', 'fleur', 'guirlande', 'jouer', 'parer') 92B12181
# ============
# ['figure', 'en', 'buste', 'femme']
#     0.5773502588272095 : ('adulte', 'femme') 31D15(+76)
#     0.5773502588272095 : ('femme',) 43C912
#     0.5773502588272095 : ('femme', 'stérilité') 42A19
#     0.5773502588272095 : ('femme', 'femme déchue') 33C44
#     0.5773502588272095 : ('adulte', 'femme') 31D15(+77)
#     0.5773502588272095 : ('adulte', 'femme') 31D15(+51)
#     0.5773502588272095 : ('adulte', 'femme') 31D15(+52)
#     0.5773502588272095 : ('Bacchus', 'déchirer en pièces', 'extase', 'femme', 'femmes de Thrace', 'mort', 'orgie') 94O68
#     0.5773502588272095 : ('adulte', 'femme') 31D15(+93231)
#     0.5773502588272095 : ('Grecs', 'Romains', 'femme', 'identité', 'nom', 'personnage historique') 98C(XANTHUS' WIFE)
# ============
# ['figure', 'de', 'profil']
#     0.18657433986663818 : ('cabestan', 'guindeau', 'proue') 46C215(BOW)
#     0.16029441356658936 : ('illustration', "livre d'illustration") 49M41
#     0.15512818098068237 : ('Standbein und Spielbein', 'contrapposto') 31A2311
#     0.14815066754817963 : ('portrait',) 98B(TITUS)9
#     0.14815066754817963 : ('portrait',) 98B(DIOSCORIDES)9
#     0.14815066754817963 : ('portrait',) 98B(TERENTIUS AFER, P.)9
#     0.14815066754817963 : ('portrait',) 98B(AUGUSTUS)9
#     0.14815066754817963 : ('portrait',) 98B(GRATIANUS)9
#     0.14815066754817963 : ('portrait',) 98B(AURELIAN)9
#     0.14815066754817963 : ('portrait',) 11F22
# ============
# ['figure', 'en', 'pied', 'homme', 'nu']
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
#     0.6079320311546326 : ('Corpo humano', 'Ripa', 'corps', 'femme', 'figure humaine', 'homme', 'nu') 31A(+3)
#     0.6079320311546326 : ('Corpo humano', 'Ripa', 'corps', 'femme', 'figure humaine', 'homme', 'nu') 31A(+9225)
#     0.6079320311546326 : ('Corpo humano', 'Ripa', 'corps', 'femme', 'figure humaine', 'homme', 'nu') 31A(+9412)
#     0.6079320311546326 : ('Corpo humano', 'Ripa', 'corps', 'femme', 'figure humaine', 'homme', 'nu') 31A(+9224)
#     0.6079320311546326 : ('Corpo humano', 'Ripa', 'corps', 'femme', 'figure humaine', 'homme', 'nu') 31A(+935)
#     0.6079320311546326 : ('Corpo humano', 'Ripa', 'corps', 'femme', 'figure humaine', 'homme', 'nu') 31A(+823)
#     0.6079320311546326 : ('Corpo humano', 'Ripa', 'corps', 'femme', 'figure humaine', 'homme', 'nu') 31A(+9213)
#     0.6079320311546326 : ('Corpo humano', 'Ripa', 'corps', 'femme', 'figure humaine', 'homme', 'nu') 31A(+821)
#     0.6079320311546326 : ('Corpo humano', 'Ripa', 'corps', 'femme', 'figure humaine', 'homme', 'nu') 31A(+72)
#     0.6079320311546326 : ('Corpo humano', 'Ripa', 'corps', 'femme', 'figure humaine', 'homme', 'nu') 31A(+812)
# ============
# ['figure', 'joint', 'main']
#     0.5773502588272095 : ('main',) 31A2245(+916)
#     0.5773502588272095 : ('Louis IX (St)', 'clou', "couronne d'épines", 'fleur-de-lis', 'justice', 'main', 'modèle', 'roi', 'sceptre', 'trois', 'église') 11H(LOUIS IX)
#     0.5773502588272095 : ('calice', 'corde', 'dé', 'main', 'marteau', 'échelle', 'éponge') 73D82(PINCERS)
#     0.5773502588272095 : ('ange', 'main', 'mains serrés') 71C131311
#     0.5773502588272095 : ('Porsenna', 'cadavre', 'devant', 'droit (contraire de gauche)', 'feu', 'main', 'ordalie') 98B(SCAEVOLA, C.M.)61
#     0.5773502588272095 : ('lier', 'main') 44G3121
#     0.5773502588272095 : ('main',) 31A2245(+934)
#     0.5773502588272095 : ('Acheiroi', 'main') 31A4414
#     0.5773502588272095 : ('exemple judiciaire', 'main', 'oreille') 98B(ALEXANDER THE GREAT)5392
#     0.5773502588272095 : ('main', 'plaie', 'toucher', 'étendre') 73E365
# ============
# ['intérieur', 'ouvert', 'porte']
#     0.5773502588272095 : ('litanie', 'porta clausa', 'porte', 'porte fermée') 71O9344
#     0.5773502588272095 : ('entrée de chevaux', 'palais', 'porte', 'soldat', 'tuer') 71L172
#     0.5773502588272095 : ('porte', 'péage') 44D221
#     0.5773502588272095 : ('frapper', 'porte') 33A31(+0)
#     0.5773502588272095 : ('porte',) 11T42
#     0.5773502588272095 : ('Luc 13', 'Matthieu 07', 'chemin', 'destruction', 'large', 'porte', 'étroit') 73C7454(+0)
#     0.5773502588272095 : ('entrer', 'porte', "refuser (l'entrée)") 73C8413
#     0.5773502588272095 : ('intérieur',) 51A51(+4)
#     0.5773502588272095 : ('battre', 'demander', 'entourer', 'foule', 'frapper', 'homosexuel', 'maison', 'porte', 'sodomie') 71C12332
#     0.5773502588272095 : ('intérieur',) 48C1412
# ============
# ['effet', 'de', 'ligne']
# ============
# ['groupe', 'de', 'figures', 'homme']
#     0.7071067690849304 : ('Grecs', 'Romains', 'homme', 'identité', 'nom', 'personnage historique') 98B(STRABO)
#     0.7071067690849304 : ('Grecs', 'Romains', 'homme', 'identité', 'nom', 'personnage historique') 98B(MAURITIUS)
#     0.7071067690849304 : ('Grecs', 'Romains', 'homme', 'identité', 'nom', 'personnage historique') 98B(MARINUS OF TYRE)
#     0.7071067690849304 : ('Genèse 18', 'Trinité', 'ange', 'homme', 'trois', 'visiter') 71C122
#     0.7071067690849304 : ('Grecs', 'Romains', 'homme', 'identité', 'nom', 'personnage historique') 98B(POLYBIUS)
#     0.7071067690849304 : ('Grecs', 'Romains', 'homme', 'identité', 'nom', 'personnage historique') 98B(PTOLOMAEUS)
#     0.7071067690849304 : ('Grecs', 'Romains', 'homme', 'identité', 'nom', 'personnage historique') 98B(HIPPARCHUS)
#     0.7071067690849304 : ('Grecs', 'Romains', 'homme', 'identité', 'nom', 'personnage historique') 98B(TIBERIUS II)
#     0.7071067690849304 : ('Grecs', 'Romains', 'homme', 'identité', 'nom', 'personnage historique') 98B(AULUS VITELLIUS GERMANICUS)
#     0.7071067690849304 : ('homme',) 97AA9
# ============
# ['groupe', 'de', 'figures', 'femme']
#     0.7071067690849304 : ('femme', 'femme déchue') 33C44
#     0.7071067690849304 : ('adulte', 'femme') 31D15(+3)
#     0.7071067690849304 : ('Weiberlisten', 'femme', 'femmes fatales', 'influence', 'influence pernicieuse') 33C1(+0)
#     0.7071067690849304 : ('adulte', 'femme') 31D15(+915)
#     0.7071067690849304 : ('animal', 'femme', 'oiseau') 97DD
#     0.7071067690849304 : ('adulte', 'femme') 31D15(+93231)
#     0.7071067690849304 : ('Bacchus', 'déchirer en pièces', 'extase', 'femme', 'femmes de Thrace', 'mort', 'orgie') 94O68
#     0.7071067690849304 : ('adulte', 'femme') 31D15(+52)
#     0.7071067690849304 : ('femme',) 41D92
#     0.7071067690849304 : ('femme',) 11I63
# ============
# ['groupe', 'de', 'figures', 'foule']
#     0.7071067690849304 : ('adoration', 'blanc', 'foule', 'robe') 73G222
#     0.7071067690849304 : ('foule',) 46A7(+0)
#     0.7071067690849304 : ('Cédron (ruisseau)', 'citoyen', 'foule', 'pleurer', 'ruisseau', 'serviteur', 'soldat') 71H8343
#     0.7071067690849304 : ('chercher', 'foule', 'lanterne', 'marché', 'être humain') 98B(DIOGENES)52
#     0.7071067690849304 : ('adresser', 'foule') 71M42(+31)
#     0.7071067690849304 : ('adresser', 'foule') 71M42
#     0.7071067690849304 : ('calmer', 'foule') 71C12333
#     0.7071067690849304 : ('chercher', 'foule', 'lanterne', 'marché', 'être humain') 98B(DIOGENES)52(+53)
#     0.7071067690849304 : ('battre', 'demander', 'entourer', 'foule', 'frapper', 'homosexuel', 'maison', 'porte', 'sodomie') 71C12332
#     0.7071067690849304 : ('chasser', 'foule', 'indemne') 73C72441
# ============
# ['groupe', 'de', 'figures', 'soldat']
#     0.7071067690849304 : ('soldat',) 45M2
#     0.7071067690849304 : ('lance', 'quatre', 'soldat', 'tuer') 73F2955
#     0.7071067690849304 : ('soldat',) 45B(+0)
#     0.7071067690849304 : ('Noli turbare circulos meos', 'cercle', 'dessin', 'diagramme', 'sable', 'soldat', 'tuer') 98B(ARCHIMEDES)68
#     0.7071067690849304 : ('Césarée', 'lettre (épître)', 'soldat') 73F22365
#     0.7071067690849304 : ('commander', 'diviser', 'ordonner', 'soldat', 'verdict') 71I325
#     0.7071067690849304 : ('dé', 'soldat', 'sort', 'tunique sans coutures') 73D622(+0)
#     0.7071067690849304 : ('dé', 'soldat', 'sort', 'tunique sans coutures') 73D622
#     0.7071067690849304 : ('soldat',) 45B(+2)
#     0.7071067690849304 : ('Chrysaor', 'Pégase', 'or', 'sang', 'soldat', 'épée') 94P331
# ============
# ['groupe', 'de', 'figures', 'casque']
#     0.7071067690849304 : ('Achille', 'Cycnus (fils de Neptune)', 'casque', 'tuer', 'étrangler') 94E12
#     0.7071067690849304 : ('casque', 'clef') 92N18(SCEPTRE WITH TWO TEETH)
#     0.7071067690849304 : ('casque',) 45C221(+0)
#     0.7071067690849304 : ('casque',) 45C221
#     0.5807095766067505 : ('armure', 'casque', 'loup') 92B48(HELMET)
#     0.5807095766067505 : ('armure', 'casque', 'loup') 92B48(TORCH)
#     0.5807095766067505 : ('armure', 'casque', 'loup') 92B48(SWORD)
#     0.5807095766067505 : ('Bénédictins', "Guillaume d'Aquitaine (St)", 'armure', 'bannière', 'casque', 'duc', 'moine') 11H(WILLIAM OF AQUITAINE)
#     0.5807095766067505 : ('armure', 'casque', 'loup') 92B48(SHIELD)
#     0.5807095766067505 : ('armure', 'casque', 'loup') 92B48(ARMOUR)
# ============
# ['groupe', 'de', 'figures', 'arme', 'lance']
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
#     0.5773502588272095 : ('Longin (St)', 'flanc', 'lance', 'percer') 73D633
#     0.5773502588272095 : ('Thomas (St)', 'apôtre', 'calice', 'ceinture', 'coeur', 'lance', 'livre', 'pierre', 'rouleau', 'équerre') 11H(THOMAS)
#     0.5773502588272095 : ('lance',) 92C28(SPEAR)
#     0.5773502588272095 : ('arme',) 31E2346
#     0.5773502588272095 : ('arme',) 45C1(+69)
#     0.5773502588272095 : ('Diane', 'Lélaps', 'chien', 'donner', 'lance', 'magique') 95A(CEPHALUS)212
#     0.5773502588272095 : ('lance',) 73D82(LANCE)
#     0.5773502588272095 : ('arc et carquois', 'carquois', 'cerf', 'chien', 'lance') 92C38(BOW)
#     0.5773502588272095 : ('arc et carquois', 'carquois', 'cerf', 'chien', 'lance') 92C38(STAG)
#     0.5773502588272095 : ('Christ', "François d'Assise (St)", 'Marie (Vierge)', 'avarice', 'convoitise', 'flèche', 'genre humain', 'intercéder', 'lance', 'luxure', 'menacer', 'orgueil', 'présenter (personne)', 'péché', 'trois') 11H(DOMINIC)343
# ============
# ['groupe', 'de', 'figures', 'animal', 'cheval', 'chien']
#     0.7005470395088196 : ('chien',) 34B11(+924)
#     0.7005470395088196 : ('chien',) 34B11(+9513)
#     0.7005470395088196 : ('chien',) 34B11(+9547)
#     0.7005470395088196 : ('chien',) 34B11(+95246)
#     0.7005470395088196 : ('arc et carquois', 'carquois', 'cerf', 'chien', 'lance') 92C38(JAVELIN)
#     0.7005470395088196 : ('chien',) 34B11(+9452)
#     0.7005470395088196 : ('Bernard de Clairvaux (St)', 'Cisterciens', 'abbé', 'blanc', 'chien', 'croix', 'crucifix', 'dragon', 'enchaîner', 'instruments de la Passion', 'mitre', 'ruche') 11H(BERNARD)
#     0.7005470395088196 : ('chien',) 34B11(+53)
#     0.7005470395088196 : ('Athènes', 'chien', 'couper', 'queue') 98B(ALCIBIADES)41
#     0.7005470395088196 : ('Dominique (St)', 'Ordre des Frères Dominicains', 'chien', 'lis', 'livre', 'moine', 'pain', 'rosaire', 'torche', 'étoile') 11H(DOMINIC)
# ============
# ['groupe', 'de', 'figures', 'coiffure']
#     0.5672897696495056 : ('cheveux', 'coiffure') 31A53
#     0.5672897696495056 : ('cheveux', 'coiffure') 31A53(+0)
#     0.5672897696495056 : ('cheveux', 'coiffure') 31A53(+921)
#     0.5672897696495056 : ('cheveux', 'coiffure') 31AA53
#     0.3152753412723541 : ('coiffeur',) 31A5321
#     0.3152753412723541 : ('coiffeur',) 31AA5321
#     0.287373811006546 : ('robe', 'vêtements') 12A5211
#     0.287373811006546 : ('canoniques', 'robe', 'vêtements') 11Q7146
#     0.2837381362915039 : ('perruque',) 31AA5331
#     0.2837381362915039 : ('perruque',) 31A5331
# ============
# ['groupe', 'de', 'figures', 'couronne', 'épine']
#     0.5773502588272095 : ('Melchisédec', 'couronne', 'mitre', 'prêtre', 'robe') 11I62(MELCHIZEDEK)
#     0.5773502588272095 : ('Josse (St)', 'couronne', 'ermite', 'prince', 'pèlerin') 11H(JUDOC)
#     0.5773502588272095 : ('alpha et oméga', 'couronne', 'instruments de la Passion', 'oméga', 'triangle') 11D111
#     0.5773502588272095 : ('arracher', 'griffe', 'guérir', 'épine') 11H(JEROME)51
#     0.5773502588272095 : ('Spinario', 'arracher', 'épine') 31A523(+0)
#     0.5773502588272095 : ('IHS monogramme', 'Ignace de Loyola (St)', 'Jésuites', 'ad majorem Dei gloriam', 'coeur enflammé', 'couronne', 'crâne', 'dragon', 'démon', 'flamme', 'globe', 'inscription', 'larme', 'livre', 'moine', 'torche') 11H(IGNATIUS)
#     0.5773502588272095 : ('Barbe (Ste)', 'Dioscure', 'boulet de canon', 'calice', 'canon (arme)', 'couronne', 'croix', 'hostie', 'martyr', 'outil', 'outillage de maçonnerie', 'plume', 'plume de paon', 'torche', 'tour', 'vierge', 'épée') 11HH(BARBARA)
#     0.5773502588272095 : ('Apollyôn', 'couronne', 'diable', 'peste', 'sauterelle') 73G3251
#     0.5773502588272095 : ('ancien', 'bête', 'couronne', 'harpe', 'quatre', 'vingt-quatre') 73G211
#     0.5773502588272095 : ('bénir', 'couronne') 11D335(+0)
# ============
# ['groupe', 'de', 'figures', 'nu']
#     0.7071067690849304 : ('Corpo humano', 'Ripa', 'corps', 'femme', 'figure humaine', 'homme', 'nu') 31A(+9225)
#     0.7071067690849304 : ('Corpo humano', 'Ripa', 'corps', 'femme', 'figure humaine', 'homme', 'nu') 31A(+76)
#     0.7071067690849304 : ('Corpo humano', 'Ripa', 'corps', 'femme', 'figure humaine', 'homme', 'nu') 31A(+79)
#     0.7071067690849304 : ('Corpo humano', 'Ripa', 'corps', 'femme', 'figure humaine', 'homme', 'nu') 31A(+75)
#     0.7071067690849304 : ('Corpo humano', 'Ripa', 'corps', 'femme', 'figure humaine', 'homme', 'nu') 31A(+9213)
#     0.7071067690849304 : ('Corpo humano', 'Ripa', 'corps', 'femme', 'figure humaine', 'homme', 'nu') 31A(+9224)
#     0.7071067690849304 : ('Corpo humano', 'Ripa', 'corps', 'femme', 'figure humaine', 'homme', 'nu') 31A(+934)
#     0.7071067690849304 : ('Corpo humano', 'Ripa', 'corps', 'femme', 'figure humaine', 'homme', 'nu') 31A(+3)
#     0.7071067690849304 : ('Corpo humano', 'Ripa', 'corps', 'femme', 'figure humaine', 'homme', 'nu') 31A(+933)
#     0.7071067690849304 : ('Corpo humano', 'Ripa', 'corps', 'femme', 'figure humaine', 'homme', 'nu') 31A(+56)
# ============
# ['abstrait']
#     0.31876736879348755 : ('art', "histoire de l'art") 49K2
#     0.31876736879348755 : ('art',) 48(+354)
#     0.31876736879348755 : ('art',) 48(+122)
#     0.31876736879348755 : ('art',) 48(+76111)
#     0.31876736879348755 : ('art',) 48(+351)
#     0.31876736879348755 : ('art',) 48(+726)
#     0.31876736879348755 : ('art',) 48(+382)
#     0.31876736879348755 : ('art',) 48(+342)
#     0.31876736879348755 : ('art',) 48(+343)
#     0.31876736879348755 : ('art',) 48(+42211)
# ============
# ['effet', 'de', 'ligne']
# ============
# ['figure', 'en', 'pied', 'femme']
#     0.5773502588272095 : ('adulte', 'femme') 31D15(+51)
#     0.5773502588272095 : ('Bacchus', 'déchirer en pièces', 'extase', 'femme', 'femmes de Thrace', 'mort', 'orgie') 94O68
#     0.5773502588272095 : ('Grecs', 'Romains', 'femme', 'identité', 'nom', 'personnage historique') 98C(PAULINA)
#     0.5773502588272095 : ('adulte', 'femme') 31D15(+78)
#     0.5773502588272095 : ('adulte', 'femme') 31D15(+9411)
#     0.5773502588272095 : ('Bona Dea', 'César (Jules)', 'déguisement', 'femme', 'festival', 'trouver') 98B(CLODIUS PULCHER, P.)51
#     0.5773502588272095 : ('Grecs', 'Romains', 'femme', 'identité', 'nom', 'personnage historique') 98C(XANTHUS' WIFE)
#     0.5773502588272095 : ('adulte', 'femme') 31D15(+3)
#     0.5773502588272095 : ('femme', 'stérilité') 42A19
#     0.5773502588272095 : ('femme', 'femme déchue') 33C44
# ============
# ['figure', 'de', 'profil']
#     0.18657433986663818 : ('cabestan', 'guindeau', 'proue') 46C215(BOW)
#     0.16029441356658936 : ('illustration', "livre d'illustration") 49M41
#     0.15512818098068237 : ('Standbein und Spielbein', 'contrapposto') 31A2311
#     0.14815066754817963 : ('portrait',) 98B(TITUS)9
#     0.14815066754817963 : ('portrait',) 98B(DIOSCORIDES)9
#     0.14815066754817963 : ('portrait',) 98B(TERENTIUS AFER, P.)9
#     0.14815066754817963 : ('portrait',) 98B(AUGUSTUS)9
#     0.14815066754817963 : ('portrait',) 98B(GRATIANUS)9
#     0.14815066754817963 : ('portrait',) 98B(AURELIAN)9
#     0.14815066754817963 : ('portrait',) 11F22
# ============
# ['figure', 'robe', 'vêtement']
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
#     0.7151807546615601 : ('robe', 'vêtements') 12A5211
#     0.7151807546615601 : ('canoniques', 'robe', 'vêtements') 11Q7146
#     0.6795544624328613 : ('Esther 05', 'Esther 15', 'robe', 'toilette (faire la)') 71Q56
#     0.6795544624328613 : ('colobium', 'robe') 73D6711
#     0.6795544624328613 : ('robe',) 41D211(+6)
#     0.6795544624328613 : ('robe',) 41D211(+43)
#     0.6795544624328613 : ('robe',) 41D211
#     0.6795544624328613 : ('Melchisédec', 'couronne', 'mitre', 'prêtre', 'robe') 11I62(MELCHIZEDEK)
#     0.6795544624328613 : ('robe',) 41D211(+83)
#     0.6795544624328613 : ('couper', 'robe') 71H234
# ============
# ['figure', 'noeud']
#     0.7071067690849304 : ('Ambroise (St)', 'berceau', 'bébé', 'fouet', 'noeud', 'ruche', 'trois', 'évêque') 11H(AMBROSE)
#     0.7071067690849304 : ('noeud',) 41D2654
#     0.7071067690849304 : ('art abstrait', 'noeud') 48A98781
#     0.7071067690849304 : ('noeud',) 47C421
#     0.18657433986663818 : ('cabestan', 'guindeau', 'proue') 46C215(BOW)
#     0.17863041162490845 : ('corde', 'ficelle') 34B133
#     0.17863041162490845 : ('corde', 'ficelle') 34B133(+0)
#     0.16029441356658936 : ('illustration', "livre d'illustration") 49M41
#     0.15512818098068237 : ('Standbein und Spielbein', 'contrapposto') 31A2311
#     0.15474626421928406 : ('Ocnus', 'corde', 'fabrication de corde', 'manger', 'tourner', 'âne') 93E86
# ============
# ['figure', 'chapeau']
#     0.7071067690849304 : ('Charles Borromée (St)', 'archevêque', 'cardinal', 'chapeau', 'corde', 'crucifix', 'crâne', 'insignes du cardinal') 11H(CHARLES BORROMEO)
#     0.7071067690849304 : ('aile', 'chapeau', 'pétase') 92B58(PETASUS)(+0)
#     0.7071067690849304 : ('chapeau', 'voile') 41D2211
#     0.7071067690849304 : ('Jérôme (St)', 'chapeau', 'crucifix', 'crâne', 'ermite', 'insignes du cardinal', 'lion', 'livre', 'pierre', 'sablier') 11H(JEROME)
#     0.7071067690849304 : ('Birgita (Ste)', 'Bridget (Ste)', 'Brigitte (Ste)', 'abbesse', 'bande', 'bougie', 'bourdon', 'chapeau', 'coeur', 'croix', 'encrier', 'habits de pèlerin', 'livre', 'sac', 'veuve', 'voile') 11HH(BRIDGET)
#     0.7071067690849304 : ('Roch (St)', 'ange', 'bourdon', 'boîte', 'bubon', 'chapeau', 'chien', 'confesseur', 'coquillage', 'coquille', 'cuiller', 'cuisse', 'habits de pèlerin', 'médecin', 'onguent', 'pain', 'peste', 'pèlerin', 'sac', 'ulcère') 11H(ROCH)
#     0.7071067690849304 : ('aile', 'chapeau', 'pétase') 92B58(PETASUS)
#     0.7071067690849304 : ('chapeau', 'voile') 41D2211(+82)
#     0.7071067690849304 : ('chapeau',) 12A9322
#     0.7071067690849304 : ('bonnet phrygien', 'chapeau') 41D2212
# ============
# ['figure', 'animal', 'chien']
#     0.6861110925674438 : ('animal', 'exercice', 'jeux', 'sport') 43C1(+412)
#     0.6861110925674438 : ('animal',) 25F(+491)
#     0.6861110925674438 : ('chien',) 34B11(+951)
#     0.6861110925674438 : ('chien', 'chien policier') 44G242
#     0.6861110925674438 : ('animal', 'exercice', 'jeux', 'sport') 43C1(+4112)
#     0.6861110925674438 : ('chien',) 34B11(+53)
#     0.6861110925674438 : ('Athènes', 'chien', 'couper', 'queue') 98B(ALCIBIADES)41
#     0.6861110925674438 : ('animal', 'exercice', 'jeux', 'sport') 43C1(+4111)
#     0.6861110925674438 : ('animal',) 25F(+64)
#     0.6861110925674438 : ('animal', 'exercice', 'jeux', 'sport') 43C1(+4171)
# ============
# ['mer']
#     1.0 : ('côte', 'mer') 25K13
#     1.0 : ('herbe', 'manger', 'mer', 'noyer', 'poisson', 'pêcheur', 'sauter') 95A(GLAUCUS)68
#     1.0 : ('brûler', 'mer', 'montagne') 73G322
#     1.0 : ('côte', 'mer') 25H13(+1)
#     1.0 : ('666', 'Antéchrist', 'bête', 'mer') 73G42
#     1.0 : ('Néréides', 'cadavre', 'mer', 'noyer', 'porter', 'sauter', 'suicide') 95B(HERO & LEANDER)22
#     1.0 : ('Anadyomène (Vénus)', 'Heures', 'Vénus Anadyomène', 'castration', 'cheveux', 'mer', 'naissance', 'tordre', 'émerger') 92C411
#     1.0 : ('marine (peinture)', 'mer') 25H23(+0)
#     1.0 : ('Anadyomène (Vénus)', 'Heures', 'Vénus Anadyomène', 'castration', 'cheveux', 'mer', 'naissance', 'tordre', 'émerger') 92C411(+0)
#     1.0 : ('bateau', 'eaux', 'fêtes publiques', 'mer') 43A4(+12)
# ============
# ['plage']
#     1.0 : ('plage',) 43B5
#     1.0 : ('plage',) 25H133
#     0.7612003087997437 : ('coquillage', 'marcher', 'plage', 'remplir', 'rencontrer', 'rivage', 'sable', 'trou') 11H(AUGUSTINE)342
#     0.3033525049686432 : ('rade',) 46C222
#     0.3023544251918793 : ('rivage', 'serpent') 94O6812
#     0.3023544251918793 : ('Tyr', 'adieux', 'prier', 'rivage') 73F22353
#     0.3023544251918793 : ('Apollon', 'Orphée', 'Ovide, Métamorphoses 11', 'rivage', 'tête') 97N71
#     0.3023544251918793 : ('dormir', 'oiseau', 'rivage', 'tigre', 'transformation', "tronc d'arbre", 'violer') 92I21211
#     0.3023544251918793 : ('deuil', 'pleurer la mort', 'rivage') 95B(HERO & LEANDER)221
#     0.3023544251918793 : ('Hector', 'Protésilas', 'bateau', 'rivage', 'sauter', 'tuer') 94E11
# ============
# ['nuage']
#     1.0 : ("Madonna (Vierge avec l'Enfant)", "air (dans l')", 'nuage') 11F5
#     1.0 : ('nuage',) 92I212132
#     1.0 : ('Io', 'Junon', 'courtiser', 'nuage', 'regarder') 92B1219(+0)
#     1.0 : ('asseoir', 'debout', 'nuage') 31A27631(+9341)
#     1.0 : ('Dieu', 'Exode 40', 'Nombres 09', 'camp', 'couvrir', 'gloire', 'nuage', 'partir') 71E13852
#     1.0 : ('asseoir', 'debout', 'nuage') 31A27631(+1)
#     1.0 : ('nuage',) 26A
#     1.0 : ('informer', 'nuage') 71M4511
#     1.0 : ("air (dans l')", 'cercle', 'cercles concentrique', 'lumière', 'nuage') 11S11
#     1.0 : ('asseoir', 'debout', 'nuage') 31AA27631
# ============
# ['bateau']
#     1.0 : ('Erasme (St)', 'bateau', 'cabestan', 'chaudron', 'clou', 'martyr', 'treuil', 'évêque') 11H(ERASMUS)
#     1.0 : ('bateau',) 46C21(+32)
#     1.0 : ('bateau',) 46C183
#     1.0 : ('ange', 'bateau', 'enseignant', 'nourrice', 'échapper') 11H(VITUS)51
#     1.0 : ('bateau',) 58B213(+4)
#     1.0 : ('bateau', 'propulsion') 46C23(+52)
#     1.0 : ('Narrenschiff', 'Nef des fous (la)', 'bateau', 'fou') 43A1221
#     1.0 : ('bateau',) 46C21(+64)
#     1.0 : ('bateau',) 43C78421
#     1.0 : ('Vincent (St)', 'bateau', 'clou', 'corbeau', 'dalmatique', 'diacre', 'grappe', 'gril', 'livre', 'martyr', 'meule') 11H(VINCENT)
# ============
# ['figure', 'assis', 'femme']
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
#     0.5773502588272095 : ('adulte', 'femme') 31D15(+52)
#     0.5773502588272095 : ('Hécube', 'Minerve', 'femme', 'femmes troyennes', 'prier', 'temple') 94F52
#     0.5773502588272095 : ('chanteur', "chanteuse d'opéra", 'femme') 48C8622
#     0.5773502588272095 : ('Grecs', 'Romains', 'femme', 'identité', 'nom', 'personnage historique') 98C(MYRTO)
#     0.5773502588272095 : ('animal', 'femme', 'mammifère') 97CC
#     0.5773502588272095 : ('Grecs', 'Romains', 'femme', 'identité', 'nom', 'personnage historique') 98C(PAULINA)
#     0.5773502588272095 : ('femme',) 43C912
#     0.5773502588272095 : ('femme',) 48C75512
#     0.5773502588272095 : ('femme',) 48C8422
#     0.5773502588272095 : ('femme',) 48CC75512
# ============
# ['figure', 'nu']
# ...
#     0.15777337551116943 : ('inspecter', 'nuit') 71R321
#     0.15777337551116943 : ('nuit',) 49B4411
#     0.15777337551116943 : ('Hellespont', 'guider', 'nager', 'nuit', 'torche', 'tour') 95B(HERO & LEANDER)21(+0)
# ============
# ['groupe', 'de', 'figures', 'chape']
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
#     0.7071067690849304 : ('Franciscains', "Louis d'Anjou (St)", 'Toulouse', 'chape', 'couronne', 'fleur-de-lis', 'sceptre', 'évêque') 11H(LOUIS OF TOULOUSE)
#     0.513996958732605 : ('chape', 'dalmatique', 'pallium', 'rational', 'surplis', 'toge', 'tunicelle') 11Q71467(DALMATIC)
#     0.513996958732605 : ('chape', 'dalmatique', 'pallium', 'rational', 'surplis', 'toge', 'tunicelle') 11Q71467(COPE)
#     0.2842371463775635 : ('Thomas Becket (St)', 'archevêque', 'chasuble', 'crâne', 'martyr', 'rouge', 'épée') 11H(THOMAS BECKET)
#     0.2842371463775635 : ('chasuble',) 11Q71463
#     0.26322656869888306 : ('Jacques le Majeur (St)', 'apôtre', 'bourdon', 'chapeau', 'coquillage', 'coquille', 'habits de pèlerin', 'livre', 'manteau', 'rouleau', 'sac', 'épée') 11H(JAMES THE GREAT)(+0)
#     0.26322656869888306 : ('bourdon', 'chapeau', 'gourde', 'habits de pèlerin', 'manteau', 'sac') 11Q624
#     0.26322656869888306 : ('Jacques le Majeur (St)', 'apôtre', 'bourdon', 'chapeau', 'coquillage', 'coquille', 'habits de pèlerin', 'livre', 'manteau', 'rouleau', 'sac', 'épée') 11H(JAMES THE GREAT)
#     0.26322656869888306 : ('chapeau', 'insigne', 'insignes du cardinal', 'manteau') 11P31121
#     0.2617780566215515 : ('Hubert (St)', 'cerf', 'chien', 'chien de chasse', 'clef', 'cor de chasse', 'étole', 'évêque') 11H(HUBERT)
# ============
# ['groupe', 'de', 'figures', 'gant']
#     0.7071067690849304 : ('gant', 'mitaine') 41D225
#     0.7071067690849304 : ('gant', 'mitaine') 41D225(+81)
#     0.5674441456794739 : ('gant', 'gantelet', 'protection', 'protection pour les mains') 45C2221
#     0.2590702176094055 : ('agneau', 'bâton', 'ceindre', 'chaussure', 'debout', 'hanche', 'partir', 'préparatifs', 'reins', 'repas') 71E1173132
#     0.25869831442832947 : ('Barthélemy (St)', 'apôtre', 'bâton', 'couteau', 'diable', 'dragon', 'fouler aux pieds', 'livre', 'peau', 'rouleau') 11H(BARTHOLOMEW)
#     0.2317962497472763 : ('Rome', 'ambassade', 'bâton', 'labourer', 'offrir', 'tyran', 'épée') 98B(CINCINNATUS)51
#     0.21817533671855927 : ('chausette', 'chaussure', 'jambe') 41D233(+83)
#     0.21817533671855927 : ('chausette', 'chaussure', 'jambe') 41D233(+81)
#     0.21817533671855927 : ('chausette', 'chaussure', 'jambe') 41D233
#     0.21817533671855927 : ('chausette', 'chaussure', 'jambe') 41D233(+82)
# ============
# ['groupe', 'de', 'figures', 'coiffure']
#     0.5672897696495056 : ('cheveux', 'coiffure') 31A53
#     0.5672897696495056 : ('cheveux', 'coiffure') 31A53(+0)
#     0.5672897696495056 : ('cheveux', 'coiffure') 31A53(+921)
#     0.5672897696495056 : ('cheveux', 'coiffure') 31AA53
#     0.3152753412723541 : ('coiffeur',) 31A5321
#     0.3152753412723541 : ('coiffeur',) 31AA5321
#     0.287373811006546 : ('robe', 'vêtements') 12A5211
#     0.287373811006546 : ('canoniques', 'robe', 'vêtements') 11Q7146
#     0.2837381362915039 : ('perruque',) 31AA5331
#     0.2837381362915039 : ('perruque',) 31A5331
# ============
# ['fond', 'de', 'paysage', 'colline']
#     0.7071067690849304 : ('colline', 'dune', 'sable') 25H1321
#     0.7071067690849304 : ('Oréades', 'colline') 92L313
#     0.7071067690849304 : ('colline', 'contrées vallonée') 25HH114
#     0.7071067690849304 : ('colline',) 25H113(+1)
#     0.7071067690849304 : ('colline', 'contrées vallonée') 25H114(+1)
#     0.7071067690849304 : ('Hur', 'bras levé', 'colline', 'victoire') 71E1272
#     0.7071067690849304 : ('colline', 'dune', 'sable') 25H1321(+1)
#     0.7071067690849304 : ('colline',) 25H113
#     0.7071067690849304 : ('colline', 'contrées vallonée') 25H114
#     0.7071067690849304 : ('Hébron', 'colline', 'porter sur les épaules') 71F3631
# ============
# ['fond', 'de', 'paysage', 'arbre']
#     0.7071067690849304 : ('arbre',) 25G3(+12)
#     0.7071067690849304 : ('arbre', 'arbre avec une ruche') 47I2431(+9441)
#     0.7071067690849304 : ('abattage des arbres', 'arbre', 'hache', 'racine') 73C111(+0)
#     0.7071067690849304 : ('Ararat (Mont)', 'arbre', 'compagnon', 'crucifixion', 'dix mille', 'empaler', 'perche') 11H(ACHATIUS)61
#     0.7071067690849304 : ('arbre',) 25G3(+24)
#     0.7071067690849304 : ('arbre', 'tomber') 43B412
#     0.7071067690849304 : ('arbre',) 25G3(+37)
#     0.7071067690849304 : ('arbre', 'groupe') 25G11(+361)
#     0.7071067690849304 : ('arbre', 'forêt') 25H15(+0)
#     0.7071067690849304 : ('arbre',) 25G3(+27)
# ============
# ['fond', 'de', 'paysage', 'soleil']
#     0.7071067690849304 : ('soleil',) 24A
#     0.7071067690849304 : ('soleil',) 24A(+0)
#     0.7071067690849304 : ('année', 'année solaire', 'soleil') 23C
#     0.5951886177062988 : ('Marie (Vierge)', "air (dans l')", 'apparition', 'lune', 'menacer', 'mulier amicta sole', 'sept', 'soleil', 'tête (animal)') 73G411
#     0.5951886177062988 : ('Ayyalôn', 'Gabaôn', 'commander', 'lune', 'ordonner', 'siège', 'soleil') 71E52942
#     0.5951886177062988 : ('lune', 'soleil') 73D674(+0)
#     0.5951886177062988 : ('lune', 'soleil') 11C51
#     0.5951886177062988 : ('Planetenkinder', 'influence', 'lune', 'soleil') 24C2(+0)
#     0.5951886177062988 : ('lune', 'soleil') 73D674
#     0.5951886177062988 : ('Planetenkinder', 'influence', 'lune', 'soleil') 24C2
# ============
# ['représentation', 'animalière', 'animal', 'chien']
#     0.6861110925674438 : ('animal',) 25F(+5733)
#     0.6861110925674438 : ('chien',) 34B11(+95732)
#     0.6861110925674438 : ('animal', 'exercice', 'jeux', 'sport') 43C1(+4164)
#     0.6861110925674438 : ('animal',) 25F(+351)
#     0.6861110925674438 : ('animal',) 71A25(+0)
#     0.6861110925674438 : ('Mostri', 'Ripa', 'animal', 'animal fabuleux', 'fiction', 'grotesque') 25FF(+25)
#     0.6861110925674438 : ('Mostri', 'Ripa', 'animal', 'animal fabuleux', 'fiction', 'grotesque') 25FF(+22)
#     0.6861110925674438 : ('animal',) 25F(+57321)
#     0.6861110925674438 : ('animal',) 43C734
#     0.6861110925674438 : ('Mostri', 'Ripa', 'animal', 'animal fabuleux', 'fiction', 'grotesque') 25FF(+7332)
# ============
# ['miroir']
#     1.0 : ('miroir', 'écriture spéculaire') 49L33
#     1.0 : ('Mercure', 'Minerve', 'aile', 'armer', 'bouclier', 'casque', 'dieux', 'donner', 'faux', 'miroir', 'poignard', 'recevoir', 'sac', 'sandale', 'sandales ailées') 94P31
#     1.0 : ('Cité de Dieu', 'Civitas Dei', 'Electa ut Sol', 'Flos Campi', 'Fons Signatus', 'Hortus Conclusus', 'Jardin Clos', 'Porta Coeli', 'Pulchra ut Luna', 'Rosa Mystica', 'Speculum sine Macula', 'Stella Maris', 'Stella Matutina', 'Turris Davidica', 'Turris Eburnea', 'fleur', 'fontaine', 'jardin', 'lune', 'miroir', 'porte', 'rose', 'soleil', 'tour', "tour d'ivoire", 'ville', 'étoile') 11F111(PORTA CLAUSA)
#     1.0 : ('admiration', 'miroir', 'regarder') 11R512
#     1.0 : ('Marie Madeleine (Ste)', 'couronne', "couronne d'épines", 'crucifix', 'fouet', 'instrument de musique', 'livre', 'miroir', 'onguent', 'palme', 'prostituée', 'rosaire', 'rouleau', 'vase') 11HH(MARY MAGDALENE)(+3)
#     1.0 : ('Grâces', 'miroir', 'toilette (faire la)') 92C452
#     1.0 : ('Cité de Dieu', 'Civitas Dei', 'Electa ut Sol', 'Flos Campi', 'Fons Signatus', 'Hortus Conclusus', 'Jardin Clos', 'Porta Coeli', 'Pulchra ut Luna', 'Rosa Mystica', 'Speculum sine Macula', 'Stella Maris', 'Stella Matutina', 'Turris Davidica', 'Turris Eburnea', 'fleur', 'fontaine', 'jardin', 'lune', 'miroir', 'porte', 'rose', 'soleil', 'tour', "tour d'ivoire", 'ville', 'étoile') 11F111(ROSE)
#     1.0 : ('Syracuse', 'bateau', 'incendier', 'miroir', 'miroir ardent', 'siège') 98B(ARCHIMEDES)41
#     1.0 : ('Cité de Dieu', 'Civitas Dei', 'Electa ut Sol', 'Flos Campi', 'Fons Signatus', 'Hortus Conclusus', 'Jardin Clos', 'Porta Coeli', 'Pulchra ut Luna', 'Rosa Mystica', 'Speculum sine Macula', 'Stella Maris', 'Stella Matutina', 'Turris Davidica', 'Turris Eburnea', 'fleur', 'fontaine', 'jardin', 'lune', 'miroir', 'porte', 'rose', 'soleil', 'tour', "tour d'ivoire", 'ville', 'étoile') 11F111(TURRIS DAVIDICA)
#     1.0 : ('Marie Madeleine (Ste)', 'couronne', "couronne d'épines", 'crucifix', 'fouet', 'instrument de musique', 'livre', 'miroir', 'onguent', 'palme', 'prostituée', 'rosaire', 'rouleau', 'vase') 11HH(MARY MAGDALENE)
# ============
# ['gant']
#     1.0 : ('gant', 'mitaine') 41D225
#     1.0 : ('gant', 'mitaine') 41D225(+81)
#     0.8024871945381165 : ('gant', 'gantelet', 'protection', 'protection pour les mains') 45C2221
#     0.36638063192367554 : ('agneau', 'bâton', 'ceindre', 'chaussure', 'debout', 'hanche', 'partir', 'préparatifs', 'reins', 'repas') 71E1173132
#     0.3658546805381775 : ('Barthélemy (St)', 'apôtre', 'bâton', 'couteau', 'diable', 'dragon', 'fouler aux pieds', 'livre', 'peau', 'rouleau') 11H(BARTHOLOMEW)
#     0.3278093934059143 : ('Rome', 'ambassade', 'bâton', 'labourer', 'offrir', 'tyran', 'épée') 98B(CINCINNATUS)51
#     0.3085465431213379 : ('chausette', 'chaussure', 'jambe') 41D233(+83)
#     0.3085465431213379 : ('chausette', 'chaussure', 'jambe') 41D233(+81)
#     0.3085465431213379 : ('chausette', 'chaussure', 'jambe') 41D233
#     0.3085465431213379 : ('chausette', 'chaussure', 'jambe') 41D233(+82)
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: divide by zero encountered in true_divide
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
# /Users/mikekestemont/anaconda3/envs/n36/lib/python3.6/site-packages/gensim/similarities/termsim.py:358: RuntimeWarning: invalid value encountered in multiply
#   Y = np.multiply(Y, 1 / np.sqrt(Y_norm))
